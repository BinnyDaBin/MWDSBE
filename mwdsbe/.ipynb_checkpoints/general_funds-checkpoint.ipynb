# %% [markdown]
# # General Funds

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import mwdsbe
import schuylkill as skool
import time

# %% [markdown]
# ## Data

# %%
registry = mwdsbe.load_registry() # geopandas df

# %%
gf = pd.read_excel(r'C:\Users\dabinlee\Documents\GitHub\mwdsbe_binny\MWDSBE\mwdsbe\data\cwedp_37_report.xlsx', sheet_name='general_funds')

# %%
city_payments = pd.read_excel(r'C:\Users\dabinlee\Documents\GitHub\mwdsbe_binny\MWDSBE\analysis\data\payments\city_payments_detailed_2017.xlsx')

# %%
gf.head()
# Out:
#    DR_ACCT  CR_ACCT CURR_PRIOR_FLAG POSTED_DATE  DEPT  SEC_FD  INDEX  \
# 0      431      101            CURR  2018-07-18     1      10  10058
# 1      431      101            CURR  2018-07-18     1      10  10058
# 2      431      101            CURR  2018-07-18     1      10  10058
# 3      431      101            CURR  2018-07-18     1      10  10058
# 4      431      101            CURR  2018-08-01     1      10  10058
#
#    PROGRAM_CD  MAJ_CLASS CLASS         DOC_NUM        TRANS_DESC DOC_REF_NUM  \
# 0         NaN          1  0101  PAYR1900105401  P.P.E.  07152018         NaN
# 1         NaN          1  0111  PAYR1900105501  P.P.E.  07152018         NaN
# 2         NaN          1  0121  PAYR1900105601  P.P.E.  07152018         NaN
# 3         NaN          1  0161  PAYR1900105701  P.P.E.  07152018         NaN
# 4         NaN          1  0101  PAYR1900383001  P.P.E.  07292018         NaN
#
#   VEND_NAME VEND_NUM        AMT DOC_NUM4 DOC_REF4
# 0       NaN      NaN  504314.18     PAYR      NaN
# 1       NaN      NaN    6653.37     PAYR      NaN
# 2       NaN      NaN   13407.00     PAYR      NaN
# 3       NaN      NaN     232.50     PAYR      NaN
# 4       NaN      NaN  514447.01     PAYR      NaN

# %%
len(gf)
# Out:
# 324213

# %%
gf = gf.loc[gf['MAJ_CLASS'] != 1]

# %%
len(gf)
# Out:
# 247721

# %%
gf = gf.loc[gf['VEND_NAME'].dropna().index]

# %%
len(gf)
# Out:
# 243375

# %%
gf.head()
# Out:
#        DR_ACCT  CR_ACCT CURR_PRIOR_FLAG POSTED_DATE  DEPT  SEC_FD  INDEX  \
# 76492      433      201           PRIOR  2018-07-05     1      10  10058
# 76493      433      201           PRIOR  2018-07-05     1      10  10058
# 76494      433      201           PRIOR  2018-07-05     1      10  10058
# 76495      433      201           PRIOR  2018-07-09     1      10  10058
# 76496      431      201            CURR  2018-07-12     1      10  10058
#
#        PROGRAM_CD  MAJ_CLASS CLASS         DOC_NUM  \
# 76492         NaN          2  0266  VCXX1900006801
# 76493         NaN          2  0266  VCXX1900007201
# 76494         NaN          2  0258  VCXX1900008101
# 76495         NaN          2  0250  PVMD1802221701
# 76496         NaN          2  0285  PVMD1900044801
#
#                                              TRANS_DESC     DOC_REF_NUM  \
# 76492  *1000465144*             MAINT 2 FLDING MAC-6/16  POXX1812248301
# 76493  *3306230172*             MAIL MAC MTHLY LSE-6/18  POXX1812200301
# 76494     *JUN34828S*              CRT RPRTING SVS-6/18  POXX1812349101
# 76495           *PCC00318* BROADCAST SERVICES JUNE 2018  MDXX1800005401
# 76496                           *072018* RENT JULY 2018  MDXX1902006801
#
#                                     VEND_NAME      VEND_NUM       AMT  \
# 76492               PITNEY BOWES INCORPORATED  060495050 01   1320.00
# 76493               PITNEY BOWES INCORPORATED  060495050 01   3114.00
# 76494             STREHLOW & ASSOCIATES, INC.  233036541 01  11125.54
# 76495                               WURD - AM  431986554 01  35000.00
# 76496  AMERICAN HERITAGE FEDERAL CREDIT UNION  231370526 01   1208.33
#
#       DOC_NUM4 DOC_REF4
# 76492     VCXX     POXX
# 76493     VCXX     POXX
# 76494     VCXX     POXX
# 76495     PVMD     MDXX
# 76496     PVMD     MDXX

# %% [markdown]
# ## General Funds by Departments

# %%
simple_cp = city_payments[['dept', 'department_title']]

# %%
# simple_cp['department_title'] = simple_cp['department_title'].str.split(" ", 1, expand=True)[1]

# %%
simple_cp = simple_cp.groupby(['dept', 'department_title']).size().to_frame('N').reset_index()

# %%
simple_cp
# Out:
#     dept                          department_title      N
# 0      1                           01 CITY COUNCIL   1544
# 1      3         03 MAYOR'S OFFICE-LABOR RELATIONS     45
# 2      4               04 MDO-OFFICE OF TECHNOLOGY   4932
# 3      5                         05 MAYOR'S OFFICE    357
# 4      6                      06 OFFICE OF HOUSING   1953
# 5      8      08 MAYOR'S OFFICE-COMMUNITY SERVICES    426
# 6     10                      10 MANAGING DIRECTOR  31179
# 7     11                                 11 POLICE   6680
# 8     12                                12 STREETS   6348
# 9     13                                   13 FIRE   4317
# 10    14                                 14 HEALTH  13957
# 11    15               15 OFFICE OF BH/MR SERVICES   2461
# 12    16                             16 RECREATION   5832
# 13    17              17 FAIRMOUNT PARK COMMISSION     13
# 14    18                    18 ATWATER KENT MUSEUM      1
# 15    20                        20 PUBLIC PROPERTY   4848
# 16    22                         22 HUMAN SERVICES  24013
# 17    23                                23 PRISONS   9230
# 18    24           24 OFFICE OF SUPPORTIVE HOUSING   4711
# 19    25                       25 FLEET MANAGEMENT  53716
# 20    26                 26 LICENSES & INSPECTIONS   3815
# 21    27        27 BOARD OF LICENSES & INSPECTIONS     40
# 22    28                                  28 WATER  19554
# 23    30                           30 ZONING BOARD     98
# 24    31                                31 RECORDS    691
# 25    34                             34 ART MUSEUM      4
# 26    35                    35 DIRECTOR OF FINANCE    935
# 27    36                                36 REVENUE   4085
# 28    37                37 SINKING FUND COMMISSION    226
# 29    38                            38 PROCUREMENT   1069
# 30    40                         40 CITY TREASURER     90
# 31    41                    41 CITY REPRESENTATIVE    104
# 32    42                               42 COMMERCE   6580
# 33    44                                    44 LAW   6112
# 34    45                        45 BOARD OF ETHICS     76
# 35    46       46 MAYOR'S OFFICE OF TRANSPORTATION      9
# 36    47                       47 YOUTH COMMISSION      1
# 37    48  48 MAYOR-OFFICE OF THE INSPECTOR GENERAL    145
# 38    49         49 MAYOR-OFFICE OF SUSTAINABILITY     96
# 39    50       50 MAYORS OFFICE-MURAL ARTS PROGRAM      4
# 40    51               51 CITY PLANNING COMMISSION    195
# 41    52                           52 FREE LIBRARY   9427
# 42    53                      53 BOARD OF PENSIONS    536
# 43    54          54 COMMISSION ON HUMAN RELATIONS    237
# 44    55               55 CIVIL SERVICE COMMISSION     19
# 45    56                              56 PERSONNEL    490
# 46    58               58 OFFICE OF ARTS & CULTURE    122
# 47    59         59 OFFICE OF PROPERTY ASSESSMENTS    695
# 48    61                        61 CITY CONTROLLER    351
# 49    62  62 MAYOR-OFF OF PLANNING AND DEVELOPMENT      7
# 50    63             63 BOARD OF REVISION OF TAXES     93
# 51    65  65 MAYOR-OFFICE OF THE CHIEF ADM OFFICER    223
# 52    66   66 MAYOR-OFFICE OF COMM SCHOOLS & PRE-K    114
# 53    67  67 PHI WATER,SEWER & STORMWTR RATE BOARD     27
# 54    68                      68 REGISTER OF WILLS    104
# 55    69                      69 DISTRICT ATTORNEY   3811
# 56    70                                70 SHERIFF   1230
# 57    73                     73 CITY COMMISSIONERS    916

# %%
gf = gf.merge(simple_cp, how='left', left_on='DEPT', right_on='dept').drop('dept', axis=1)

# %%
gf_dept = gf.groupby(['DEPT','department_title'])['AMT'].sum().to_frame('AMT').reset_index()

# %%
top_10 = gf_dept.sort_values(by='AMT', ascending=False)[:10]

# %%
sns.set(style="whitegrid")
ax = sns.barplot(x="AMT", y="department_title", data=top_10)
ax.set(xlabel='Fund Amount', ylabel='Department')
plt.show()

# %% [markdown]
# ## Vendors under Director of Finance

# %%
finance = gf.loc[gf['department_title'] == '35 DIRECTOR OF FINANCE']

# %%
len(finance)
# Out:
# 5679

# %%
len(finance['VEND_NAME'].unique())
# Out:
# 781

# %%
finance['VEND_NAME'].unique()
# Out:
# array(['BARRY SCOTT', 'ARTICULATE GLOBAL INC', 'UNITED PARCEL SERVICE',
#        'XEROX CORPORATION', 'THE CURLEY ADJUSTMENT BUREAU INC',
#        'LAWTON ASSOCIATES, INC.', 'SELECTIVE INSURANCE - FLOOD',
#        'HOWARTH OCCUPATIONAL & ENV. CONSULTING P',
#        'A V INTERNATIONAL INC', 'OFFICE OF THE DIRECTOR OF FINANCE',
#        'BAER CORWIN INSURANCE AGENCY, INC.',
#        'WILLIS OF PENNSYLVANIA, INC.', 'WILLIS OF NEW YORK INC',
#        'RISK & INSURANCE MGNT SOCIETY, INC RIMS',
#        'INSURANCE SOCIETY OF PHILA', 'ENV SERVICES INC',
#        'AMERICAN SOCIETY OF SAFETY PROFESSIONALS',
#        'HAAS AND WILKERSON INSURANCE INC.', 'SHREEN M. WILLIAMS',
#        'NATIONAL SAFETY COUNCIL', 'U S FACILITIES INC',
#        'OCCIDENTAL FIRE & CASUALTY COMPANY OF NC', 'SHAROLYN MURPHY',
#        'BRADLEY AND BRADLEY ASSOCIATES',
#        'SUPERIOR MOVING & STORAGE, INC.', 'THE GRAHAM COMPANY',
#        'FACTORY MUTUAL INSURANCE COMPANY', 'SHI INTERNATIONAL CORP',
#        'UNITED PARCEL SERVICE INC', 'AXIOMATIC LLC', 'RAIMUNDO ROSADO',
#        'SHANTAE THORPE', 'JAMIKA S. BAUCOM', 'SHENIKA J. RUFF',
#        'AMERICAN EXPRESS', 'WITNESS EXPENSE IMPREST ACCOUNT',
#        'AMERICAN MEDICAL RESPONSE MID-ATLANTIC', 'KARON WHITE',
#        'TANYA MILLER', 'PHILLIP MITCHELL', 'RACGEK HAYES', 'JULIAN HAYES',
#        'KATELYN PEINING', 'CLIFFROY HYLTON', 'ADEMELA LEE',
#        'KRUNOL SHARMA', 'ARLENE VINCENT', 'DEAN SCHMELTZ',
#        'KAEL DOUGHERTY', 'OSMAN ZUBAIR', 'USMAN CHAUDERHI',
#        'ELHADJ CONDE', 'XIANGFU WANG', 'XUERONG CHEN', 'HENRY KOWALESKI',
#        'LAUREN BUCCI', 'MALCOLM JENNINGS', 'MARK SABLOWSKY',
#        'KEITH LAUER', 'SHANE COOPER', 'NAHKELIAH RILEY',
#        'DELORES MAGWOOD', 'MARKESHA GRIFFIN', 'HOWARD HASSELL',
#        'Zhong Chen', 'Ryan McKim', 'Kathleen Sutton', 'Joseph Clardy',
#        'Devon Minto', 'Joseph Thomas', 'Michael Pugh', 'Debra Elling',
#        'Frederick Elling', 'Fred Geathers', 'shalaine Duran',
#        'Terrelle Cherry', 'Catherine Shoemaker', 'Jessica Gibson',
#        'Jillian Paynter', 'Anna Paynter', 'Davine Love', 'Larry Laiken',
#        'Merline Barlett', 'Nancy Papay', 'Alberto Tolbert',
#        'William Rowell', 'Patrice Dantzler', 'Nayaz Glee-Knight',
#        'Henry, Khrishna', 'Laiken, Larry', 'Paynter, Jullian',
#        'Paynter, Anna', 'Love, Davine', 'Bartlett, Merline',
#        'Bartlett, Sunnil', 'Miless, Jade', 'Hogans, Tiffany',
#        'Palmer, Aaron', 'Burroughs, Summyr', 'Caraballo, Edward',
#        'Ryan, John', 'Wilkerson, Steven', 'Johnson, Jamie',
#        'Wood, Marcie', 'Barnett, Jonathan', 'Klinpeter, Cassandra',
#        'Hennessy, Catherine', 'Machels, Sayde', 'Gibson, Jessica',
#        'Williams, Renee', 'Tolbert, Alberto', 'Maya Hall',
#        'Sandra Thompson', 'Daniel Ritz', 'Darcel Blocker',
#        'Leslie, Mella', 'Callaway,    Kenna', 'Davenport,    Brenda',
#        'Wehgular,    Joseph', 'Johnson,    Aisha', 'Baeringer,    Joseph',
#        "D'Attore,    Alexander", 'Woods, Earl', 'Woods, Ashley',
#        'Woods,    Taneesha', 'Shelly, Joy', 'Kennedy,    Eugene',
#        'Kennedy,    Keena', 'Scott, David', 'Young, Oscela',
#        'McIntosh,    Odessa', 'Foreman, Jack', 'Rosa,    Jennifer',
#        'Lane, Mia', 'Woods,    Tanessha', 'Harrison,    Donald',
#        'Santana, Ariel', 'Hague, Shakeel', 'Compacre,    Mohomed',
#        'Serrano,    Jazzlynn', 'Spellman,    Leslie',
#        'Shedrick,    Leona', 'Ansary,    Mohammad', 'Green, Gregory',
#        'Tran, Long', 'Chance,    Clifford', 'Sheridan,    Marissa',
#        'Sheridan III,    Charles', 'Carter-Brown,    Heather',
#        'Hall, Jody', 'Leslie, Fagan', 'GOLDSTEINS FUNERAL HOME',
#        'MICHAEL HUBLER', 'JOSEPH RASIUL JR', 'CHARLOTTE VAUGHAN',
#        'LISAMARIE KELEMEN', 'DENNIS GRANT', 'CAROL SEMINACK',
#        'LAURA HILDEBRANDT', 'SUSAN FOX', 'LARAINE GRECO',
#        'BARBARA BRONISZ', 'MARK JONAS', 'EDWIN THOMPSON', 'LUCY CASPER',
#        'JANICE BERSHAD', 'GAIL STEIN', 'MARLENE MASON', 'DENNIS MULLIN',
#        'ANDREA MERYL WOLF', 'LOIS SESSKIN', 'ELLEN BILO', 'DAVID HOEHN',
#        'GERTRUDE TOMS', 'JOSEPH FOCHT', 'SUZANNE DUNPHY',
#        'MARIANNE BUCCI', 'ROSEANN SCAIRATO', 'JOANNE MCALLISTER',
#        'JEAN SIMONE', 'MARGARET MCKENNA', 'GARY CORWIN', 'STACEY SARNO',
#        'STUART BELL', 'SHARON ZIMMELMAN', 'JONATHAN COHEN', 'ALICE ROBB',
#        'CAROL FEBBO', 'BETTY BROWN', 'GERMAINE DECICCO',
#        'MARYANN MARSELLA', 'TINA TRANTAS', 'BERNADETTE DEANE',
#        'CHARLES BRION', 'DENISE KNIGHT', 'KATHLEEN STELMACH',
#        'MARY LIZZUL', 'ROBERT CICIRELLO', 'GERALD ZACCARIA',
#        'THOMAS MADORNA', 'ELIZABETH FITZPATRICK', 'SHELDON MARGOLIS',
#        'JENNIFER FORTE', 'JOSEPH PERAINO', 'THOMAS PETA',
#        'NANCY CAPPIELLO', 'JOANNE RUGGIANO',
#        'SAVIN FUNERAL HOME INCORPORATED', 'FLUEHR FUNERAL HOME',
#        'ROSE FUNERAL HOME', 'MARVIL FUNERAL HOME', 'MARIE KRAUS',
#        'FRANCES CHRISTENSSEN', 'PATRICIA TRIFILETTI', 'MARILYN RAND',
#        'FELICIA MOTTO', 'EDYIE MARIANO', 'SHIRLEY HERDER',
#        'BERNIE FUNDENBERG', 'SHEILA PALMER', 'EDITH DIXON',
#        'GALZERANO FUNERAL HOME', 'DISTINGUISHED MEMORIAL CHAPELS INC',
#        'TERESA    CLEACHEN', 'JOSEPH    KARP', 'GLORIA    MALONEY',
#        'DAVID    EGEE', 'STEPHEN    IOELE', 'SHERRY    SHERMAN',
#        'CLAIRE    BOYLE', 'ALIYMA    ALSAADHL', 'MARGARET    RITTO',
#        'MARY    KAISER', 'SANDA    PYTRYSSON', 'ANNE    KLINEWSKI',
#        'GLENN    FORD', 'ANITA    WRIGHT', 'VIRIGINA    FLEMING',
#        'MARGARET    GEIST', 'CHERLY WELLS', 'ANN    WALTON',
#        'KAREN    MORRIS', 'JULIE    DANCZEWSKI', 'MARSHA    STERN',
#        'HARRIET    CITRON', 'JOSEPH    FABRIZIO', 'CLARA    DITIZIO',
#        'KATHRYN    EWING', 'GLORIA    MARTIN', 'JOHN    SINIBALDI',
#        'GEORGINA    ENGLE', 'VERONICA    BEVIDAS', 'RICHARD    DALY JR',
#        'MARIE    HANSEN', 'JUDITH    HANNIGAN', 'TIMOTHY    FORMICA',
#        'VALERIE    CANAL', 'RONALD    MASCI', 'ROSEMARIE    MAYBAUM',
#        'ANTHONY    ANTONELLI', 'ABBI    COHEN', 'VICTORIA    FINNEGAN',
#        'NORMAN    LOCK', 'DONNA    GENDEK', 'KAREN    BERKO',
#        'DAVID    DEMARCO', 'SUSAN    BUTLER', 'CHRISTINE    RIVELLO',
#        'GARY    SHANKER', 'BARBARA    DOUGHERTY', 'NAOMI    MARMORSTEIN',
#        "SUSAN    O'DONNELL", 'JOSEPH    LYNCH', 'CYNTHIA    INVERSO',
#        'SUSANNA    SALVATI', 'WILLIAM    SEYBOLD', 'VERONICA    MOSCATO',
#        'MARK    CIVATTE', 'LORI    ALVAREZ', 'JACQUELINE    BROCK',
#        'CAROLYN    KELLY', 'LINDA    SANDA', 'RONALD    MCNALLY',
#        'PETNER FUNERAL HOME', 'MANNAL FUNERAL HOME',
#        'TOMLINSON FUNERAL HOME', "LEONETTI-O'LEARY FUNERAL HOME INC",
#        'GOVERNMENT FINANCE OFFICERS ASSOCIATION', 'ROBERT WELLS',
#        'GILBERT    H SCHOBERT', 'BONNIE R    SCHRAMM',
#        'STEVEN    SCHICKMAN', 'PAUL S    RYSKALCHICK', 'JANET    RUDMAN',
#        'JASON T    ROSE', 'ELLEN    ROBINSON', 'JASMINDA    D NAVARRO',
#        'DOLORES    T KOLECKI', 'DAVID J    MURAWSKI',
#        'EVELYN P    MUNIZZA', 'ANN    MIRIELLO', 'NORMA    MILARSKY',
#        "JENNIFER    D'ANGELO", 'VIRGINIA    McEACHIN',
#        'GERALDINE    C MAZZAFRO', 'DOROTHY    MATTHEWS',
#        'PATRICIA    R GRADY', 'ADOLPH J    LORENZ JR',
#        'STEVEN    KRASNEY', 'CONSTANCE    M ELWELL', 'JAMES    KIRWIN',
#        'HELEN V    KEIMER', 'KATHRYN    A JUDGE', 'MARY    EVANS JOHNSON',
#        'WANDA    GAUTHNEY', 'MARK    JACOBS', 'MARIE    HACKIMER',
#        'TERESA    MEREDITH', 'MARIANNE    GALLAGHER', 'MARY    DUFFY',
#        'CHRISTINE    EMBERY', 'DR. ALAN    FREIDMAN', 'KAREN    ZELTT',
#        'MIRIAM    A. DYDAK', 'ELIZABETH    C. DOUGHERTY',
#        'BEATRICE    DEVLIN', 'CHRISTINE    DENUCCIO', 'CLAIRE    TAYLOR',
#        'VIENNA    COLEMAN', 'SHELLEY    BLUMSTEIN',
#        'FLORENCE    BARBARDO', 'LOUIS    AUERBACH',
#        'JAMES R.    MEHAFFEY', 'DONNA    REGAN', 'ROBERT    KANE',
#        'ANDREA    DEVENNEY', 'GRETA    VISH', 'AMELIA    FOGARINO',
#        'DIANE    DELCOLOMBO', 'MICHAEL    RUBEO', 'MARIA I    ECHEVARRIA',
#        'BEVERLY    MONTEVERDE', 'JANICE    GRAMLICH', 'PATRICIA    CELIA',
#        'IDA    TAYLOR', 'BETTY    SIGRIST', 'CAROLYN    CAPOBIANCO',
#        'CATHERINE    HOLLAND', 'MR.    JOSEPH SMITH III',
#        'JOSEPH    FEDURA', 'BETTY T.    KIRKLEY', 'NEIL    INVERSO',
#        'ROSE    OWEN', 'VIRGINIA    BRODE', 'HARVEY    WERKSTELL',
#        'MRS.    PATTI J SCHEIDE', 'MRS.    AVITAL CNAAN',
#        'NANCY D.    BURKE', 'DANA L    WHITMORE', 'BOCK  BETTY',
#        'VOLLRATH    MARIE J', 'THOMAS    DOTT', 'JEANNINE    GERSTLE',
#        'MARY    HARMATZ', 'JAMES J.    SNELL JR.', 'ANDREW    ZELEZ',
#        'DONNA    IANNELLI', 'DEBORAH    BROWN-WILLIAMS',
#        'DR.    LINDA WEBER', 'PAUL    VETTRAINO', 'MELVIN    STEWART',
#        'MARLENE    SIMONS', 'JEFFREY    SHORE', 'BARBARA    OAKS',
#        'CAROL    HERSHEY', 'SARAH    WESCOTT', 'MICHAEL    TANKLE',
#        'LORRAINE    CRUZ', 'VALERIE    FERRIS', 'THERESA    SAUNDERS',
#        'BEULAH    SAIDEMAN', 'LINDA O    RIDEOUT', 'GERALDINE    POTTER',
#        'ADELE    POINTER', 'BETTIE A    PEYTON', 'REGINA    PATTERSON',
#        'JOYCE    NEFF', 'MICHAEL    NEEDLE', 'CAMILLE    BAKER',
#        'JAMES J    MOSKOWITZ', 'JOHN    MARKELWITH', 'ELISE    LEHRFELD',
#        'MARION    WEBSTER', 'JOANNE    KLEIN', 'MARIAN    KENNEDY',
#        'SABINA    KELLER', 'BARBARA    JOHNSON', 'PHYLLIS    HALPERN',
#        'ROBERT    GREENFIELD', 'ROSEMARY    GRANT', 'DENISE    GANNON',
#        'STEPHEN    FRANKOWSKI', 'CAROL    ANN ERCOLONO',
#        'JAMES    EDWARD JR', 'THOMAS    DELACOURT',
#        'JACQUELINE    CRAWFORD', 'WILLIAM    J CRAGIN JR',
#        'KATHLEEN    COLEMAN', 'SHELLY    GUSS', 'WILLIAM    K  ALLEN',
#        'BARBARA    ZUKERMAN', 'MARK    WEISSMAN', 'JOYCEAN    MOSELEY',
#        'RITA    MCKEOWN', 'MICHAL    LEVENTHAL', 'SUSAN    GOLDENBERG',
#        'ELAINE    LACHOWICZ', 'LOUIS    DINAPOLI',
#        'PHYLLIS    STANSBURY CARTER', 'VIVIAN    DIKEMAN',
#        'SARA    LOCKLEY', 'NANCY    JORDAN', 'AMY    KANDER',
#        'WILLIAM    BENONIS', 'KIM    JOHNSTON', 'MICHAEL    VERNACCHIO',
#        'MARK    NICOLL', 'SHERRY    SHAMANSKY', 'ROBIN    SCHLOSBERG',
#        'ANDREW    BACKOVER', 'ADAM    KURLAND', 'FRED    COHEN',
#        'LYNNE    WICKLINE', 'LINDA    RICCI', 'STEVEN    LOVE',
#        'DENISE    SERPENTINE', 'KIMBERLY    BERNER', 'KARIN    HEPP',
#        'JOSEPH    MURPHY', 'MICHAEL    JOHN', 'CARL    WANJEK',
#        'AUSTRALIA    ACKISS', 'MICHALINA    PALIOTTO', 'LOUISE    BROWN',
#        'CELIA    TOMPKINS', 'LYNN    MUELLER', 'CAROL    LEABOURNE',
#        'DONNA    MANGOLD', 'JOSEPH    RUCINSKI', 'LUBA    SAHASAYLO',
#        'BERNADETTE    LEWIS', 'WILLIAM    MONTELEONE',
#        'MICHAEL    YAEGER', 'NICHOLAS    GERACE', 'BARBARA    HARTZELL',
#        'LINDA    ISARD', 'GARY    JESTER', 'MARGARET    LINK',
#        'PATRICIA    MASIEJCZYK', 'IRA    POGACHEFSKY', 'GERALD    RUBIN',
#        'CINTHIA    SILVERSTEIN', 'BETTE    WOOLSEY', 'KIM    MOSKOWITZ',
#        'ERVINA WHITE-BEAUFORD FUNERAL HOME', 'JOSEFINE AREVALO',
#        'RICHARD SENSENBRENNER', 'GIRGIS Z. SHEHATA', 'YASHESH SHAH',
#        'MAXIMUS FINANCIAL SERVICES, INC.', 'ZELENKOFSKE AXELROD LLC',
#        'BOXWOOD TECHNOLOGY, INC.', 'MICROGRAPHIC COMPUTER SERVICES INC',
#        'IHS GLOBAL INC.', 'NU VISION TECHNOLOGIES LLC', 'JOHN W CORLIES',
#        'SOLUSTAFF', 'ABSO', 'ENTERPRISE HOLDINGS INC.', 'JOHN W. HODGE',
#        'A T & T MOBILITY NATIONAL ACCOUNTS LLC', 'CAROLYN R. STEINBERG',
#        'PENNSYLVANIA MUNICIPAL LEAGUE', 'SS & C TECHNOLOGIES, INC.',
#        'ROBERT J GLOUDEMANS', 'CHEIRON, INC.', 'DORIS SMALLWOOD',
#        'FRANCIS GIZAZA CPA', 'URISA', 'AERC ACQUISITION CORP',
#        'HORSEY, BUCKNER & HEFFLER, LLP', 'KRONOS INCORPORATED',
#        'STAPLES BUSINESS ADVANTAGE', 'WAREHOUSE BATTERY OUTLET INC',
#        'ENVELOPES & PRINTED PRODUCTS INC', 'SAFEWARE INCORPORATED',
#        'SAF T GARD', 'INNOVATIVE PRINTING SYSTEMS INC.', 'PHILACOR',
#        'W B MASON COMPANY INC', 'PAPER MART INCORPORATED',
#        'VERITIV OPERATING COMPANY',
#        'CENTER CITY NEWSPAPER DISTRIBUTORS INC', 'NBF CORP',
#        'DELL MARKETING LP', 'CDW GOVERNMENT INC', 'GREEN & SCHAFLE LLC',
#        'MINCEY FITZPATRICK ROSS LLC',
#        'CITY OF PHILADELPHIA FINANCE DEPARTMENT',
#        'GERALD S. SEGAL AND ASSOCIATES P.C.', 'ANNY DING',
#        'ABRAMSON & DENENBERG P.C.', 'JAFFE & HOUGH, P.C.',
#        'STEVEN AUERBACH', 'LEVIN & ZEIGER LLP',
#        'METLIFE ASSIGNMENT COMPANY INC',
#        'KAIRYS RUDOVSKY MESSING FEINBERG LIN LLP', 'RSM US LLP',
#        'INSTITUTE FOR JUSTICE', 'CONSOLE MATTIACCI LAW LLC',
#        'MICHAEL D. CARROLL LLC', 'REGINALD C. ALLEN', 'RASHIDA HOLMES',
#        'COMMONWEALTH OF PA DEPT OF REVENUE', 'SO YONG SUH',
#        'SIMON & SIMON PC', 'ANTHONY GUALTIERI', 'ROBERT J. GARNICK',
#        'SPEAR GREENFIELD RICHMAN WEITZ &TAGGART', 'J. FINE LAW GROUP, PC',
#        'MICHAEL P. MURPHY, JR.', 'SALIMAH BARKLEY',
#        'MILDENBERG LAW FIRM PC', 'ADAMS KEARNEY LLC',
#        'GINSBURG & ASSOCIATES',
#        'DASHEVSKY HORWITZ KUHN NOVELLO& SHORR PC',
#        'VILLARI BRANDES & GIANNONE PC', 'SAFFREN & WEINBERG L.P.',
#        'HARRY J. SHER', 'KELLY & HERRON P.C.',
#        'RONALD A. CLEARFIELD & ASSOCIATES P.C.',
#        'BISHOP,DORFMAN,KROUPA & BISHOP P.C.',
#        'BROWNSTEIN,PEARLMAN,WIEZER,NEWMAN &COOK',
#        'MATKOFF SHENGOLD BURKE BLYWEISS ARBITTIE',
#        'LAW OFFICES OF PAUL H. KAHN, P.C.', 'STUART M. NIEMTZOW',
#        'SCHATZ & STEINBERG, P.C.', 'ROSENBAUM & ASSOCIATES, P.C.',
#        'JMV HOLDING CORPORATION', 'SWARTZ CULLETON PC, INC.',
#        'JOSEPH J. DIGIOVANNI, P.C.', 'ZHEN CHUN WENG',
#        'STEVEN M LIPSCHUTZ, P.C.', 'DISANDRO & MALLOY, P.C.',
#        'ROVNER ALLEN ROVNER ZIMMERMAN AND NASH', 'KILLINO FIRM, P.C.',
#        'THE ROTHENBERG LAW FIRM LLP', 'FODERA & LONG, P.C.',
#        'ANTHONY L. CIANFRANI, ESQUIRE', 'LOWENTHAL & ABRAMS P.C.',
#        'WILLIAM I. SHINDELL, ESQUIRE', 'WILLIAM A. CALANDRA, ESQUIRE',
#        'THE LAW OFFICE OF JARED S. ZAFRAN LLC',
#        'CRAIG A. ALTMAN, ESQUIRE', 'CIANFRANI LAW LLC',
#        'VAL PLEET WILSON ESQUIRE', 'DAVID B. SHERMAN, ESQUIRE',
#        'HOWARD K. TRUBMAN', 'FREIWALD LAW P.C.', 'BENTLEY M. SAUL, LTD.',
#        'LAW OFFICES CHRISTY ADAMS PC', 'KARPF KARPF & CERUTTI P.C.',
#        'SILVERS, LANGSAM & WEITZMAN, P.C.',
#        'LEONARD K. HILL & ASSOC, P.C.', 'DEFINO LAW ASSOCIATES PC',
#        'RICHARD M. OCHROCH & ASSOCIATES',
#        'LOUIS B. HIMMELSTEIN AND ASSOCIATES P.C.',
#        'SPIVACK & SPIVACK, LLP', 'LAW OFFICES OF ALAN F. GALERMAN P.C.',
#        'FINE AND STAUD LLC', 'JOHN T. DOOLEY, ESQUIRE',
#        'JAMES E. LOGAN III', 'BEZARK LERNER & DEVIRGILIS PC',
#        'BKB COMMUNITY DEVELOPMENT INC', 'GOLDBERG & WEINSTEIN LLC',
#        'G. LAWRENCE DEMARCO, LLM', 'ELIZABETH A. SAVITT, ESQUIRE P.C.',
#        'WILLIAMS CEDAR LLC', 'NEIL R. GELB, PC',
#        'LAW OFFICE OF JOEL J. KOFSKY, ESQ.',
#        'LAW OFFICES OF KENNETH M.RODGERS ESQUIRE',
#        'DEPASQUALE LAW OFFICE', 'VAUGHN A. BOOKER, ESQUIRE',
#        'LAW OFFICES OF LEONARD ZOFTIS', 'STUART LEON ESQUIRE',
#        'SACCHETTA & FALCONE', 'PETER L. JOHNSTON',
#        'MARINO & ASSOCIATES PC', 'DION, SOLOMON, & SHAPIRO, LLC',
#        'SAGOT CORNETT P.C.', 'PATRICK J. RODDEN, ESQUIRE',
#        'SEAN E. QUINN', 'DONALD BUREMS SR',
#        'BROWNSTEIN, VITALE & WEISS, PC',
#        'MCMONAGLE, PERRI & MCHUGH, P.C.', 'KWARTLER MANUS LLC',
#        'SILVERMAN TROTMAN & SCHNEIDER LLC',
#        'LAW OFFICES OF STEPHEN GREENFIELD PC',
#        'STEPHEN A. CORBMAN, ESQUIRE', 'GARNICK & ASSOCIATES, P.C.',
#        'VELTER, YUROVSKY & ZOFTIS, LLC',
#        'HAGGERTY GOLDBERG SCHLEIFER & KUPERSMITH', 'JOYCE ULLMAN ALPERIN',
#        'LAW OFFICES OF TODD B. JACOBS LLC',
#        'KINDER MORGAN OPERATING L.P. "D"', 'SILVER & SILVER',
#        'SOLNICK & ASSOCIATES LLC', 'TRICHON, CAMMISA & AXELROD, P.C.',
#        'EAGLE INDUSTRIAL HYGIENE ASSOCIATES INC',
#        'TANTALA ASSOCIATES LLC', 'URBAN DEVELOPMENT CORPORATION',
#        'JOYCE CONOVER', 'STEVEN L. CHUNG ESQUIRE, LLC',
#        'MCCANN & WALL, LLC', 'SALTZ, MONGELUZZI, BARRETT & BENDESKY PC',
#        'PECO ENERGY COMPANY', 'WILLIAM J. FAUST II, ESQUIRE',
#        'KANE & SILVERMAN, P.C.', 'SOLOFF & ZERVANOS',
#        'JAMES R. RADMORE, ESQUIRE', 'WARREN MCGRAW & KNOWLES LLC',
#        'SILVERMAN TROTMAN & SCHNEIDER', 'ARCHER & GREINER',
#        'KATS & ASSOCIATES, P.C.', 'SHOR & LEVIN, PC',
#        'BERNARD M. GROSS, ESQ.', 'MARZZACCO INJURY LAW INC',
#        'FREEDMAN & LORRY, P.C.', 'GARY P. HESLIN ESQUIRE',
#        'BARATTA & RUSSELL, P.C.', 'MURRAY L. GREENFIELD & ASSOCIATES',
#        'MARGARET BOYCE FUREY', 'SACKS WESTON DIAMOND LLC',
#        'FELDMAN SHEPHERD WOHLGELERNTER TANNER', 'THE WEITZ FIRM LLC',
#        'EISENBERG ROTHWEILER WINKLER EISENBERG J',
#        'MASTER WEINSTEIN MOYER, P.C.', 'ANDREW T. NEUWIRTH',
#        'MEDNICK, MEZYK AND KREDO, P.C.', 'MARC E. BATT',
#        'DEBORAH M. TRUSCELLO', 'LAUREN C. LEVIN, LTD',
#        'ROSEN, MOSS, SNYDER & BLEEFELD LLP',
#        'LARRY PITT & ASSOCIATES, P.C.', 'GIBBONS LEGAL P.C.',
#        'LAW OFFICE OF RHONDA HILL WILSON P.C.', 'MARRONE LAW FIRM',
#        'ROBERT WILLIAM SINK', 'WILLIAM M. CARLITZ P.C.',
#        'STEPHEN ALTAMURO, ESQUIRE', 'ZAVODNICK ZAVODNICK & LASKY LLC',
#        'JOSEPH CHAIKEN & ASSOCIATES P.C.', 'COOPER AND SCHALL, P.C.',
#        'STEPHEN W BRUCCOLERI', 'KAUFMANN & ANASTASIA',
#        'THE PEARCE LAW FIRM P.C.', 'WHEELS, INC.',
#        'JOSEPH L MESSA & ASSOCIATES', 'LEVANT LAW P.C.',
#        'LOWELL KENNETH CHOTINER', 'SPRAGUE & SPRAGUE',
#        'JENSEN BAGNATO PC', 'NEUFELD SCHECK & BRUSTIN LLP',
#        'EARL D. RAYNOR, JR.', 'EMMANUEL DAVENPORT', 'LAURIE R. JUBELIRER',
#        'HENRY DUGAN', 'JAMES KOPACZEWSKI', 'JEAN-PIERRE LANGAN',
#        'DAVID FISHER', 'STEPHEN HOLDEN', 'R. EMMETT MADDEN, ESQ',
#        'TEMPLE UNIVERSITY HOSPITAL',
#        'WAPNER NEWMAN WIGRIZER BRECHER & MILLER',
#        'PROFESSIONAL LAW ASSOCIATION', 'CHRISTOPHER J. EVARTS',
#        'CONRAD J. BENEDETTO, ESQUIRE', 'LAW OFFICE OF LONNY FISH, PC',
#        "THE O'HANLON LAW FIRM, P.C.", 'MICHAEL I. MCDERMOTT, ESQUIRE',
#        'PATRICK G. GECKLE, LLC', 'DENISE C. GENTILE',
#        'LISS & MARION, P.C.', 'WILLIAM AVERONA, ESQUIRE',
#        'GAY & CHACKER PC', 'OXMAN GOODSTADT KURITZ PC',
#        'STANSHINE & SIGAL, P.C.', 'KLAPROTH LAW PLCC',
#        'GREENBLATT, PIERCE FUNT AND FLORES LLC', 'MICHAEL PILEGGI',
#        'DECHERT LLP', 'LAW OFFICE OF GREGORY J. PAGANO, PC',
#        'BRETT TESSLER & ASSOCIATES, P.C.', 'PAUL J. HETZNECKER, ESQUIRE',
#        'LAW OFFICES OF WILLIAM J. FOX, P.C.',
#        'JAMES, SCHWARTZ & ASSOCIATES PC', 'BADEY, SLOAN & DIGENOVA P.C.',
#        'LAW OFFICES OF RICHARD A. STOLOFF', 'POPPER AND YATVIN',
#        'JOHNATHAN M. RUIZ', 'LAW OFFICES OF WILLIAM P. FEDULLO',
#        'FREDRICK E. CHARLES', 'KHURSHID A. MUGHAL', 'LAUREN A. WIMMER',
#        'FELLERMAN & CIARIMBOLI LAW PC', 'FRANCIS REPICI JR.',
#        'DOMONIC GORDINE', 'JANNA DIBIASE', 'MEGHAN LEWIS',
#        'NICOLE MARCHESANO', 'TARYN PHILIPPI', 'ANNMARIE BACINO',
#        'PETER C. BOWERS, P.C.', 'AR V. CITY OF PHILADELPHIA QSF',
#        'PRINCE LAW OFFICES, P.C.', 'SHINGLESLAW LLC',
#        'MICHAEL A. SHECHTMAN', 'DAVID WESLEY CORNISH',
#        'DEREK A STEENSON, ESQ', 'AUGUSTUS L PASQUARELLA P.C.',
#        'THE SPADE LAW FIRM LLC', 'KASHKASHIAN DOVER AND ASSOCIATES',
#        'HANAMIRIAN FIRM, P.C.', 'JOHN WENDELL BEAVERS ESQUIRE',
#        'THE FENERTY LAW FIRM, LLC', 'RANIA MAJOR', 'MCKOY LAW FIRM LLC',
#        'LAW OFFICE OF GREGG L. ZEFF', 'LAFFEY BUCCI & KENT LLP',
#        'LAW OFFICES OF CHRISTOPHER HUDOCK, PLLC', 'ANAPOL WEISS',
#        'MINCEY & FITZPATRICK LLC', 'SUSAN GOBRESKI',
#        'SCHOOL DISTRICT OF PHILADELPHIA', 'INTEREST ON REFUNDS',
#        'COMMUNITY COLLEGE OF PHILADELPHIA', 'SYDREA OUTEN',
#        'ENOCH GOODMAN', 'ROBERT GASKINS', 'KHADIJAH MARY ROBINSON',
#        'WELCOME AMERICA, INC.', 'PHILADELPHIA MUSEUM OF ART',
#        'AVENUE OF THE ARTS, INC.', 'WILLS EYE HOSPITAL',
#        'THE AFRICAN AMERICAN MUSEUM IN PHILA',
#        'PHILA AUTHORITY FOR INDUSTRIAL DEVELOP',
#        'GREATER PHILA. TOURIST MARKETING CORP.',
#        'PHILADELPHIA CONVENTION & VISITORS BUR',
#        'JOHNSON HOUSE HISTORIC SITE INC',
#        'PHILADELPHIA HOUSING AUTHORITY',
#        'FUND FOR SCHOOL DISTRICT OF PHILADELPHIA',
#        'URBAN AFFAIRS COALITION', 'CITY YEAR, INC.',
#        'THE PHILADELPHIA FOUNDATION', 'PHILADELPHIA CLEF CLUB',
#        'DELAWARE VALLEY REGIONAL PLANNING COMM',
#        'FUND FOR PHILADELPHIA INCORPORATED',
#        'THE MANN CENTER FOR THE PERFORMING ARTS',
#        'LAW OFFICES OF ERIC A SHORE', 'RHONDA MCLAIN', 'MATTHEW R. KLINE',
#        'PATRICE HOWARD THOMAS', 'TROY H. WILSON, ESQUIRE, LLC',
#        'ALICIA ABBOTT', 'MARKOWITZ & RICHMAN', 'WEISBERG LAW',
#        'KRASNER & LONG LLC', 'TOBIN LAW OFFICE LLC',
#        'PENNSYLVANIA INSTITUTIONAL LAW PROJECT', 'CITY OF PHILADELPHIA',
#        'HOUSING TRUST FUND'], dtype=object)

# %% [markdown]
# ## Unique Vendors of all general funds

# %%
len(gf['VEND_NAME'].unique()) # out of 243375
# Out:
# 9543

# %%
print('Percentage of unique vendors:', 9543 / 243375 * 100, '%')
# Out:
# Percentage of unique vendors: 3.921109399075501 %

# %% [markdown]
# ## Matching: Fuzz95 + TF-IDF85

# %%
# clean data
ignore_words = ['inc', 'group', 'llc', 'corp', 'pc', 'incorporated', 'ltd', 'co', 'associates', 'services', 'company', 'enterprises', 'enterprise', 'service', 'corporation']
cleaned_registry = skool.clean_strings(registry, ['company_name', 'dba_name'], True, ignore_words)
cleaned_gf = skool.clean_strings(gf, ['VEND_NAME'], True, ignore_words)

cleaned_registry = cleaned_registry.dropna(subset=['company_name'])
cleaned_gf = cleaned_gf.dropna(subset=['VEND_NAME'])

# %%
cleaned_gf.to_excel(r'C:\Users\dabinlee\Documents\GitHub\mwdsbe_binny\MWDSBE\analysis\data\general_funds\cleaned_gf.xlsx', header=True)

# %%
len(cleaned_gf)
# Out:
# 243375

# %%
# Fuzz 95 + TF-IDF 85 with max_matches = 1
t1 = time.time()
merged = (
    skool.fuzzy_merge(cleaned_registry, cleaned_gf, left_on="company_name", right_on="VEND_NAME", score_cutoff=95)
    .pipe(skool.fuzzy_merge, cleaned_registry, cleaned_gf, left_on="dba_name", right_on="VEND_NAME", score_cutoff=95)
    .pipe(skool.tf_idf_merge, cleaned_registry, cleaned_gf, left_on="company_name", right_on="VEND_NAME", score_cutoff=85)
    .pipe(skool.tf_idf_merge, cleaned_registry, cleaned_gf, left_on="dba_name", right_on="VEND_NAME", score_cutoff=85)
)
t = time.time() - t1

# %%
print('Execution time:', t/60, 'min')
# Out:
# Execution time: 22.8173419157664 min

# %%
matched = merged.dropna(subset=['VEND_NAME'])

# %%
print('Matching:', len(matched), 'out of', len(cleaned_registry))
# Out:
# Matching: 136 out of 3119

# %%
unique_vendors = matched['VEND_NAME'].tolist()

# %%
full_matched = cleaned_gf.loc[cleaned_gf['VEND_NAME'].apply(lambda x : x in unique_vendors)]
# Out:
#         DR_ACCT  CR_ACCT CURR_PRIOR_FLAG POSTED_DATE  DEPT  SEC_FD   INDEX  \
# 2           433      201           PRIOR  2018-07-05     1      10   10058
# 18          433      201           PRIOR  2018-07-19     1      10   10058
# 19          433      201           PRIOR  2018-07-19     1      10   10058
# 202         431      201            CURR  2018-08-10     1      10   10058
# 203         431      201            CURR  2018-08-13     1      10   10058
# ...         ...      ...             ...         ...   ...     ...     ...
# 238272      433      201           PRIOR  2018-07-27    23      10  230073
# 238285      431      201            CURR  2019-06-27    22      10  226280
# 238289      431      201            CURR  2019-06-18    22      10  226280
# 238299      433      201           PRIOR  2019-01-08    22      10  226280
# 243328      431      201            CURR  2019-04-15    37      10  370072
#
#         PROGRAM_CD  MAJ_CLASS CLASS         DOC_NUM  \
# 2              NaN          2  0258  VCXX1900008101
# 18             NaN          2  0258  VCXX1900408101
# 19             NaN          2  0258  VCXX1900383201
# 202            NaN          2  0258  VCXX1901049401
# 203            NaN          2  0258  VCXX1901062201
# ...            ...        ...   ...             ...
# 238272         NaN          4  0427  VCXX1900606001
# 238285         NaN          4  0427  VCXX1909362302
# 238289         NaN          4  0427  VCXX1909085702
# 238299         NaN          4  0427  VCXX1903988102
# 243328         NaN          7  0705  PVXX1901010901
#
#                                                TRANS_DESC     DOC_REF_NUM  \
# 2           *JUN34828S*              CRT RPRTING SVS-6/18  POXX1812349101
# 18          *JUL35226S*              CRT RPRTING SVS-6/18  POXX1812349101
# 19      *MAY34385S*              CRT RPRTING SVS-4/18&...  POXX1812349101
# 202       *JUL35228S*              CRT RRT WAIT TIME-6/18  POXX1910295101
# 203         *JUL35391S*              CRT RPRTING SVS-7/18  POXX1910293901
# ...                                                   ...             ...
# 238272     *B08480763*              B08480763/EQUIP/06/18  POXX1812162501
# 238285                   #B10002045#              SCANNER  POXX1912118102
# 238289                    #B10068691#              WEBCAM  POXX1912141802
# 238299                    #B08440820#              ENDRUN  POXX1812335002
# 243328                            *09B EXTENSION* FA FEES             NaN
#
#                 VEND_NAME      VEND_NUM       AMT DOC_NUM4 DOC_REF4  \
# 2                strehlow  233036541 01  11125.54     VCXX     POXX
# 18               strehlow  233036541 01   3273.93     VCXX     POXX
# 19               strehlow  233036541 01  18024.30     VCXX     POXX
# 202              strehlow  233036541 01     70.00     VCXX     POXX
# 203              strehlow  233036541 01    587.10     VCXX     POXX
# ...                   ...           ...       ...      ...      ...
# 238272  shi international  223009648 01  21700.00     VCXX     POXX
# 238285  shi international  223009648 01    168.80     VCXX     POXX
# 238289  shi international  223009648 01    166.00     VCXX     POXX
# 238299  shi international  223009648 01   1785.53     VCXX     POXX
# 243328   acacia financial  204775407 01   3000.00     PVXX      NaN
#
#                   department_title        N
# 2                  01 CITY COUNCIL   1544.0
# 18                 01 CITY COUNCIL   1544.0
# 19                 01 CITY COUNCIL   1544.0
# 202                01 CITY COUNCIL   1544.0
# 203                01 CITY COUNCIL   1544.0
# ...                            ...      ...
# 238272                  23 PRISONS   9230.0
# 238285           22 HUMAN SERVICES  24013.0
# 238289           22 HUMAN SERVICES  24013.0
# 238299           22 HUMAN SERVICES  24013.0
# 243328  37 SINKING FUND COMMISSION    226.0
#
# [5730 rows x 20 columns]
