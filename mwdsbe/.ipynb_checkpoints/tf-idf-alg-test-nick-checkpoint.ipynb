# %% [markdown]
# # TF-IDF

# %%
import mwdsbe
import mwdsbe.datasets.licenses as licenses
import schuylkill as skool
import pandas as pd
import numpy as np

# %%
# import registry
registry = mwdsbe.load_registry() # geopandas df

# %%
registry.head()
# Out:
#                            company_name    dba_name owner_first owner_last  \
# registry_id
# 0                119 Degrees Architects         NaN      Rafael     Utrera
# 1                         12Bravo Group         NaN     JEFFREY  YEKENCHIK
# 2            1st Choice Financial Group    ProVisio    Kathrina      Nease
# 3                     212 Harakawa Inc.  Two Twelve         Ann   Harakawa
# 4                   215 Media Solutions         NaN      Dewain    Johnson
#
#                                  location  location_city location_state  \
# registry_id
# 0            1503 Green Street, Suite # 4   Philadelphia             PA
# 1                     236 McKendimen Road  Medford Lakes             NJ
# 2                      133 N. 21st Street      Camp Hill             PA
# 3            236 W 27th Street, Suite 802       New York             NY
# 4                       810 Felton Avenue    Sharon Hill             PA
#
#              zip_code               mailing_address   mailing_city  \
# registry_id
# 0             19130.0  1503 Green Street, Suite # 4   Philadelphia
# 1              8055.0           236 McKendimen Road  Medford Lakes
# 2             17011.0            133 N. 21st Street      Camp Hill
# 3             10001.0  236 W 27th Street, Suite 802       New York
# 4             19079.0             810 Felton Avenue    Sharon Hill
#
#             mailing_state  mailing_zip certification_type  \
# registry_id
# 0                      PA      19130.0                MBE
# 1                      NJ       8055.0               DSBE
# 2                      PA      17011.0                WBE
# 3                      NY      10001.0               MWBE
# 4                      PA      19079.0                MBE
#
#                                                     capability  local  \
# registry_id
# 0            NAICS 5413 Architectural, Engineering, and Rel...   True
# 1            Addition, alteration and renovation for-sale b...  False
# 2                           NAICS 928120 International Affairs  False
# 3            Graphic Design Services; Graphic design servic...  False
# 4            NAICS 5414 Specialized Design Services ; NAICS...  False
#
#              out_of_state location_standard        lat        lng  \
# registry_id
# 0                   False     1503 GREEN ST  39.964275 -75.163042
# 1                    True               NaN        NaN        NaN
# 2                   False               NaN        NaN        NaN
# 3                    True               NaN        NaN        NaN
# 4                   False               NaN        NaN        NaN
#
#                                                  geometry
# registry_id
# 0            POINT (-75.16304190105227 39.96427495800303)
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN

# %%
# import license data
license = licenses.CommercialActivityLicenses.download()

# %%
license.head()
# Out:
#   license_num            issue_date license_status  \
# 0      188053  1990-01-01T00:00:00Z         Active
# 1      058781  1990-01-12T00:00:00Z         Active
# 2      057406  1990-01-23T00:00:00Z         Active
# 3      332055  1990-02-08T00:00:00Z         Active
# 4      188058  1990-12-31T00:00:00Z         Active
#
#                      company_name
# 0  BIRMINGHAM FIRE INS CO OF PA T
# 1            CLAYMAN EDWARD P ESQ
# 2                     BRENNAN J F
# 3            TASTY BAKING COMPANY
# 4               MAGARGEE BROS INC

# %%
mini_registry = registry[:5]

# %%
# clean company_name and dba_name of clean datasets
ignore = ['inc', 'group', 'llc', 'corp', 'pc', 'incorporated', 'ltd']
registry = skool.clean_strings(registry, ['company_name', 'dba_name'], True, ignore)
license = skool.clean_strings(license, ['company_name'], True, ignore)

# %%
from ftfy import fix_text
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-def075cbfbcf> in <module>
# ----> 1 from ftfy import fix_text
#
# ModuleNotFoundError: No module named 'ftfy'

# %%
import re

def ngrams(string, n=3):
    string = re.sub(r'[,-./]|\sBD',r'', string)
    ngrams = zip(*[string[i:] for i in range(n)])
    return [''.join(ngram) for ngram in ngrams]

# %%
ngrams(registry['company_name'].iloc[0])
# Out:
# ['119',
#  '19 ',
#  '9 d',
#  ' de',
#  'deg',
#  'egr',
#  'gre',
#  'ree',
#  'ees',
#  'es ',
#  's a',
#  ' ar',
#  'arc',
#  'rch',
#  'chi',
#  'hit',
#  'ite',
#  'tec',
#  'ect',
#  'cts']

# %%
from scipy.sparse import csr_matrix
import sparse_dot_topn.sparse_dot_topn as ct

# %%
def awesome_cossim_top(A, B, ntop, lower_bound=0):
    # force A and B as a CSR matrix.
    # If they have already been CSR, there is no overhead
    A = A.tocsr()
    B = B.tocsr()
    M, _ = A.shape
    _, N = B.shape
 
    idx_dtype = np.int32
 
    nnz_max = M*ntop
 
    indptr = np.zeros(M+1, dtype=idx_dtype)
    indices = np.zeros(nnz_max, dtype=idx_dtype)
    data = np.zeros(nnz_max, dtype=A.dtype)

    ct.sparse_dot_topn(
        M, N, np.asarray(A.indptr, dtype=idx_dtype),
        np.asarray(A.indices, dtype=idx_dtype),
        A.data,
        np.asarray(B.indptr, dtype=idx_dtype),
        np.asarray(B.indices, dtype=idx_dtype),
        B.data,
        ntop,
        lower_bound,
        indptr, indices, data)

    return csr_matrix((data,indices,indptr),shape=(M,N))

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

company_names = registry['company_name'].iloc[:10]
vectorizer = TfidfVectorizer(min_df=1, analyzer=ngrams)
tf_idf_matrix = vectorizer.fit_transform(company_names)

# %%
tf_idf_matrix
# Out:
# <10x124 sparse matrix of type '<class 'numpy.float64'>'
# 	with 126 stored elements in Compressed Sparse Row format>

# %%
def get_matches_df(sparse_matrix, name_vector, top=100):
    non_zeros = sparse_matrix.nonzero()
    
    sparserows = non_zeros[0]
    sparsecols = non_zeros[1]
    
    if top:
        nr_matches = top
    else:
        nr_matches = sparsecols.size
    
    left_side = np.empty([nr_matches], dtype=object)
    right_side = np.empty([nr_matches], dtype=object)
    similairity = np.zeros(nr_matches)
    
    for index in range(0, nr_matches):
        left_side[index] = name_vector[sparserows[index]]
        right_side[index] = name_vector[sparsecols[index]]
        similairity[index] = sparse_matrix.data[index]
    
    return pd.DataFrame({'left_side': left_side,
                          'right_side': right_side,
                           'similairity': similairity})

# %%
all_company_names = pd.concat([registry['company_name'].dropna(), license['company_name'].dropna()]).unique()

# %%
len(all_company_names)
# Out:
# 196349

# %%
vectorizer = TfidfVectorizer(min_df=1, analyzer=ngrams)
tf_idf_matrix = vectorizer.fit_transform(all_company_names)

# %%
import time
t1 = time.time()
matches = awesome_cossim_top(tf_idf_matrix, tf_idf_matrix.transpose(), 10, 0.85)
t = time.time()-t1
print("SELFTIMED:", t)
# Out:
# SELFTIMED: 86.46712231636047

# %%
matches
# Out:
# <196349x196349 sparse matrix of type '<class 'numpy.float64'>'
# 	with 213835 stored elements in Compressed Sparse Row format>

# %%
def get_matches_df(sparse_matrix, name_vector, top=100):
    non_zeros = sparse_matrix.nonzero()
    
    sparserows = non_zeros[0]
    sparsecols = non_zeros[1]
    
    if top:
        nr_matches = top
    else:
        nr_matches = sparsecols.size
    
    left_side = np.empty([nr_matches], dtype=object)
    right_side = np.empty([nr_matches], dtype=object)
    similairity = np.zeros(nr_matches)
    
    for index in range(0, nr_matches):
        left_side[index] = name_vector[sparserows[index]]
        right_side[index] = name_vector[sparsecols[index]]
        similairity[index] = sparse_matrix.data[index]
    
    return pd.DataFrame({'left_side': left_side,
                          'right_side': right_side,
                           'similarity': similairity})

# %%
matches_df = get_matches_df(matches, all_company_names, top=100000)

# %%
pd.options.display.max_rows = 999

# %%
matches_df.loc[(matches_df['similairity'] < 0.99999) & (matches_df['similairity'] > 0.94)]
# Out:
#                                       left_side  \
# 7                     24 hour cleaning services
# 22                   a c environmental services
# 62                          abc construction co
# 78        accord mechanical management services
# 120        advantage building facility services
# 134                 affordable office furniture
# 160                       al engineering design
# 180              allegheny fabricating supplies
# 208                               amc associate
# 225                   american renewable energy
# 227                american renewable energy pa
# 456                      blaze building service
# 461              blue light welding fabricating
# 531                                 btn service
# 555                              c baldwin sons
# 617                     castleoak securities lp
# 875                         darrel r roopnarain
# 887                dawn underground engineering
# 928             dewitt heating air conditioning
# 942                          digital innovation
# 1000          dubose printing business services
# 1100                             em enterprises
# 1117                    endeavor investigations
# 1205                   financial realty service
# 1227                      flex e communications
# 1243     franklin construction project managers
# 1248                    fred gross construction
# 1266                 g c environmental services
# 1302          general excavating and demolition
# 1346                 gmf interior installations
# 1474            hoon ho oh builders contractors
# 1530                    infinity hardwood floor
# 1569     integrity cleaning janitorial services
# 1576            international pioneer marketing
# 1579                international waste service
# 1643                           jag expansion lp
# 1898   locating utility infrastructure services
# 1915                              lrw solutions
# 1960          maddox behavioral health services
# 1988                        mangual excavations
# 2031   mathews nielsen landscape architects p c
# 2108                        minute construction
# 2184                    n f general contractors
# 2228                       new age distributors
# 2230                              new beginning
# 2252                     north american roofers
# 2284     oakley commercial flooring contractors
# 2323                orlando espinosa associates
# 2370                    patrick paul enterprise
# 2404          perfect image cartridge solutions
# 2459                             pmh enterprise
# 2468          polatnick zacharjasz architecture
# 2494            preservation design partnership
# 2506             princeton engineering services
# 2572                     r r general contractor
# 2601                           ramy enterprises
# 2636               resilient business solutions
# 2648      reyna information technology services
# 2657               richard grubb and associates
# 2784             scotlandyard security services
# 2840                sioutis coatings enterprise
# 2883                south jersey paper products
# 2911               star bright cleaning service
# 2993         sylvester cheatham home remodeling
# 3201                             tomar trucking
# 3209                    torrado construction co
# 3280                          u s plate mirrors
# 3286                   ultimate hardwood floors
# 3369                          virgo investments
# 3434                          williams electric
# 3645                            elliott elliott
# 3711                      terry construction co
# 3733                     eastwick joint venture
# 3747                             5337 jefferson
# 3886                               j p brothers
# 4176                        lindenmeyr paper co
# 4425                b c reliable towing service
# 4442                          byzantine holding
# 4534                         salaam enterprises
# 4586                     metric construction co
# 4605                          costello costello
# 4786                 chestnut hill ob gyn assoc
# 4795                         dougherty electric
# 4820                           linda s fashions
# 4834                        house of winsome ii
# 4851                 fred gross construction co
# 4870                             k beauty salon
# 5022                       center city hardware
# 5054                 liberty business credit co
# 5326              cottman beverage distributors
# 5427                      remington products co
# 5608                                walnut nail
# 5829                           eagle enterprise
# 5864                        tap pharmaceuticals
# 5946                            amy enterprises
# 5948                       house of winsome iii
# 5962                        oxford health plans
# 5974                   1604 chestnut associates
# 6055                           leo mall markets
# 6062            stanton stanton construction co
# 6070                     ffe maplewood cliveden
# 6473                    lage lage t a lage lage
# 6479                 lawrence street seafood co
# 6913                     oxford health plans pa
# 6973                     philly sportswear kids
# 7125              dugan brinkmann maginnis pace
# 7220                      mitchell construction
# 7422                            cohen jeffrey l
# 7661                            j p development
# 7753             congressional construction cor
# 8190                    precision aerial survey
# 8314                           scoggins evadney
# 8619                      borek construction co
# 8933       phila clef club of performing arts i
# 10063                 general vascular surgical
# 10262                      pediatric adolescent
# 10288                    thrifty scott beverage
# 10434                          abbs enterprises
# 10744                       berwind aviation co
# 10822                                     silco
# 11067                  hamilton construction co
# 11182                  jardines de borinquen ii
# 11521                   medical broadcasting co
# 11830                         don s auto repair
# 12061            preservation design partnershi
# 12076                     woods construction co
# 12289                                 rios deli
# 12485              cottman beverage distributor
# 12586                     barrington associates
# 12604                     spiezle architectural
# 12641                    certified environments
# 12654                   environmental resources
# 12655                   environmental resources
# 12668                    american demolition co
# 12674                           dong van nguyen
# 12814                  b c reliable towing serv
# 13094        accord mechanical management servi
# 13317                 the dynamic compaction co
# 13380                           fiesta pizza ii
# 13561                          tims enterprises
# 13649                practical healthcare solut
# 13690                    modern construction co
# 13795                        madison leasing co
# 13850                  mitchell construction co
# 13994                        edward i friedland
# 14137                              construction
# 14435                   certified environmental
# 14448                   premier design builders
# 14660                         eagle enterprises
# 14943              americore drilling sawcuttin
# 15058                      american wholesalers
# 15357                  nextlink pennsylvania lp
# 15465                       bradley bradley ent
# 15525                     a a cleaning services
# 15619                 j g wentworth partners lp
# 15622                    j g wentworth partners
# 15672                jackson cross associates i
# 15746                           taylor george l
# 15812                       r and a auto repair
# 16353                     rycon construction co
# 16495              e j heating air conditioning
# 16565                delawre grp equity fnds iv
# 16571                delawre grp equity fnds ii
# 16692                          dekap properties
# 16733                    despatch industries lp
# 16754                           pmh enterprises
# 17366                power plant productions lp
# 17489                   circus time kiddie ride
# 17741                       c j construction co
# 17814                  pediatric and adolescent
# 17817              perfect image cartridge solu
# 17917                         griff enterprises
# 18234                 cultural studies analysis
# 18323             independence center realty lp
# 18769                                   chadama
# 18905                                  costello
# 19127                           daly investment
# 19758                            1442 callowhil
# 20075                           dollar crazy ii
# 20076                           dollar crazy ii
# 20253                         rodriguez grocery
# 20373                    minute construction co
# 21102                  broad street investments
# 21502                   sunrise fortune cookies
# 21688                           1442 callowhill
# 21821                      cramers kiddie shops
# 21855                        liftex corporation
# 21905                          prime investment
# 22027                  24 hour cleaning service
# 22106                  walnut street investment
# 22135                 walnut street investments
# 22532                             cramco realty
# 22693                  environmental management
# 22713                    in style salon and spa
# 22890                   ostrobrod and ostrobrod
# 23007                 mamsi insurance resources
# 23028                  mamsi insurance resource
# 23313                global technology solution
# 23395                       stagliano michael a
# 23561                           goldrich harvey
# 23904                                     torco
# 24123                         maria enterprises
# 24155                          schultz williams
# 24279                   barnes noble bookstores
# 24345                        engineering design
# 24511                           ims enterprises
# 24686                     brugar enterprises lp
# 24698                         south philly nail
# 24789              accelerated collateral recov
# 24881                   galaxy amusement center
# 24897                haines automotive services
# 24900                    drummond associates lp
# 24909               sarah allen community homes
# 24950                    ipnosi construction co
# 25240             liberty property philadelphia
# 25366                         a plus appliances
# 25460                       girard furniture co
# 25546                         nerak enterprises
# 25637                      fairmount properties
# 25825                       usa parking systems
# 26021                      medical broadcasting
# 26203                            tropical nails
# 26480          crown two penn center associates
# 26481          crown two penn center associates
# 26917                     nextlink pennsylvania
# 27012                       mc donough thomas f
# 27163             churchview common condo assoc
# 27196                         dunleavy thomas j
# 27227               chestnut hill ob gyn assocs
# 27341                       alpha card services
# 27728                        ditman investments
# 28163                 tro avenue of the arts lp
# 28247                  fountain street partners
# 28322                       ritz camera centers
# 28425                         murphy roofing co
# 28542                    the dynamic compaction
# 28712           goddess art and antique gallery
# 29298                            a k investment
# 29409                 five star construction co
# 29463                 sansom street restaurants
# 29773              hoon ho oh builders contract
# 29850                         howard and howard
# 29888                          dollar crazy iii
# 29967                      delaware valley rest
# 30373                           smith elizabeth
# 30374                           smith elizabeth
# 30871                           l s contractors
# 30940                     first vehicle service
# 31009                  equity partners fund vii
# 31333                            a j auto parts
# 31513                          abc construction
# 31574                 705 717 pine street assoc
# 31762                           dollar crazy iv
# 31830                       ralston restoration
# 31885              franklin villa apartments lp
# 31970                           sph investments
# 32123                    key investment prop ii
# 32278                             howard howard
# 32352                       salaman law offices
# 32391                hanlan midgette scriven lp
# 32548              international pioneer market
# 32554                 garrett business services
# 32619                            dollar crazy v
# 32942              distinct destinations travel
# 33116                            dollar crazy i
# 33117                            dollar crazy i
# 33199                 great american leasing co
# 33276                         ele international
# 33295                            american tower
# 33340                                     demco
# 33447                   key investment prop iii
# 33490                          fiesta pizza iii
# 33564                frontier warehouse funding
# 33567                  british imperial cleaner
# 33578                       frontier funding ii
# 33587                           gold galore iii
# 33609                                   nolters
# 33714               remington vernick engineers
# 33734             robert nicoletti family trust
# 33741            practical healthcare solutions
# 33934                           ljr investments
# 33974                               new horizon
# 34163                            cherry fashion
# 34198                          landvest llp iii
# 34200                           landvest llp ii
# 34310                       style salon and spa
# 34319             five star property management
# 34520                       phoenix investments
# 34607                     mayflower bakery cafe
# 34800                      a m berk tax service
# 34829                hanson general contracting
# 35316                       dekap properties lp
# 35846            6935 n 15th street holdings lp
# 35900                              walnut nails
# 36295                              neff drugs 2
# 36363                  philly s sportswear kids
# 36473                           ladoux lucien m
# 36511                        1507 walnut street
# 36522                          le international
# 36629                  bondresource partners lp
# 36645                     1627 walnut street lp
# 36671                   ark asset management co
# 36829                holly wood ii construction
# 36944                       house of beauty iii
# 37047                                kraftworks
# 37076                   boulevard apartments lp
# 37316                ripple effects interactive
# 37397                  precision aerial surveys
# 37899                           shobha mehta md
# 37982                  center south housing dev
# 38044                             pa capital lp
# 38237                  hylan datacom electrical
# 38582                    frank clements taverns
# 38606                           cigarette cigar
# 38808                princeton engineering serv
# 38905                  brown family enterprises
# 38913                           modern classics
# 39376          neighborhood restorations lp xii
# 39377          neighborhood restorations lp xii
# 39393           neighborhood restorations lp xi
# 39394           neighborhood restorations lp xi
# 39439                        american wholesale
# 39513                   dp lipson properties lp
# 39593                        spencer enterprise
# 39598                        harr properties ii
# 39607                       harr properties iii
# 39633                          829 n 29th st lp
# 39687                           leo mall market
# 39716                voltage electrical service
# 39756                       sunbeam enterprises
# 39919               voice of victory publishing
# 39924                           autobahn motors
# 39955                        good food partners
# 40110                   central electric supply
# 40162                       temperature control
# 40217                       wishing well market
# 40381                accelerated collateral rec
# 40437                     bag property mgmt iii
# 40761                           rak enterprises
# 40882               bell howell asset placement
# 41194                                 nam kee h
# 41298                    main street restaurant
# 41401                     1507 walnut street lp
# 41563                      hometown investments
# 41578                   main street restaurants
# 41599                     lyons construction co
# 41709                           amm enterprises
# 42257                   port richmond dev ii lp
# 42338                   rapha foot ankle center
# 42378                           don giovanni ii
# 42409                     creative hairdressers
# 42426                        trinity investment
# 42666                      east west connection
# 42825                          eli anderson son
# 42867                 kevin mcginn plumbing and
# 43066                   vasiliades family lp iv
# 43067                   vasiliades family lp iv
# 43071                  vasiliades family lp iii
# 43072                  vasiliades family lp iii
# 43101                   vasiliades family lp ii
# 43102                   vasiliades family lp ii
# 43103                   vasiliades family lp ii
# 43105                    vasiliades family lp i
# 43106                    vasiliades family lp i
# 43107                    vasiliades family lp i
# 43113                             ne management
# 43203                           junes breakfast
# 43361                 m m professional cleaning
# 43721                        cigarette cigar ii
# 43781                           bard associates
# 43906                             crosby crosby
# 43921                ranson general contracting
# 44153                    creek view partners lp
# 44155                     baxter ii partnership
# 44162                    baxter iii partnership
# 44184                         elite enterprises
# 44269                           dollar crazy vi
# 44281                national building facility
# 44367                         downtown equities
# 44369                      downtown equities ii
# 44391                      boulevard apartments
# 44681         neighborhood restorations lp xvii
# 44815            ripple effects interactive phi
# 44827                                    crosby
# 45202                      cobbs creek property
# 45969            marvin waxman consulting engin
# 46211                   equity partners fund vi
# 46248            international financial compan
# 46531                    johns custom stairways
# 46589                   joyce j sweinberg assoc
# 46948                           friedman steven
# 47110                        leighton barbara m
# 47328                           campbell dennis
# 47354                           tong van nguyen
# 47424                       spencer enterprises
# 47655                   lanum metal products co
# 47679                  hillman environmental co
# 47979               miller building partners lp
# 48120                      rcn telecom services
# 48162                 athletes international co
# 48589                           myers stephen a
# 48721                  circus time kiddie rides
# 48772                        remington products
# 49081                       fellheimer eichen k
# 49168                             alvarez janet
# 49178            huntingdon mechanical contract
# 49364                         saunders patricia
# 49404                           thomas thomas c
# 49405                           thomas thomas c
# 49550                     national collision co
# 49601                            ahlzadeh david
# 49764                              van t nguyen
# 49883                       cliftex corporation
# 50570                       metric construction
# 50642                brandywine enviromental co
# 50675                  liberty mutual insurance
# 50710                       koltsaklis theodore
# 50742                        woloshin michael a
# 50769                  1904 08 spring garden st
# 50824                            amoroso robert
# 51222                        dillon christine l
# 51441                          robinson james l
# 51470                          dillon christine
# 51505                      wishing well markets
# 51550                             boyle james a
# 51748                           crawford robert
# 51784                           acosta claire r
# 51810                       saunders patricia a
# 51991                                baik kon h
# 52109                           cohen jeffrey a
# 52208                                kim yang h
# 52226                      creative hairdresser
# 52287                       crankshaw william a
# 52409              grant meadows associates l p
# 52492                           cherry fashions
# 52647                           a k enterprises
# 52711                       quagliariello rocco
# 53014                           skubin robert l
# 53185                            brooks charles
# 53217             franklin villa apartments l p
# 53231                               boyle james
# 54046                     evangelisto gilbert j
# 54268                  walnut towers associates
# 54715                          presti salvatore
# 54924                              gray bernard
# 55271                  galaxy amusement centers
# 55419                         smith elizabeth a
# 56336                      real estate resource
# 56386                   tyco valves controls lp
# 56422                           k r enterprises
# 56503                                    silcon
# 56766                              pappas chris
# 57131            ashton village chiropractic he
# 57163                      lanum metal products
# 57270            touch of class goodies gift in
# 57287                        tap pharmaceutical
# 57373                                  cugginis
# 57521                       drummond associates
# 57963                    wm a j shaeffer s sons
# 57973                                     rebel
# 58017            education party of philadelphi
# 58160                      frontier funding iii
# 58284                      academy plaza assocs
# 58288                              smith barton
# 58368                        borek construction
# 58563                 south twelfth partnership
# 58696                              lrw solution
# 58841            northwestern management servic
# 58853                            modern classic
# 58970                          star enterprises
# 59275                            thomas charles
# 59531                               ross samuel
# 59689                    stouffer restaurant co
# 59851                        g g shops of penna
# 59860                          mc intyre john f
# 59912                  pavilion drainage supply
# 60060                              cohen steven
# 60101                           schultz william
# 60187                                rice david
# 60340                      allied mercantile co
# 60476                     m fedele construction
# 60646                               kim yang ho
# 60749                        ritz camera center
# 60805                           star enterprise
# 60903                                kim sang j
# 60933                            brocco anthony
# 61092                          brooks charles e
# 61570                          shobha mehta m d
# 61736                          1510 chestnut st
# 61838                     johns custom stairway
# 61895                                  corticon
# 61929                center city podiatry assoc
# 62003                         thomas william jr
# 62071                        barco construction
# 62162                          reiver kenneth s
# 62523                           snyder robert c
# 62581                       stouffer restaurant
# 62783                     edward i friedland co
# 62800                            welsh james jr
# 62802                             welsh james j
# 62904                          leighton barbara
# 62983                              man t nguyen
# 63139                           dunleavy thomas
# 63295                          thomas william j
# 63530                              williams dan
# 63542                   pulmonary disease assoc
# 63620                             snyder robert
# 63937                              gross samuel
# 64056                                   cortico
# 64206                           palumbo stephen
# 64359                       chava madhusudhan r
# 64397                    athletes international
# 64458                           schwartz lenore
# 64474                     quagliariello rocco m
# 64517                    custom construction co
# 64662                                   conston
# 64947                     chava madhusudhan rao
# 65155                     united parcel service
# 65340                            march herman c
# 65375                    colonial security serv
# 65446                            peterson james
# 65563                     flynn construction co
# 65770                         jarema elfriede f
# 65912                            lee kwang sook
# 66292                      atlantic maintenance
# 66393                        presti salvatore j
# 66825                         mc erlean james a
# 66880                       gallagher richard p
# 67278                        cabahug teresita j
# 67479                       target food systems
# 67576                         goldstein glenn a
# 68001                        byzantine holdings
# 68056                           shields james l
# 68071                       gallagher richard a
# 68125                                 kim kyung
# 68221                            kunze albert l
# 68223                          peterson james a
# 68226                             lee kwang soo
# 68525                         campbell dennis a
# 68537                         smith elizabeth m
# 68595                         bradley joseph jr
# 68602                          williams irene s
# 69071                         goldrich harvey j
# 69304                       dombrowski joseph c
# 69366                            foschini vince
# 69379                       waddington robert c
# 69408                 world apparel products co
# 69566                       berkowitz berkowitz
# 69581                             taylor george
# 70413                         dombrowski joseph
# 70765                            l natural food
# 70848                          mc carthy dennis
# 71396                            robinson james
# 71532                        corsetti vincent s
# 71641                          pfeffer mitchell
# 71868                         darrel roopnarain
# 71986                          gibson charles f
# 72022                        target food system
# 72091                             myers stephen
# 72223                          bradley joseph j
# 72295                    world apparel products
# 72524                       alliance enterprise
# 72620                        braunstein estelle
# 73207                              march herman
# 73228                        ruggeri nicholas c
# 73249                      alliance enterprises
# 73476                     allegheny real estate
# 73907                               peoples son
# 74472                        bernstein robert s
# 74779                        mc devitt thomas f
# 74817                       academy plaza assoc
# 74907                   corrado construction co
# 75127                          ruggeri nicholas
# 75237                        schwartz stephen a
# 75497                      yu hsiang garden iii
# 75731                      rittenhouse claridge
# 75982                         harris lawrence c
# 76043                         blockbuster video
# 76390                        pfeffer mitchell e
# 76504                 environmental resource co
# 76505                 environmental resource co
# 76822                          woloshin michael
# 77245                            snyder bruce c
# 77539                              snyder bruce
# 77606                      u s cleaning service
# 77875                           thomas thomas p
# 77876                           thomas thomas p
# 78073                       waddington robert m
# 78159                       cramers kiddie shop
# 78222                       evangelisto gilbert
# 78324                      premier design build
# 78410                        corsetti vincent b
# 78458                            csuha ronald s
# 78581                           aguirre jorge m
# 78682                      m cardone industries
# 78746                     delaware valley restr
# 78997                            cohen steven m
# 79118                         a m berk tax serv
# 79247                               brown louis
# 79662                        tilghman anthony w
# 79665                           shields james p
# 79723                           5337 jeffersons
# 79769                    barnes noble bookstore
# 79811                        1327 n 60th street
# 79832                               ray bernard
# 80034                         allied mercantile
# 80072                        the renfrew center
# 80159                           l natural foods
# 80496                        phoenix investment
# 80557                                    harper
# 80679                          mc devitt thomas
# 80682                        ahlzadeh david and
# 80744                             stran son van
# 80759                      american concrete co
# 80796                     kevin mcginn plumbing
# 80911                             super sneaker
# 81249                         nguyen william au
# 81421                          mc intyre john j
# 81476                                 callaghan
# 81603                          williams irene c
# 81794                           w c enterprises
# 81816                wayne avenue associates lp
# 82062                             skubin robert
# 82099                           jarema elfriede
# 82211                         gelco corporation
# 82826                          williams richard
# 83266                       salt pepper deli ii
# 83424                               kim sang jo
# 83518                      koltsaklis theodoros
# 83669                                nam kee ho
# 83708                               kim kyung s
# 84168                        juniper properties
# 84259                              tran son van
# 84529                         sonex corporation
# 84670                        goldstein lester a
# 85176                congressional construction
# 85352                          landscape design
# 85629                    south twelfth partners
# 85636                             acosta claire
# 85672                  diversified historic inv
# 85731                  jackson cross associates
# 85770                        brugar enterprises
# 85961                           alvarez janet l
# 86081                           martinez juan a
# 86093                          cabahug teresita
# 86121                             thomas thomas
# 86122                             thomas thomas
# 86301                     hamilton construction
# 86514                             chair factory
# 86764              joyce j sweinberg associates
# 87082                      urban engineering co
# 87169                           mc erlean james
# 87242                          nguyen william a
# 87314                            super sneakers
# 87353                            smith barton s
# 87365                             martinez juan
# 87586                         schwartz lenore e
# 87612                    environmental resource
# 87613                    environmental resource
# 87617                   liberty business credit
# 87909                central electric supply co
# 88127                            b k mechanical
# 88226                             rocco anthony
# 88503                    father son shoe stores
# 88505                 father son shoe stores co
# 88654                          tilghman anthony
# 89135                         stagliano michael
# 89554                      midlantic restaurant
# 89561                      braunstein estelle s
# 89716                           goldstein glenn
# 89748                             pappas christ
# 89849                         mc donough thomas
# 89864                       sparc environmental
# 90073                        scoggins evadney m
# 90079                            1327 n 60th st
# 90126                                   salmons
# 90199                           fischer douglas
# 90653                      salt pepper deli iii
# 90680                         g g shops of penn
# 90737                             kivitz norman
# 91023              us bank national association
# 91098                         palumbo stephen r
# 91114                 5601 chestnut partners lp
# 91151                           cambridge ii lp
# 91202                  pulmonary disease assocs
# 91234                   atlantic maintenance pa
# 91245                   allegheny real estate i
# 91814                        mc carthy dennis m
# 91818                             aguirre jorge
# 91856                             es industries
# 92061                 ccp leasing associates ii
# 92728              universal building construct
# 92922                    santos construction co
# 92981             reyes real estate corporation
# 93166                            drc investment
# 93260                        usa parking system
# 93357                              tps ii of pa
# 93488                       ostrobrod ostrobrod
# 93507                          bernstein robert
# 93604              general vascular surgical gr
# 93688                         bassetti edmond f
# 93851                   cobbs creek property lp
# 93913                  professional health serv
# 94028                             nutri systems
# 94035             6935 n 15th street holdings l
# 94079                        salaman law office
# 94108                         crankshaw william
# 94197                          berwind aviation
# 94214                            gibson charles
# 94227                   brandywine enviromental
# 94479                          lindenmeyr paper
# 94610                  paul schure limited part
# 94630               fox rehabilitation services
# 94694                        pain relief center
# 94707                          a plus appliance
# 94720                              brown louise
# 94869                         eli anderson sons
# 94875            mantua community vector contro
# 94903                       3175 jfk associates
# 94921                         ditman investment
# 94939                          schwartz larry j
# 94945                                  constons
# 95185                  m fedele construction co
# 95470                            schwartz larry
# 95923                         harris lawrence r
# 96169                engel air conditioning cor
# 96196                        alpha card service
# 96417                              land holding
# 96420              cultural studies analysis in
# 96556                 sansom precious metals co
# 96612                     midlantic restaurants
# 96817                diversified historic inves
# 96861            rittenhouse grill associates l
# 97140                          amoroso robert s
# 97337                  kosciuszko literary assn
# 97389                               price david
# 97594              law offices of christy adams
# 97595              law offices of christy adams
# 97671            rebuildables property acquisit
# 97703                   center city hardware co
# 97845                  miller building partners
# 98136                               baik kon ho
# 98152                        schwartz stephen f
# 98156            center city podiatry associate
# 98167                           bassetti edmond
# 98428                            baker margaret
# 98529                            j m enterprise
# 98541                    5601 chestnut partners
# 98543                           a k investments
# 98559                          baker margaret a
# 98948                          foschini vincent
# 99092                             cable connect
# 99321                              csuha ronald
# 99358                             tps iii of pa
# 99521                      pain relief center i
# 99559                       lanard and axilbund
# 99648                     fe maplewood cliveden
# 99839                center city real estate co
# 99899                              nutri system
# 99922                          daly investments
#
#                                   right_side  similairity
# 7                   24 hour cleaning service     0.984544
# 22                g c environmental services     0.956803
# 62                          abc construction     0.943583
# 78        accord mechanical management servi     0.967137
# 120      advantage building facility service     0.990050
# 134           affordable office furniture in     0.963825
# 160                       engineering design     0.940081
# 180             allegheny fabricating suppli     0.968917
# 208                           amc associates     0.967131
# 225             american renewable energy pa     0.944017
# 227                american renewable energy     0.944017
# 456                  blaze building services     0.983746
# 461             blue light welding fabricati     0.983964
# 531                             btn services     0.971739
# 555                            c baldwin son     0.982040
# 617                 castleoak securities l p     0.950230
# 875                        darrel roopnarain     0.951380
# 887           dawn underground engineering i     0.971188
# 928      dewitt heating and air conditioning     0.955963
# 942                      digital innovations     0.987185
# 1000           dubose printing business serv     0.958433
# 1100                         gem enterprises     0.957427
# 1117              endeavor investigations co     0.962155
# 1205               financial realty services     0.981207
# 1227                    flex e communication     0.987459
# 1243   franklin construction project manager     0.991159
# 1248              fred gross construction co     0.959398
# 1266              a c environmental services     0.956803
# 1302          general excavating and demolit     0.969568
# 1346               gmf interior installation     0.991084
# 1474            hoon ho oh builders contract     0.957234
# 1530                infinity hardwood floors     0.982494
# 1569   integrity cleaning janitorial service     0.990383
# 1576            international pioneer market     0.950670
# 1579            international waste services     0.982940
# 1643                           jag expansion     0.942832
# 1898    locating utility infrastructure serv     0.968170
# 1915                            lrw solution     0.984396
# 1960          maddox behavioral health servi     0.976301
# 1988                      mangual excavation     0.988316
# 2031    mathews nielsen landscape architects     0.952479
# 2108                  minute construction co     0.949810
# 2184                  n f general contractor     0.975230
# 2228                     new age distributor     0.976032
# 2230                          new beginnings     0.968081
# 2252                   north american roofer     0.985646
# 2284    oakley comercial flooring contractor     0.941106
# 2323         orlando espinosa and associates     0.953800
# 2370                patrick paul enterprises     0.977244
# 2404            perfect image cartridge solu     0.953082
# 2459                         pmh enterprises     0.970087
# 2468         polatnick zacharjasz architects     0.952985
# 2494          preservation design partnershi     0.975157
# 2506              princeton engineering serv     0.953759
# 2572                 r r general contractors     0.974085
# 2601                         amy enterprises     0.952533
# 2636          resilient business solutions l     0.967041
# 2648    reyna information technology service     0.990914
# 2657                richard grubb associates     0.943867
# 2784              scotlandyard security sers     0.942853
# 2840            sioutis coatings enterprises     0.981321
# 2883          south jersey paper products in     0.954178
# 2911           star bright cleaning services     0.985806
# 2993          sylvester cheatham home remode     0.955595
# 3201                           omar trucking     0.945302
# 3209                 corrado construction co     0.955948
# 3280                    u s plate mirrors co     0.954112
# 3286                 ultimate hardwood floor     0.981673
# 3369                        virgo investment     0.972770
# 3434                      williams electrica     0.976315
# 3645                          elliott elliot     0.978696
# 3711                   berry construction co     0.954485
# 3733                eastwick joint venture v     0.959495
# 3747                         5337 jeffersons     0.989619
# 3886                             j p brother     0.974881
# 4176                        lindenmeyr paper     0.965708
# 4425                b c reliable towing serv     0.963085
# 4442                      byzantine holdings     0.975787
# 4534                       salaam enterprise     0.974592
# 4586                     metric construction     0.946373
# 4605                                costello     0.952843
# 4786             chestnut hill ob gyn assocs     0.970316
# 4795                     dougherty electrics     0.964402
# 4820                        minda s fashions     0.941681
# 4834                    house of winsome iii     0.962458
# 4851                 fred gross construction     0.959398
# 4870                         ok beauty salon     0.944946
# 5022                 center city hardware co     0.950616
# 5054                 liberty business credit     0.947193
# 5326            cottman beverage distributor     0.984401
# 5427                      remington products     0.940758
# 5608                            walnut nails     0.944606
# 5829                       eagle enterprises     0.966925
# 5864                      tap pharmaceutical     0.970377
# 5946                        ramy enterprises     0.952533
# 5948                     house of winsome ii     0.962458
# 5962                  oxford health plans pa     0.943377
# 5974             1604 chestnut associates lp     0.962633
# 6055                         leo mall market     0.945439
# 6062            stanton stanton construction     0.979100
# 6070                   fe maplewood cliveden     0.973540
# 6473                               lage lage     0.944255
# 6479                 lawrence street seafood     0.951143
# 6913                     oxford health plans     0.943377
# 6973                philly s sportswear kids     0.968408
# 7125            dugan brinkmann maginnis pac     0.983853
# 7220                mitchell construction co     0.953196
# 7422                           cohen jeffrey     0.940802
# 7661                        j p developments     0.969825
# 7753              congressional construction     0.947437
# 8190                precision aerial surveys     0.969747
# 8314                      scoggins evadney m     0.964337
# 8619                      borek construction     0.951720
# 8933      phila clef club of performing arts     0.976327
# 10063           general vascular surgical gr     0.954630
# 10262               pediatric and adolescent     0.940102
# 10288                thrifty scott beverages     0.965219
# 10434                      habbs enterprises     0.945521
# 10744                       berwind aviation     0.953230
# 10822                                 silcon     0.962716
# 11067                  hamilton construction     0.964000
# 11182                  jardines de borinquen     0.944146
# 11521                   medical broadcasting     0.960369
# 11830                        n s auto repair     0.942744
# 12061        preservation design partnership     0.975157
# 12076                     woods construction     0.943342
# 12289                             trios deli     0.952914
# 12485          cottman beverage distributors     0.984401
# 12586                  harrington associates     0.943500
# 12604               spiezle architectural in     0.960079
# 12641                certified environmental     0.943756
# 12654                 environmental resource     0.984715
# 12655              environmental resource co     0.946559
# 12668                    american demolition     0.955410
# 12674                        tong van nguyen     0.947552
# 12814            b c reliable towing service     0.963085
# 13094  accord mechanical management services     0.967137
# 13317                 the dynamic compaction     0.967714
# 13380                       fiesta pizza iii     0.951790
# 13561                        ims enterprises     0.941830
# 13649         practical healthcare solutions     0.956247
# 13690                    modern construction     0.955067
# 13795                        madison leasing     0.941457
# 13850                  mitchell construction     0.953196
# 13994                  edward i friedland co     0.957557
# 14137                            onstruction     0.956574
# 14435                 certified environments     0.943756
# 14448                   premier design build     0.941344
# 14660                       eagle enterprise     0.966925
# 14943          americore drilling sawcutting     0.994963
# 15058                     american wholesale     0.957543
# 15357                  nextlink pennsylvania     0.955137
# ...
# 62162                         reiver kenneth     0.949997
# 62523                          snyder robert     0.941359
# 62581                 stouffer restaurant co     0.955272
# 62783                     edward i friedland     0.957557
# 62800                          welsh james j     0.960914
# 62802                         welsh james jr     0.960914
# 62904                     leighton barbara m     0.947803
# 62983                           van t nguyen     0.943510
# 63139                      dunleavy thomas j     0.949468
# 63295                      thomas william jr     0.962896
# 63530                          williams dana     0.962458
# 63542               pulmonary disease assocs     0.960329
# 63620                        snyder robert c     0.941359
# 63937                            ross samuel     0.952563
# 64056                               corticon     0.955044
# 64206                      palumbo stephen r     0.955483
# 64359                  chava madhusudhan rao     0.941293
# 64397              athletes international co     0.958074
# 64458                      schwartz lenore e     0.952539
# 64474                    quagliariello rocco     0.952455
# 64517                    custom construction     0.948877
# 64662                               constons     0.955319
# 64947                    chava madhusudhan r     0.941293
# 65155               united parcel service co     0.950486
# 65340                           march herman     0.940859
# 65375             colonial security services     0.944499
# 65446                       peterson james a     0.940523
# 65563                     flynn construction     0.957717
# 65770                        jarema elfriede     0.945970
# 65912                          lee kwang soo     0.958093
# 66292                atlantic maintenance pa     0.944727
# 66393                       presti salvatore     0.941612
# 66825                        mc erlean james     0.954890
# 66880                    gallagher richard a     0.940907
# 67278                       cabahug teresita     0.946093
# 67479                     target food system     0.968377
# 67576                        goldstein glenn     0.940918
# 68001                      byzantine holding     0.975787
# 68056                        shields james p     0.941918
# 68071                    gallagher richard p     0.940907
# 68125                            kim kyung s     0.947807
# 68221                           kunze albert     0.946786
# 68223                         peterson james     0.940523
# 68226                         lee kwang sook     0.958093
# 68525                        campbell dennis     0.952893
# 68537                        smith elizabeth     0.948315
# 68595                       bradley joseph j     0.968643
# 68602                       williams irene c     0.949555
# 69071                        goldrich harvey     0.941648
# 69304                      dombrowski joseph     0.944751
# 69366                       foschini vincent     0.962472
# 69379                    waddington robert m     0.947217
# 69408                 world apparel products     0.956194
# 69566                              berkowitz     0.954426
# 69581                        taylor george l     0.941608
# 70413                    dombrowski joseph c     0.944751
# 70765                        l natural foods     0.948387
# 70848                     mc carthy dennis m     0.944361
# 71396                       robinson james l     0.946042
# 71532                     corsetti vincent b     0.940448
# 71641                     pfeffer mitchell e     0.960149
# 71868                    darrel r roopnarain     0.951380
# 71986                         gibson charles     0.946207
# 72022                    target food systems     0.968377
# 72091                        myers stephen a     0.943138
# 72223                      bradley joseph jr     0.968643
# 72295              world apparel products co     0.956194
# 72524                   alliance enterprises     0.966100
# 72620                   braunstein estelle s     0.962656
# 73207                         march herman c     0.940859
# 73228                       ruggeri nicholas     0.960021
# 73249                    alliance enterprise     0.966100
# 73476                allegheny real estate i     0.957134
# 73907                           peoples sons     0.980036
# 74472                       bernstein robert     0.946601
# 74779                       mc devitt thomas     0.942375
# 74817                   academy plaza assocs     0.953130
# 74907                torrado construction co     0.955948
# 75127                     ruggeri nicholas c     0.960021
# 75237                     schwartz stephen f     0.949515
# 75497                    yu hsiang garden ii     0.970742
# 75731                rittenhouse claridge lp     0.943268
# 75982                      harris lawrence r     0.946619
# 76043                     blockbuster videos     0.942583
# 76390                       pfeffer mitchell     0.960149
# 76504                 environmental resource     0.961252
# 76505                environmental resources     0.946559
# 76822                     woloshin michael a     0.947028
# 77245                           snyder bruce     0.952567
# 77539                         snyder bruce c     0.952567
# 77606                  u s cleaning services     0.977495
# 77875                        thomas thomas c     0.963679
# 77876                          thomas thomas     0.958920
# 78073                    waddington robert c     0.947217
# 78159                   cramers kiddie shops     0.956265
# 78222                  evangelisto gilbert j     0.948189
# 78324                premier design builders     0.941344
# 78410                     corsetti vincent s     0.940448
# 78458                           csuha ronald     0.950137
# 78581                          aguirre jorge     0.949106
# 78682                     cardone industries     0.941145
# 78746                   delaware valley rest     0.985412
# 78997                           cohen steven     0.942109
# 79118                   a m berk tax service     0.955359
# 79247                           brown louise     0.965409
# 79662                       tilghman anthony     0.942113
# 79665                        shields james l     0.941918
# 79723                         5337 jefferson     0.989619
# 79769                barnes noble bookstores     0.987616
# 79811                         1327 n 60th st     0.948674
# 79832                           gray bernard     0.947789
# 80034                   allied mercantile co     0.951661
# 80072                    the renfrew centers     0.984441
# 80159                         l natural food     0.948387
# 80496                    phoenix investments     0.977827
# 80557                                harpers     0.941174
# 80679                     mc devitt thomas f     0.942375
# 80682                         ahlzadeh david     0.940768
# 80744                           tran son van     0.970154
# 80759                      american concrete     0.943678
# 80796              kevin mcginn plumbing and     0.948070
# 80911                         super sneakers     0.982297
# 81249                       nguyen william a     0.973706
# 81421                       mc intyre john f     0.940403
# 81476                callaghan and callaghan     0.941177
# 81603                       williams irene s     0.949555
# 81794                         w c enterprise     0.959616
# 81816                wayne avenue associates     0.955397
# 82062                        skubin robert l     0.943221
# 82099                      jarema elfriede f     0.945970
# 82211                       elco corporation     0.950621
# 82826                      williams richards     0.942777
# 83266                   salt pepper deli iii     0.965823
# 83424                             kim sang j     0.959234
# 83518                    koltsaklis theodore     0.943201
# 83669                              nam kee h     0.968867
# 83708                              kim kyung     0.947807
# 84168                  juniper properties lp     0.943071
# 84259                          stran son van     0.970154
# 84529                      ronex corporation     0.941459
# 84670                       goldstein lester     0.954696
# 85176         congressional construction cor     0.947437
# 85352                      landscape designs     0.948050
# 85629              south twelfth partnership     0.944211
# 85636                        acosta claire r     0.941686
# 85672             diversified historic inves     0.970890
# 85731             jackson cross associates i     0.962514
# 85770                  brugar enterprises lp     0.940391
# 85961                          alvarez janet     0.946100
# 86081                          martinez juan     0.955762
# 86093                     cabahug teresita j     0.946093
# 86121                        thomas thomas c     0.962437
# 86122                        thomas thomas p     0.958920
# 86301               hamilton construction co     0.964000
# 86514                           hair factory     0.970866
# 86764                joyce j sweinberg assoc     0.945586
# 87082                      urban engineering     0.950720
# 87169                      mc erlean james a     0.954890
# 87242                      nguyen william au     0.973706
# 87314                          super sneaker     0.982297
# 87353                           smith barton     0.949211
# 87365                        martinez juan a     0.955762
# 87586                        schwartz lenore     0.952539
# 87612                environmental resources     0.984715
# 87613              environmental resource co     0.961252
# 87617             liberty business credit co     0.947193
# 87909                central electric supply     0.950464
# 88127                        b k mechanicals     0.955709
# 88226                         brocco anthony     0.967492
# 88503              father son shoe stores co     0.959622
# 88505                 father son shoe stores     0.959622
# 88654                     tilghman anthony w     0.942113
# 89135                    stagliano michael a     0.950403
# 89554                  midlantic restaurants     0.980017
# 89561                     braunstein estelle     0.962656
# 89716                      goldstein glenn a     0.940918
# 89748                           pappas chris     0.965705
# 89849                    mc donough thomas f     0.952960
# 89864                      arc environmental     0.943072
# 90073                       scoggins evadney     0.964337
# 90079                     1327 n 60th street     0.948674
# 90126                                 salmon     0.960008
# 90199                      fischer douglas s     0.948757
# 90653                    salt pepper deli ii     0.965823
# 90680                     g g shops of penna     0.965554
# 90737                       kivitz norman co     0.958066
# 91023        us bank national association tr     0.954730
# 91098                        palumbo stephen     0.955483
# 91114                 5601 chestnut partners     0.955192
# 91151                       cambridge iii lp     0.958092
# 91202                pulmonary disease assoc     0.960329
# 91234                   atlantic maintenance     0.944727
# 91245                  allegheny real estate     0.957134
# 91814                       mc carthy dennis     0.944361
# 91818                        aguirre jorge m     0.949106
# 91856                           s industries     0.969962
# 92061             ccp leasing associates iii     0.970009
# 92728        universal building construction     0.968874
# 92922                    santos construction     0.948668
# 92981              reyes real estate corpora     0.951449
# 93166                        drc investments     0.969682
# 93260                    usa parking systems     0.964311
# 93357                          tps iii of pa     0.953795
# 93488                ostrobrod and ostrobrod     0.965329
# 93507                     bernstein robert s     0.946601
# 93604              general vascular surgical     0.954630
# 93688                        bassetti edmond     0.950952
# 93851                   cobbs creek property     0.946560
# 93913           professional health services     0.944988
# 94028                           nutri system     0.954089
# 94035         6935 n 15th street holdings lp     0.990319
# 94079                    salaman law offices     0.981739
# 94108                    crankshaw william a     0.943802
# 94197                    berwind aviation co     0.953230
# 94214                       gibson charles f     0.946207
# 94227             brandywine enviromental co     0.967223
# 94479                    lindenmeyr paper co     0.965708
# 94610           paul schure limited partners     0.940019
# 94630         fox rehabilitation services ll     0.949995
# 94694                   pain relief center i     0.950622
# 94707                      a plus appliances     0.979760
# 94720                            brown louis     0.965409
# 94869                       eli anderson son     0.982621
# 94875        mantua community vector control     0.980262
# 94903                 3175 jfk associates lp     0.967289
# 94921                     ditman investments     0.970746
# 94939                         schwartz larry     0.940702
# 94945                                conston     0.955319
# 95185                  m fedele construction     0.957345
# 95470                       schwartz larry j     0.940702
# 95923                      harris lawrence c     0.946619
# 96169                 engel air conditioning     0.942898
# 96196                    alpha card services     0.977156
# 96417                          land holdings     0.942226
# 96420              cultural studies analysis     0.957558
# 96556                 sansom precious metals     0.956298
# 96612                   midlantic restaurant     0.980017
# 96817               diversified historic inv     0.970890
# 96861        rittenhouse grill associates lp     0.986917
# 97140                         amoroso robert     0.946323
# 97337              kosciuszko literary assoc     0.947850
# 97389                             rice david     0.952600
# 97594         law offices of christy adams p     0.967838
# 97595       the law offices of christy adams     0.948848
# 97671      rebuildables property acquisition     0.972172
# 97703                   center city hardware     0.950616
# 97845            miller building partners lp     0.940598
# 98136                             baik kon h     0.977293
# 98152                     schwartz stephen a     0.949515
# 98156             center city podiatry assoc     0.952290
# 98167                      bassetti edmond f     0.950952
# 98428                       baker margaret a     0.940488
# 98529                        j m enterprises     0.958685
# 98541              5601 chestnut partners lp     0.955192
# 98543                         a k investment     0.963347
# 98559                         baker margaret     0.940488
# 98948                         foschini vince     0.962472
# 99092                       cable connection     0.944313
# 99321                         csuha ronald s     0.950137
# 99358                           tps ii of pa     0.953795
# 99521                     pain relief center     0.950622
# 99559                        lanard axilbund     0.946447
# 99648                 ffe maplewood cliveden     0.973540
# 99839                center city real estate     0.948162
# 99899                          nutri systems     0.954089
# 99922                        daly investment     0.965011
