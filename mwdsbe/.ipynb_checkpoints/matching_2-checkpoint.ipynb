# %%
import mwdsbe
import mwdsbe.datasets.licenses as licenses
import schuylkill as skool
import numpy as np
import pandas as pd

# %%
registry = mwdsbe.load_registry()
len(registry)
# Out:
# 3119

# %%
license = licenses.CommercialActivityLicenses().download()
len(license)
# Out:
# 203149

# %%
def exact_match(data1, data2, on, how):
    
    if how not in ["exact", "contains", "startswith"]:
        raise ValueError("how should be one of: 'exact', 'contains', 'startswith'")
    
    merged = skool.exact_merge(data1, data2, on=on, how=how)
    matched = merged.dropna(subset=['company_name_y'])
    
    return matched

# %%
def fuzzy_match(data1, data2, on, score_cutoff):
    
    merged = skool.fuzzy_merge(data1, data2, on=on, score_cutoff=score_cutoff)
    matched = merged.dropna(subset=["company_name_y"])
    
    return matched

# %%
def get_match_rate(original, matched):
    return len(matched) / len(original) * 100

# %%
mini_registry = registry[:100]

# clean company_name and dba name
ignore = ['inc', 'group', 'llc', 'corp', 'pc', 'incorporated', 'ltd']
cleaned_registry = skool.clean_strings(registry, ['company_name', 'dba_name'], True, ignore)
cleaned_mini_registry = skool.clean_strings(mini_registry, ['company_name', 'dba_name'], True, ignore)
cleaned_license = skool.clean_strings(license, ['company_name'], True, ignore)

# %%
exact = exact_match(cleaned_mini_registry, cleaned_license, on="company_name", how="exact")

# %%
get_match_rate(cleaned_mini_registry, exact)
# Out:
# 41.0

# %%
# exact_contains = exact_match(cleaned_mini_registry, cleaned_license, on="company_name", how="contains")

# %%
fuzzy_95 = fuzzy_match(cleaned_mini_registry, cleaned_license, on="company_name", score_cutoff=95)

get_match_rate(cleaned_mini_registry, fuzzy_95)
# Out:
# 48.0

# %%
fuzzy_90 = fuzzy_match(cleaned_mini_registry, cleaned_license, on="company_name", score_cutoff=90)

# %%
get_match_rate(cleaned_mini_registry, fuzzy_90)
# Out:
# 55.00000000000001

# %%
fuzzy_85 = fuzzy_match(cleaned_mini_registry, cleaned_license, on="company_name", score_cutoff=85)

get_match_rate(cleaned_mini_registry, fuzzy_85)
# Out:
# 73.0

# %%
# exact match for full cleaned data
full_exact = exact_match(cleaned_registry, cleaned_license, on="company_name", how="exact")
get_match_rate(cleaned_registry, exact)
# Out:
# 42.51362616223148

# %%
len(full_exact)
# Out:
# 1326

# %%
# fuzzy match with 95 score_cutoff for full data
# full_fuzzy_95 = fuzzy_match(cleaned_registry, cleaned_license, on="company_name", score_cutoff=95)
# get_match_rate(cleaned_registry, full_fuzzy_95)

full_fuzzy_95_copy = pd.read_excel(r'C:\Users\dabinlee\Desktop\mwdsbe\data\full_clean_fuzzy_95.xlsx', index = None)

# %%
len(full_fuzzy_95)
# Out:
# 1345

# %%
full_exact.to_excel (r'C:\Users\dabinlee\Desktop\mwdsbe\data\full_clean_exact.xlsx', index = None, header=True)

# %%
full_fuzzy_95.to_excel (r'C:\Users\dabinlee\Desktop\mwdsbe\data\full_clean_fuzzy_95.xlsx', index = None, header=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-1b9e2f8ea50e> in <module>
# ----> 1 full_fuzzy_95.to_excel (r'C:\Users\dabinlee\Desktop\mwdsbe\data\full_clean_fuzzy_95.xlsx', index = None, header=True)
#
# NameError: name 'full_fuzzy_95' is not defined

# %%
diff = full_fuzzy_95_copy[full_fuzzy_95_copy['match_probability'] < 1]
diff
# Out:
#                   company_name_x dba_name   owner_first          owner_last  \
# 2      24 hour cleaning services      NaN  Mary Colleen           Zoltowski
# 11                a bob s towing      NaN        Mikina            Harrison
# 15                  a m electric      NaN       Anthony            Muhammad
# 16                  a m painting      NaN      Abdullah            Muhammad
# 17         a m truck auto repair      NaN         CATHY  MATARAZZO-NICHOLAS
# ...                          ...      ...           ...                 ...
# 1303            vistaconnections      NaN        Judith            Donnelly
# 1304    vj associates of suffolk      NaN         Vijay               Desai
# 1315  west construction services      NaN     Christine           Gallagher
# 1321           williams electric      NaN       Richard            Williams
# 1327            woodland wallker      NaN        Jeremy              Walker
#
#                                     location location_city location_state  \
# 2                      14005 Barcalow Street  Philadelphia             PA
# 11                      2220 Orthodox Street  Philadelphia             PA
# 15                   2222 N. Marshall Street  Philadelphia             PA
# 16                  2745 North Garnet Street  Philadelphia             PA
# 17                       14065 Townsend Road  Philadelphia             PA
# ...                                      ...           ...            ...
# 1303              12120 State Line Road #292       Leawood             KS
# 1304  1090 King Georges Post Road, Suite 301        Edison             NJ
# 1315                       264 Broadway Road        Merion             PA
# 1321                          17 Karen Drive  Williamstown             NJ
# 1327                    4701 Woodland Avenue  Philadelphia             PA
#
#       zip_code                         mailing_address  mailing_city  ...  \
# 2      19116.0                   14005 Barcalow Street  Philadelphia  ...
# 11     19137.0                    2220 Orthodox Street  Philadelphia  ...
# 15     19133.0                 2222 N. Marshall Street  Philadelphia  ...
# 16     19132.0                2745 North Garnet Street  Philadelphia  ...
# 17     19154.0                     14065 Townsend Road  Philadelphia  ...
# ...        ...                                     ...           ...  ...
# 1303   66209.0              12120 State Line Road #292       Leawood  ...
# 1304    8837.0  1090 King Georges Post Road, Suite 301        Edison  ...
# 1315   19066.0                       264 Broadway Road        Merion  ...
# 1321    8094.0                      1532 S 53rd Street  Philadelphia  ...
# 1327   19143.0                    4701 Woodland Avenue  Philadelphia  ...
#
#        location_standard        lat        lng  \
# 2      14005 BARCALOW ST  40.131349 -75.014284
# 11      2220 ORTHODOX ST  40.008166 -75.078701
# 15    2222 N MARSHALL ST  39.985489 -75.144539
# 16      2745 N GARNET ST  39.996079 -75.162692
# 17     14065 TOWNSEND RD  40.108419 -74.975170
# ...                  ...        ...        ...
# 1303                 NaN        NaN        NaN
# 1304                 NaN        NaN        NaN
# 1315                 NaN        NaN        NaN
# 1321                 NaN        NaN        NaN
# 1327   4701 WOODLAND AVE  39.943011 -75.211579
#
#                                           geometry  match_probability  \
# 2       POINT (-75.0142839608247 40.1313485259829)               0.98
# 11      POINT (-75.07870119360095 40.008166153533)               0.96
# 15     POINT (-75.14453871694691 39.9854885343929)               0.96
# 16    POINT (-75.16269177785369 39.99607919723243)               0.96
# 17    POINT (-74.97516992544176 40.10841900796122)               0.98
# ...                                            ...                ...
# 1303                                           NaN               0.97
# 1304                                           NaN               0.98
# 1315                                           NaN               0.96
# 1321                                           NaN               0.97
# 1327  POINT (-75.21157922611978 39.94301058989137)               0.97
#
#       right_index license_num            issue_date  license_status  \
# 2           17310      120711  1999-08-30T00:00:00Z          Active
# 11         134142      134939  2010-02-04T00:00:00Z          Active
# 15          28712      154795  2002-11-27T00:00:00Z          Active
# 16         118208      419397  2007-08-06T00:00:00Z          Active
# 17          19881      131320  2000-05-25T00:00:00Z          Active
# ...           ...         ...                   ...             ...
# 1303       169197      670243  2015-07-06T00:00:00Z          Active
# 1304       195398      794326  2018-11-13T00:00:00Z          Active
# 1315       105190      360580  2006-03-20T00:00:00Z          Active
# 1321       125884      453068  2008-08-04T00:00:00Z          Active
# 1327       152382      590839  2013-04-20T00:00:00Z          Active
#
#                   company_name_y
# 2       24 hour cleaning service
# 11                 a bobs towing
# 15                   am electric
# 16                   am painting
# 17          am truck auto repair
# ...                          ...
# 1303           vista connections
# 1304   v j associates of suffolk
# 1315  best construction services
# 1321          williams electrica
# 1327             woodland walker
#
# [137 rows x 26 columns]

# %%
diff.to_excel (r'C:\Users\dabinlee\Desktop\mwdsbe\data\diff_exact_95.xlsx', index = None, header=True)

# %%
# fuzzy match with 90 score_cutoff for full data
full_fuzzy_90 = fuzzy_match(cleaned_registry, cleaned_license, on="company_name", score_cutoff=90)
get_match_rate(cleaned_registry, full_fuzzy_90)
# Out:
# 52.48477075985893

# %%
full_fuzzy_90.to_excel (r'C:\Users\dabinlee\Desktop\mwdsbe\data\full_clean_fuzzy_90.xlsx', index = None, header=True)

# %%
diff_exact_90 = full_fuzzy_90[full_fuzzy_90['match_probability'] < 1]
len(diff_exact_90)
# Out:
# 429

# %%
diff_exact_90.to_excel (r'C:\Users\dabinlee\Desktop\mwdsbe\data\diff_exact_90.xlsx', index = None, header=True)

# %%
diff_95_90 = full_fuzzy_90[full_fuzzy_90['match_probability'] < 1]
diff_95_90 = diff_95_90[diff_95_90['match_probability'] > 0.9]
diff_95_90
# Out:
#                   company_name_x dba_name   owner_first owner_last  \
# 1                        12bravo      NaN       JEFFREY  YEKENCHIK
# 7      24 hour cleaning services      NaN  Mary Colleen  Zoltowski
# 25                a bob s towing      NaN        Mikina   Harrison
# 34                  a m electric      NaN       Anthony   Muhammad
# 35                  a m painting      NaN      Abdullah   Muhammad
# ...                          ...      ...           ...        ...
# 3045          webster associates      NaN       Deborah    Webster
# 3053  west construction services      NaN     Christine  Gallagher
# 3064           williams electric      NaN       Richard   Williams
# 3073      wjj global enterprises      NaN        Willie      Jones
# 3078            woodland wallker      NaN        Jeremy     Walker
#
#                             location  location_city location_state  zip_code  \
# 1                236 McKendimen Road  Medford Lakes             NJ    8055.0
# 7              14005 Barcalow Street   Philadelphia             PA   19116.0
# 25              2220 Orthodox Street   Philadelphia             PA   19137.0
# 34           2222 N. Marshall Street   Philadelphia             PA   19133.0
# 35          2745 North Garnet Street   Philadelphia             PA   19132.0
# ...                              ...            ...            ...       ...
# 3045  301 South Elm Street Suite 508     Greensboro             NC   27401.0
# 3053               264 Broadway Road         Merion             PA   19066.0
# 3064                  17 Karen Drive   Williamstown             NJ    8094.0
# 3073               1242 Pratt Street   Philadelphia             PA   19124.0
# 3078            4701 Woodland Avenue   Philadelphia             PA   19143.0
#
#                      mailing_address   mailing_city  ...   location_standard  \
# 1                236 McKendimen Road  Medford Lakes  ...                 NaN
# 7              14005 Barcalow Street   Philadelphia  ...   14005 BARCALOW ST
# 25              2220 Orthodox Street   Philadelphia  ...    2220 ORTHODOX ST
# 34           2222 N. Marshall Street   Philadelphia  ...  2222 N MARSHALL ST
# 35          2745 North Garnet Street   Philadelphia  ...    2745 N GARNET ST
# ...                              ...            ...  ...                 ...
# 3045  301 South Elm Street Suite 508     Greensboro  ...                 NaN
# 3053               264 Broadway Road         Merion  ...                 NaN
# 3064              1532 S 53rd Street   Philadelphia  ...                 NaN
# 3073               1242 Pratt Street   Philadelphia  ...       1242 PRATT ST
# 3078            4701 Woodland Avenue   Philadelphia  ...   4701 WOODLAND AVE
#
#             lat        lng                    geometry  match_probability  \
# 1           NaN        NaN                        None               0.93
# 7     40.131349 -75.014284  POINT (-75.01428 40.13135)               0.98
# 25    40.008166 -75.078701  POINT (-75.07870 40.00817)               0.96
# 34    39.985489 -75.144539  POINT (-75.14454 39.98549)               0.96
# 35    39.996079 -75.162692  POINT (-75.16269 39.99608)               0.96
# ...         ...        ...                         ...                ...
# 3045        NaN        NaN                        None               0.94
# 3053        NaN        NaN                        None               0.96
# 3064        NaN        NaN                        None               0.97
# 3073  40.025222 -75.083344  POINT (-75.08334 40.02522)               0.91
# 3078  39.943011 -75.211579  POINT (-75.21158 39.94301)               0.97
#
#       right_index license_num            issue_date  license_status  \
# 1        200602.0      815623  2019-06-17T00:00:00Z          Active
# 7         17320.0      120711  1999-08-30T00:00:00Z          Active
# 25       134133.0      134939  2010-02-04T00:00:00Z          Active
# 34        28710.0      154795  2002-11-27T00:00:00Z          Active
# 35       118226.0      419397  2007-08-06T00:00:00Z          Active
# ...           ...         ...                   ...             ...
# 3045      22355.0      131448  2001-01-22T00:00:00Z          Active
# 3053     105222.0      360580  2006-03-20T00:00:00Z          Active
# 3064     125874.0      453068  2008-08-04T00:00:00Z          Active
# 3073     172657.0      687493  2015-12-30T00:00:00Z          Active
# 3078     152394.0      590839  2013-04-20T00:00:00Z          Active
#
#                   company_name_y
# 1                       12 bravo
# 7       24 hour cleaning service
# 25                 a bobs towing
# 34                   am electric
# 35                   am painting
# ...                          ...
# 3045            weber associates
# 3053  best construction services
# 3064          williams electrica
# 3073      cjr global enterprises
# 3078             woodland walker
#
# [362 rows x 26 columns]

# %%
diff_95_90.to_excel (r'C:\Users\dabinlee\Desktop\mwdsbe\data\diff_95_90.xlsx', index = None, header=True)

# %%
# match company_name and dba_name
merged = (
    skool.fuzzy_merge(cleaned_registry, cleaned_license, on="company_name", score_cutoff=95)
    .pipe(skool.fuzzy_merge, cleaned_registry, cleaned_license, left_on="dba_name", right_on="company_name", score_cutoff=95)
)
matched = merged.dropna(subset=['company_name_y'])
matched
# Out:
#                     company_name_x          dba_name   owner_first  \
# 0           119 degrees architects               NaN        Rafael
# 5                               22               NaN      Caroline
# 7        24 hour cleaning services               NaN  Mary Colleen
# 8                   259 strategies               NaN         Chaka
# 12                     4u services  stellar services         Liang
# ...                            ...               ...           ...
# 3105                    zana cakes               NaN          Zana
# 3106       zanaras reporting video               NaN         JULIE
# 3107  zavorski masonry restoration               NaN          Lisa
# 3110             zenga engineering               NaN     Gwendolyn
# 3113        zizza highway services               NaN        Arlene
#
#        owner_last                        location location_city  \
# 0          Utrera    1503 Green Street, Suite # 4  Philadelphia
# 5          Harper                 757 Public Road     Bethlehem
# 7       Zoltowski           14005 Barcalow Street  Philadelphia
# 8     Fattah, Jr.    Two Logan Square, Suite 1900  Philadelphia
# 12           Chen  70 West 36th Street, Ste. #702      New York
# ...           ...                             ...           ...
# 3105       Billue    7715 Crittenden Street, #339  Philadelphia
# 3106      ZANARAS   1845 WALNUT STREET, Suite 938  Philadelphia
# 3107     Zavorski                 717 Ford Avenue     Langhorne
# 3110       Lodise           313 East Broad Street       Palmyra
# 3113        Zizza          382 CONCHESTER HIGHWAY    Glen Mills
#
#      location_state  zip_code                 mailing_address  mailing_city  \
# 0                PA   19130.0    1503 Green Street, Suite # 4  Philadelphia
# 5                PA   18015.0                 757 Public Road     Bethlehem
# 7                PA   19116.0           14005 Barcalow Street  Philadelphia
# 8                PA   19103.0    Two Logan Square, Suite 1900  Philadelphia
# 12               NY   10018.0  70 West 36th Street, Ste. #702      New York
# ...             ...       ...                             ...           ...
# 3105             PA   19118.0    7715 Crittenden Street, #339  Philadelphia
# 3106             PA   19103.0   1845 WALNUT STREET, Suite 938  Philadelphia
# 3107             PA   19047.0                 717 Ford Avenue     Langhorne
# 3110             NJ    8065.0           313 East Broad Street       Palmyra
# 3113             PA   19342.0          382 CONCHESTER HIGHWAY    Glen Mills
#
#       ...   location_standard        lat        lng  \
# 0     ...       1503 GREEN ST  39.964275 -75.163042
# 5     ...                 NaN        NaN        NaN
# 7     ...   14005 BARCALOW ST  40.131349 -75.014284
# 8     ...    100-20 N 18TH ST  39.955726 -75.169784
# 12    ...                 NaN        NaN        NaN
# ...   ...                 ...        ...        ...
# 3105  ...  7715 CRITTENDEN ST  40.074388 -75.193592
# 3106  ...      1845 WALNUT ST  39.950665 -75.171552
# 3107  ...                 NaN        NaN        NaN
# 3110  ...                 NaN        NaN        NaN
# 3113  ...                 NaN        NaN        NaN
#
#                         geometry  match_probability  right_index license_num  \
# 0     POINT (-75.16304 39.96427)               1.00     131109.0      480115
# 5                           None               1.00     168696.0      667661
# 7     POINT (-75.01428 40.13135)               0.98      17318.0      120711
# 8     POINT (-75.16978 39.95573)               1.00     102402.0      346817
# 12                          None               1.00     141065.0      531189
# ...                          ...                ...          ...         ...
# 3105  POINT (-75.19359 40.07439)               1.00      97875.0      167047
# 3106  POINT (-75.17155 39.95067)               1.00     113998.0      401529
# 3107                        None               1.00     101646.0      343160
# 3110                        None               1.00     136809.0      509641
# 3113                        None               1.00      30232.0      161685
#
#                 issue_date  license_status                company_name_y
# 0     2009-07-31T00:00:00Z          Active        119 degrees architects
# 5     2015-06-10T00:00:00Z          Active                            22
# 7     1999-08-30T00:00:00Z          Active      24 hour cleaning service
# 8     2005-11-28T00:00:00Z          Active                259 strategies
# 12    2011-04-22T00:00:00Z          Active                   4u services
# ...                    ...             ...                           ...
# 3105  2005-07-01T00:00:00Z          Active                    zana cakes
# 3106  2007-03-05T00:00:00Z          Active       zanaras reporting video
# 3107  2005-10-31T00:00:00Z          Active  zavorski masonry restoration
# 3110  2010-07-26T00:00:00Z          Active             zenga engineering
# 3113  2003-05-09T00:00:00Z          Active        zizza highway services
#
# [1360 rows x 26 columns]

# %%
dba = matched[matched['dba_name'].notna()]
dba
# Out:
#                     company_name_x                       dba_name owner_first  \
# 12                     4u services               stellar services       Liang
# 17               84 lumber company              84 lumber company    Margaret
# 18             a a court reporting                 andrea st john      Andrea
# 29                  a best vending  a best vending coffee service         Sue
# 48             abbadon corporation      superior facility service       Donna
# ...                            ...                            ...         ...
# 3034        walls engineering pllc                  richard walls     Richard
# 3037            wash cycle laundry             wash cycle laundry     Gabriel
# 3051          wendy saltzman media             philly power media       Wendy
# 3066  willow accounting consulting   willow accounting consulting     Miranda
# 3086          wright commissioning           wright commissioning         Kim
#
#       owner_last                              location location_city  \
# 12          Chen        70 West 36th Street, Ste. #702      New York
# 17    Hardy-Knox                        1019 Route 519   Eighty Four
# 18      St. John     303 Chestnut Street, Second Floor  Philadelphia
# 29       Epstein                         7336 State Rd  Philadelphia
# 48         Cohen                     712 Bigler Street  Philadelphia
# ...          ...                                   ...           ...
# 3034       Walls  10911 Raven Ridge Road, Suite 103-76       Raleigh
# 3037   Mandujano      1617 JFK Boulevard, Suite - 1855  Philadelphia
# 3051    Saltzman                1112 South 17th Street  Philadelphia
# 3066      Willow        4811 Jonestown Road, Suite 224    Harrisburg
# 3086      Wright            150 Monument Rd, Suite 101   Bala Cynwyd
#
#      location_state  zip_code                       mailing_address  \
# 12               NY   10018.0        70 West 36th Street, Ste. #702
# 17               PA   15330.0                        1019 Route 519
# 18               PA   19106.0                  P.O. Box 74, Suite 4
# 29               PA   19136.0                         7336 State Rd
# 48               PA   19148.0                         712 Bigler St
# ...             ...       ...                                   ...
# 3034             NC   27614.0  10911 Raven Ridge Road, Suite 103-76
# 3037             PA   19103.0      1617 JFK Boulevard, Suite - 1855
# 3051             PA   19146.0                1112 South 17th Street
# 3066             PA   17109.0        4811 Jonestown Road, Suite 224
# 3086             PA   19004.0            150 Monument Rd, Suite 101
#
#       mailing_city  ...         location_standard        lat        lng  \
# 12        New York  ...                       NaN        NaN        NaN
# 17     Eighty Four  ...                       NaN        NaN        NaN
# 18      Moorestown  ...           303 CHESTNUT ST  39.948849 -75.146173
# 29    Philadelphia  ...             7336 STATE RD  40.026532 -75.030907
# 48    Philadelphia  ...             712 BIGLER ST  39.912636 -75.161093
# ...            ...  ...                       ...        ...        ...
# 3034       Raleigh  ...                       NaN        NaN        NaN
# 3037  Philadelphia  ...  1617 JOHN F KENNEDY BLVD  39.953873 -75.167082
# 3051  Philadelphia  ...            1112 S 17TH ST  39.937827 -75.171934
# 3066    Harrisburg  ...                       NaN        NaN        NaN
# 3086   Bala Cynwyd  ...                       NaN        NaN        NaN
#
#                         geometry  match_probability  right_index license_num  \
# 12                          None                1.0     141065.0      531189
# 17                          None                1.0     111886.0      393009
# 18    POINT (-75.14617 39.94885)                1.0     154361.0      107405
# 29    POINT (-75.03091 40.02653)                1.0     110609.0      122115
# 48    POINT (-75.16109 39.91264)                1.0     103092.0      019267
# ...                          ...                ...          ...         ...
# 3034                        None                1.0     198351.0      806486
# 3037  POINT (-75.16708 39.95387)                1.0     147085.0      560293
# 3051  POINT (-75.17193 39.93783)                1.0     190358.0      772115
# 3066                        None                1.0     182953.0      737961
# 3086                        None                1.0     149742.0      575500
#
#                 issue_date  license_status                company_name_y
# 12    2011-04-22T00:00:00Z          Active                   4u services
# 17    2006-11-30T00:00:00Z          Active             84 lumber company
# 18    2013-07-29T00:00:00Z          Active           a a court reporting
# 29    2006-10-06T00:00:00Z          Active                a best vending
# 48    2005-12-23T00:00:00Z          Active           abbadon corporation
# ...                    ...             ...                           ...
# 3034  2019-03-21T00:00:00Z          Active        walls engineering pllc
# 3037  2012-04-10T00:00:00Z          Active            wash cycle laundry
# 3051  2018-04-09T00:00:00Z          Active          wendy saltzman media
# 3066  2017-05-09T00:00:00Z          Active  willow accounting consulting
# 3086  2012-10-11T00:00:00Z          Active          wright commissioning
#
# [201 rows x 26 columns]

# %%
# match just dba_name
fuzzy_dba_merged = skool.fuzzy_merge(cleaned_registry, cleaned_license, left_on="dba_name", right_on="company_name", score_cutoff=95)
fuzzy_dba_matched = fuzzy_dba_merged.dropna(subset=['company_name_y'])
fuzzy_dba_matched
# Out:
#                                    company_name_x  \
# 17                              84 lumber company
# 48                            abbadon corporation
# 75                                ack contracting
# 169                         alpha office supplies
# 170   alpha omega systems services medical supply
# ...                                           ...
# 3001                         vic thompson company
# 3005                                    virgo iii
# 3037                           wash cycle laundry
# 3066                 willow accounting consulting
# 3086                         wright commissioning
#
#                           dba_name owner_first  owner_last  \
# 17               84 lumber company    Margaret  Hardy-Knox
# 48       superior facility service       Donna       Cohen
# 75                 ack contracting      Brenda     Kellogg
# 169               alpha enterprise   Terrill L       Brown
# 170            aoss medical supply       Hon K        Liew
# ...                            ...         ...         ...
# 3001                           vtc   Christine      Norton
# 3005                     virgo iii        Anne      Manuel
# 3037            wash cycle laundry     Gabriel   Mandujano
# 3066  willow accounting consulting     Miranda      Willow
# 3086          wright commissioning         Kim      Wright
#
#                               location   location_city location_state  \
# 17                      1019 Route 519     Eighty Four             PA
# 48                   712 Bigler Street    Philadelphia             PA
# 75              18 Campus Blvd Ste 100  Newtown Square             PA
# 169    4950 Parkside Avenue, Suite 500    Philadelphia             PA
# 170                4971 Central Avenue          Monroe             LA
# ...                                ...             ...            ...
# 3001   3751 New York Avenue, Suite 140       Arlington             TX
# 3005                    766 Knox Court         Yardley             PA
# 3037  1617 JFK Boulevard, Suite - 1855    Philadelphia             PA
# 3066    4811 Jonestown Road, Suite 224      Harrisburg             PA
# 3086        150 Monument Rd, Suite 101     Bala Cynwyd             PA
#
#       zip_code                   mailing_address    mailing_city  ...  \
# 17     15330.0                    1019 Route 519     Eighty Four  ...
# 48     19148.0                     712 Bigler St    Philadelphia  ...
# 75     19073.0            18 Campus Blvd Ste 100  Newtown Square  ...
# 169    19131.0                      P O BOX 2361     Bala Cynwyd  ...
# 170    71203.0               4971 Central Avenue          Monroe  ...
# ...        ...                               ...             ...  ...
# 3001   76014.0   3751 New York Avenue, Suite 140       Arlington  ...
# 3005   19067.0                    766 Knox Court         Yardley  ...
# 3037   19103.0  1617 JFK Boulevard, Suite - 1855    Philadelphia  ...
# 3066   17109.0    4811 Jonestown Road, Suite 224      Harrisburg  ...
# 3086   19004.0        150 Monument Rd, Suite 101     Bala Cynwyd  ...
#
#              location_standard        lat        lng  \
# 17                         NaN        NaN        NaN
# 48               712 BIGLER ST  39.912636 -75.161093
# 75                         NaN        NaN        NaN
# 169          4950 PARKSIDE AVE  39.979714 -75.218697
# 170                        NaN        NaN        NaN
# ...                        ...        ...        ...
# 3001                       NaN        NaN        NaN
# 3005                       NaN        NaN        NaN
# 3037  1617 JOHN F KENNEDY BLVD  39.953873 -75.167082
# 3066                       NaN        NaN        NaN
# 3086                       NaN        NaN        NaN
#
#                         geometry  match_probability  right_index license_num  \
# 17                          None               1.00     111886.0      393009
# 48    POINT (-75.16109 39.91264)               1.00     178872.0      720072
# 75                          None               1.00     197871.0      804592
# 169   POINT (-75.21870 39.97971)               0.97     172754.0      687938
# 170                         None               1.00     149286.0      573020
# ...                          ...                ...          ...         ...
# 3001                        None               1.00     145421.0      552631
# 3005                        None               1.00      94090.0      191740
# 3037  POINT (-75.16708 39.95387)               1.00     147085.0      560293
# 3066                        None               1.00     182953.0      737961
# 3086                        None               1.00     149742.0      575500
#
#                 issue_date  license_status                company_name_y
# 17    2006-11-30T00:00:00Z          Active             84 lumber company
# 48    2016-11-16T00:00:00Z          Active     superior facility service
# 75    2019-03-05T00:00:00Z          Active               ack contracting
# 169   2016-01-06T00:00:00Z          Active             alpha enterprises
# 170   2012-09-06T00:00:00Z          Active           aoss medical supply
# ...                    ...             ...                           ...
# 3001  2012-01-19T00:00:00Z          Active                           vtc
# 3005  2005-03-02T00:00:00Z          Active                     virgo iii
# 3037  2012-04-10T00:00:00Z          Active            wash cycle laundry
# 3066  2017-05-09T00:00:00Z          Active  willow accounting consulting
# 3086  2012-10-11T00:00:00Z          Active          wright commissioning
#
# [62 rows x 26 columns]

# %%
fuzzy_dba_matched.to_excel (r'C:\Users\dabinlee\Desktop\mwdsbe\data\full_clean_dba_fuzzy_95.xlsx', index = None, header=True)

# %%
# pipe all: exact, fuzzy_95 on company_name, fuzzy_95 on dba_name

# %%
# store data into excel

#     path = r'C:\Users\dabinlee\Desktop\mwdsbe\data\clean_fuzzy_merge'
#     path.join(['_', str(score_cutoff), '.xlsx'])
    
#     export_excel = matched.to_excel(path, index = None, header=True)

# %%
# get_match_rate(cleaned_mini_registry, exact_contains)

# exact_contains.to_excel (r'C:\Users\dabinlee\Desktop\mwdsbe\data\clean_exact_contains.xlsx', index = None, header=True)
