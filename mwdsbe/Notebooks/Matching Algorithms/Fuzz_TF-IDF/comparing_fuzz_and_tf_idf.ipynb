# %% [markdown]
# # Comparing Company Names using TF-IDF/ N-grams / cosine similarity

# %% [markdown]
# # Table of Contents
#
# 1. [Data](#data)
# 2. [Functions](#functions)
# 3. [Matching with TF-IDF](#tfidf)
# 4. [Comparing between fuzzy and TF-IDF](#compare)
#     1. [Fuzzy match with score-cutoff 95](#fuzz95)
#     2. [TF-IDF with score-cutoff 90](#tfidf90)
#     3. [TF-IDF with score-cutoff 85](#tfidf85)
#     4. [TF-IDF with score-cutoff 80](#tfidf80)
# 5. [Test Cosine Similary with sklearn](#cossimsklarn)

# %% [markdown]
# <a id="data"></a>
# ## Data

# %%
import mwdsbe
import mwdsbe.datasets.licenses as licenses
import schuylkill as skool
import pandas as pd
import numpy as np

# %%
# import registry
registry = mwdsbe.load_registry() # geopandas df

# %%
np.shape(registry)
# Out:
# (3119, 20)

# %%
registry.head()
# Out:
#                            company_name    dba_name owner_first owner_last  \
# registry_id
# 0                119 Degrees Architects         NaN      Rafael     Utrera
# 1                         12Bravo Group         NaN     JEFFREY  YEKENCHIK
# 2            1st Choice Financial Group    ProVisio    Kathrina      Nease
# 3                     212 Harakawa Inc.  Two Twelve         Ann   Harakawa
# 4                   215 Media Solutions         NaN      Dewain    Johnson
#
#                                  location  location_city location_state  \
# registry_id
# 0            1503 Green Street, Suite # 4   Philadelphia             PA
# 1                     236 McKendimen Road  Medford Lakes             NJ
# 2                      133 N. 21st Street      Camp Hill             PA
# 3            236 W 27th Street, Suite 802       New York             NY
# 4                       810 Felton Avenue    Sharon Hill             PA
#
#              zip_code               mailing_address   mailing_city  \
# registry_id
# 0             19130.0  1503 Green Street, Suite # 4   Philadelphia
# 1              8055.0           236 McKendimen Road  Medford Lakes
# 2             17011.0            133 N. 21st Street      Camp Hill
# 3             10001.0  236 W 27th Street, Suite 802       New York
# 4             19079.0             810 Felton Avenue    Sharon Hill
#
#             mailing_state  mailing_zip certification_type  \
# registry_id
# 0                      PA      19130.0                MBE
# 1                      NJ       8055.0               DSBE
# 2                      PA      17011.0                WBE
# 3                      NY      10001.0               MWBE
# 4                      PA      19079.0                MBE
#
#                                                     capability  local  \
# registry_id
# 0            NAICS 5413 Architectural, Engineering, and Rel...   True
# 1            Addition, alteration and renovation for-sale b...  False
# 2                           NAICS 928120 International Affairs  False
# 3            Graphic Design Services; Graphic design servic...  False
# 4            NAICS 5414 Specialized Design Services ; NAICS...  False
#
#              out_of_state location_standard        lat        lng  \
# registry_id
# 0                   False     1503 GREEN ST  39.964275 -75.163042
# 1                    True               NaN        NaN        NaN
# 2                   False               NaN        NaN        NaN
# 3                    True               NaN        NaN        NaN
# 4                   False               NaN        NaN        NaN
#
#                                                  geometry
# registry_id
# 0            POINT (-75.16304190105227 39.96427495800303)
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN

# %%
# import license data
license = licenses.CommercialActivityLicenses().download()

# %%
np.shape(license)
# Out:
# (203479, 4)

# %%
license.head()
# Out:
#   license_num            issue_date license_status  \
# 0      188053  1990-01-01T00:00:00Z         Active
# 1      058781  1990-01-12T00:00:00Z         Active
# 2      057406  1990-01-23T00:00:00Z         Active
# 3      332055  1990-02-08T00:00:00Z         Active
# 4      188058  1990-12-31T00:00:00Z         Active
#
#                      company_name
# 0  BIRMINGHAM FIRE INS CO OF PA T
# 1            CLAYMAN EDWARD P ESQ
# 2                     BRENNAN J F
# 3            TASTY BAKING COMPANY
# 4               MAGARGEE BROS INC

# %%
# clean_license = clean_license.drop_duplicates(subset='company_name', keep='first', inplace=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-d35faeffe4b5> in <module>
# ----> 1 clean_license = clean_license.drop_duplicates(subset='company_name', keep='first', inplace=False)
#
# NameError: name 'clean_license' is not defined

# %% [markdown]
# <a id="functions"></a>
# ## Functions

# %%
# N-Grams
import re

def ngrams(string, n=3):
    string = re.sub(r'[,-./]|\sBD',r'', string)
    ngrams = zip(*[string[i:] for i in range(n)])
    return [''.join(ngram) for ngram in ngrams]

# %%
from scipy.sparse import csr_matrix
import sparse_dot_topn.sparse_dot_topn as ct

def awesome_cossim_top(A, B, ntop, lower_bound=0):
    # force A and B as a CSR matrix.
    # If they have already been CSR, there is no overhead
    A = A.tocsr()
    B = B.tocsr()
    M, _ = A.shape
    _, N = B.shape
 
    idx_dtype = np.int32
 
    nnz_max = M*ntop
 
    indptr = np.zeros(M+1, dtype=idx_dtype)
    indices = np.zeros(nnz_max, dtype=idx_dtype)
    data = np.zeros(nnz_max, dtype=A.dtype)

    ct.sparse_dot_topn(
        M, N, np.asarray(A.indptr, dtype=idx_dtype),
        np.asarray(A.indices, dtype=idx_dtype),
        A.data,
        np.asarray(B.indptr, dtype=idx_dtype),
        np.asarray(B.indices, dtype=idx_dtype),
        B.data,
        ntop,
        lower_bound,
        indptr, indices, data)

    return csr_matrix((data,indices,indptr),shape=(M,N))

# %%
# from sklearn.feature_extraction.text import TfidfVectorizer

# company_names = clean_mini_registry['company_name']
# vectorizer = TfidfVectorizer(min_df=1, analyzer=ngrams)
# tf_idf_matrix = vectorizer.fit_transform(company_names)

# %%
# company_names_2 = clean_license['company_name']
# company_names_2 = company_names_2.dropna()

# %%
# tf_idf_matrix_2 = vectorizer.fit_transform(company_names_2)

# %%
# print(tf_idf_matrix[0])

# %%
# from sklearn.metrics.pairwise import cosine_similarity

# %%
# cosine_similarity(tf_idf_matrix[0], tf_idf_matrix_2) # dimension error

# %%
# test for cosine similarity
# data1 = ['apple', 'qple', 'applr', 'aple', 'grape']

# %%
# tf_idf_matrix_test = vectorizer.fit_transform(data1)

# %%
# matches_test = awesome_cossim_top(tf_idf_matrix_test, tf_idf_matrix_test, 2, 0.8)

# %%
def get_matches_df(sparse_matrix, name_vector, top=100):
    non_zeros = sparse_matrix.nonzero()
    
    sparserows = non_zeros[0]
    sparsecols = non_zeros[1]
    
    if top:
        nr_matches = top
    else:
        nr_matches = sparsecols.size
    
    left_side = np.empty([nr_matches], dtype=object)
    right_side = np.empty([nr_matches], dtype=object)
    similairity = np.zeros(nr_matches)
    
    for index in range(0, nr_matches):
        left_side[index] = name_vector[sparserows[index]]
        right_side[index] = name_vector[sparsecols[index]]
        similairity[index] = sparse_matrix.data[index]
    
    return pd.DataFrame({'left_side': left_side,
                          'right_side': right_side,
                           'similairity': similairity})

# %% [markdown]
# <a id="tfidf"></a>
# ## Matching with TF-IDF

# %%
# get_matches_df(matches_test, tf_idf_matrix_test)

# %%
# test combine 2 datasets and apply TF-IDF and cosine similarity approach
combined = clean_mini_registry.append(clean_license, sort=False)

# %%
company_names = combined['company_name'].values.astype('U')
vectorizer = TfidfVectorizer(min_df=1, analyzer=ngrams)
tf_idf_matrix = vectorizer.fit_transform(company_names)

# %%
# print(tf_idf_matrix[0])
# company_names

# %%
matches = awesome_cossim_top(tf_idf_matrix, tf_idf_matrix.transpose(), 2, 0.9)

# %%
matches_df = get_matches_df(matches, company_names, top=10000)

# %%
# matches_df[:10]

# %%
matches_df = matches_df[matches_df['similairity'] < 0.99999] # Remove all exact matches

# %%
# test dataset with size 100
mini_registry = registry[:100] # for testing purpose

# clean company_name and dba_name of clean datasets
ignore = ['inc', 'group', 'llc', 'corp', 'pc', 'incorporated', 'ltd']
clean_mini_registry = skool.clean_strings(mini_registry, ['company_name', 'dba_name'], True, ignore)
clean_license = skool.clean_strings(license, ['company_name'], True, ignore)

# %%
# test combine 2 datasets and apply TF-IDF and cosine similarity approach
combined = clean_mini_registry.append(clean_license, sort=False)

# transform to matrix
company_names = combined['company_name'].values.astype('U')
vectorizer = TfidfVectorizer(min_df=1, analyzer=ngrams)
tf_idf_matrix = vectorizer.fit_transform(company_names)

# calculate cosine similarity
matches = awesome_cossim_top(tf_idf_matrix, tf_idf_matrix.transpose(), 2, 0.9)

# %%
matches_df = get_matches_df(matches, company_names, top=1000)

# %%
# matches_df[-10:]

# %%
# last company name of clean_mini_registry
matches_df.loc[matches_df['left_side'] == 'advanced integration'] # this should be the cutting line of matrix mult
# Out:
#                 left_side            right_side  similairity
# 142  advanced integration  advanced integration          1.0
# 143  advanced integration  advanced integration          1.0

# %%
matches_df = matches_df[:144]

# %%
matches_df[40:50]
# Out:
#                      left_side                  right_side  similairity
# 40            a m e mechanical            a m e mechanical     1.000000
# 41            a m e mechanical            a m e mechanical     1.000000
# 42  a g consulting engineering  a g consulting engineering     1.000000
# 43     a l jackson company p a     a l jackson company p a     1.000000
# 44          a lee cook hauling          a lee cook hauling     1.000000
# 45          a lee cook hauling          a lee cook hauling     1.000000
# 46                a m electric                a m electric     1.000000
# 47                a m electric              d a m electric     0.911687
# 48                a m painting                a m painting     1.000000
# 49                a c advisory                a c advisory     1.000000

# %%
filter_matches = matches_df.duplicated(subset='left_side', keep='first') # all duplicates except their first occurrence will be marked as True

# %%
filter_matches = matches_df[filter_matches]

# %%
filter_matches
# Out:
#                                  left_side  \
# 1                   119 degrees architects
# 8                24 hour cleaning services
# 10                          259 strategies
# 15                             4u services
# 19                          521 management
# 21                    6 degrees consulting
# 23                       84 lumber company
# 25                     a a court reporting
# 29              a c environmental services
# 31                            a i security
# 39                          a best vending
# 41                        a m e mechanical
# 45                      a lee cook hauling
# 47                            a m electric
# 51                   a m truck auto repair
# 58           aaaa office warehouse surplus
# 64                     abbadon corporation
# 66                              abbi print
# 68                      abbonizio transfer
# 70                     abc construction co
# 72             abc multi language services
# 77                                abstract
# 82                        acacia financial
# 85               accelerated land transfer
# 87               access personnel services
# 89    accessibility modification solutions
# 92   accord mechanical management services
# 94                     accountants for you
# 97                   accu fire fabrication
# 100                               accustar
# 105                        ack contracting
# 107                         acme supply co
# 109                         acorn services
# 111              acp demolition remodeling
# 116                               acutedge
# 120                     adaptive resources
# 122                      adcon consultants
# 125              adept consulting services
# 128                      adkins management
# 131                    admiral integration
# 133            adolphues building services
# 137            advanced disposal solutions
# 139             advanced hydraulic systems
# 141         advanced infrastructure design
# 143                   advanced integration
#
#                                right_side  similairity
# 1                  119 degrees architects     1.000000
# 8                24 hour cleaning service     0.984436
# 10                         259 strategies     1.000000
# 15                            4u services     1.000000
# 19                         521 management     1.000000
# 21                   6 degrees consulting     1.000000
# 23                      84 lumber company     1.000000
# 25                    a a court reporting     1.000000
# 29             a c environmental services     1.000000
# 31                           a i security     1.000000
# 39                         a best vending     1.000000
# 41                       a m e mechanical     1.000000
# 45                     a lee cook hauling     1.000000
# 47                         d a m electric     0.911687
# 51                   am truck auto repair     0.920161
# 58      aaaa office and warehouse surplus     0.938331
# 64                    abbadon corporation     1.000000
# 66                             abbi print     1.000000
# 68                     abbonizio transfer     1.000000
# 70                    abc construction co     1.000000
# 72            abc multi language services     1.000000
# 77                               abstract     1.000000
# 82                       acacia financial     1.000000
# 85              accelerated land transfer     1.000000
# 87              access personnel services     1.000000
# 89   accessibility modification solutions     1.000000
# 92     accord mechanical management servi     0.966991
# 94                    accountants for you     1.000000
# 97                  accu fire fabrication     1.000000
# 100                              accustar     1.000000
# 105                       ack contracting     1.000000
# 107                           acme supply     0.929429
# 109                        acorn services     1.000000
# 111             acp demolition remodeling     1.000000
# 116                              acutedge     1.000000
# 120                    adaptive resources     1.000000
# 122                     adcon consultants     1.000000
# 125                 adept consulting serv     0.933910
# 128                     adkins management     1.000000
# 131                   admiral integration     1.000000
# 133           adolphues building services     1.000000
# 137           advanced disposal solutions     1.000000
# 139            advanced hydraulic systems     1.000000
# 141        advanced infrastructure design     1.000000
# 143                  advanced integration     1.000000

# %%
len(filter_matches)
# Out:
# 45

# %%
len(filter_matches) == len(np.unique(filter_matches['left_side'])) # all unique
# Out:
# True

# %% [markdown]
# <a id="compare"></a>
# ## Comparing between fuzzy and TF-IDF

# %% [markdown]
# <a id="fuzz95"></a>
# ### Fuzzy match with score-cutoff 95 (best score-cutoff)

# %%
mini_registry = registry[:100]

# clean company_name and dba name
ignore = ['inc', 'group', 'llc', 'corp', 'pc', 'incorporated', 'ltd', 'co']
cleaned_registry = skool.clean_strings(registry, ['company_name', 'dba_name'], True, ignore)
cleaned_mini_registry = skool.clean_strings(mini_registry, ['company_name', 'dba_name'], True, ignore)
cleaned_license = skool.clean_strings(license, ['company_name'], True, ignore)

cleaned_mini_registry = cleaned_mini_registry.drop_duplicates(subset='company_name', keep='first', inplace=False)
cleaned_license = cleaned_license.drop_duplicates(subset='company_name', keep='first', inplace=False)

# %%
print('Size of mini_registry data: ', len(cleaned_mini_registry))
print('Size of license data: ', len(cleaned_license))
# Out:
# Size of mini_registry data:  100
# Size of license data:  194686

# %%
# fuzzy on company_name and dba_name with 95 score-cutoff
# match company_name and dba_name
import time
t1 = time.time()
merged = (
    skool.fuzzy_merge(cleaned_mini_registry, cleaned_license, on="company_name", score_cutoff=95)
    .pipe(skool.fuzzy_merge, cleaned_mini_registry, cleaned_license, left_on="dba_name", right_on="company_name", score_cutoff=95)
)
t = time.time() - t1
matched = merged.dropna(subset=['company_name_y'])

# %%
print('Fuzzywuzzy match: ', len(matched), 'out of 100')
# Out:
# Fuzzywuzzy match:  49 out of 100

# %%
print('Execution fuzzywuzzy match: ', t/60, ' minute')
# Out:
# Execution fuzzywuzzy match:  0.5492017984390258  minute

# %%
matched[['company_name_x', 'company_name_y', 'match_probability']]
# Out:
#                            company_name_x  \
# 0                  119 degrees architects
# 5                                      22
# 7               24 hour cleaning services
# 8                          259 strategies
# 12                            4u services
# 15                         521 management
# 16                   6 degrees consulting
# 17                      84 lumber company
# 18                    a a court reporting
# 21             a c environmental services
# 22                           a i security
# 25                         a bob s towing
# 29                         a best vending
# 30                       a m e mechanical
# 33                     a lee cook hauling
# 34                           a m electric
# 35                           a m painting
# 37                  a m truck auto repair
# 40                    a v rental services
# 48                    abbadon corporation
# 49                             abbi print
# 50                     abbonizio transfer
# 51                       abc construction
# 52            abc multi language services
# 56                               abstract
# 58                       ac s contractors
# 60                       acacia financial
# 62              accelerated land transfer
# 63              access personnel services
# 64   accessibility modification solutions
# 66  accord mechanical management services
# 67                    accountants for you
# 69                  accu fire fabrication
# 71                               accustar
# 75                        ack contracting
# 76                            acme supply
# 77                         acorn services
# 78              acp demolition remodeling
# 82                               acutedge
# 85                     adaptive resources
# 86                      adcon consultants
# 89                        adg enterprises
# 90                      adkins management
# 92                    admiral integration
# 93            adolphues building services
# 96            advanced disposal solutions
# 97             advanced hydraulic systems
# 98         advanced infrastructure design
# 99                   advanced integration
#
#                           company_name_y match_probability
# 0                 119 degrees architects                 1
# 5                                     22                 1
# 7               24 hour cleaning service              0.98
# 8                         259 strategies                 1
# 12                           4u services                 1
# 15                        521 management                 1
# 16                  6 degrees consulting                 1
# 17                     84 lumber company                 1
# 18                   a a court reporting                 1
# 21            a c environmental services                 1
# 22                          a i security                 1
# 25                         a bobs towing              0.96
# 29                        a best vending                 1
# 30                      a m e mechanical                 1
# 33                    a lee cook hauling                 1
# 34                           am electric              0.96
# 35                           am painting              0.96
# 37                  am truck auto repair              0.98
# 40                    av rental services              0.97
# 48                   abbadon corporation                 1
# 49                            abbi print                 1
# 50                    abbonizio transfer                 1
# 51                      abc construction                 1
# 52           abc multi language services                 1
# 56                              abstract                 1
# 58                       a s contractors              0.97
# 60                      acacia financial                 1
# 62             accelerated land transfer                 1
# 63             access personnel services                 1
# 64  accessibility modification solutions                 1
# 66    accord mechanical management servi              0.96
# 67                   accountants for you                 1
# 69                 accu fire fabrication                 1
# 71                              accustar                 1
# 75                       ack contracting                 1
# 76                           acme supply                 1
# 77                        acorn services                 1
# 78             acp demolition remodeling                 1
# 82                              acutedge                 1
# 85                    adaptive resources                 1
# 86                     adcon consultants                 1
# 89                        ag enterprises              0.97
# 90                     adkins management                 1
# 92                   admiral integration                 1
# 93           adolphues building services                 1
# 96           advanced disposal solutions                 1
# 97            advanced hydraulic systems                 1
# 98        advanced infrastructure design                 1
# 99                  advanced integration                 1

# %% [markdown]
# <a id="tfidf90"></a>
# ### TF-IDF with score-cutoff 90

# %%
# TF-IDF on company_name with 90 score-cutoff
combined = cleaned_mini_registry.append(cleaned_license, sort=False)

# transform to matrix
from sklearn.feature_extraction.text import TfidfVectorizer

company_names = combined['company_name'].values.astype('U')
vectorizer = TfidfVectorizer(min_df=1, analyzer=ngrams)
tf_idf_matrix = vectorizer.fit_transform(company_names)

# calculate cosine similarity
import time
t1 = time.time()
matches = awesome_cossim_top(tf_idf_matrix, tf_idf_matrix.transpose(), 2, 0.9)
t = time.time() - t1

# %%
print('Execution time for cossim 90: ', t/60, ' minute')
# Out:
# Execution time for cossim 90:  1.5641103386878967  minute

# %%
matches_df = get_matches_df(matches, company_names, top=1000)

# %%
matches
# Out:
# <194830x194830 sparse matrix of type '<class 'numpy.float64'>'
# 	with 200648 stored elements in Compressed Sparse Row format>

# %%
# last company name of clean_mini_registry
last_index = len(cleaned_mini_registry) - 1
last_company_name = cleaned_mini_registry.loc[last_index, 'company_name']
last_company_index_to_consider = matches_df.loc[matches_df['left_side'] == last_company_name].index.tolist()[-1] # this should be the cutting line of matrix mult

# %%
matches_df = matches_df[:last_company_index_to_consider + 1]

filter_matches = matches_df.duplicated(subset='left_side', keep='first') # all duplicates except their first occurrence will be marked as True

filter_matches = matches_df[filter_matches]

print('TF-IDF match: ', len(filter_matches), ' out of ', len(cleaned_mini_registry))
# Out:
# TF-IDF match:  45  out of  100

# %%
filter_matches
# Out:
#                                  left_side  \
# 1                   119 degrees architects
# 8                24 hour cleaning services
# 10                          259 strategies
# 15                             4u services
# 19                          521 management
# 21                    6 degrees consulting
# 23                       84 lumber company
# 25                     a a court reporting
# 29              a c environmental services
# 31                            a i security
# 39                          a best vending
# 41                        a m e mechanical
# 45                      a lee cook hauling
# 47                            a m electric
# 51                   a m truck auto repair
# 58           aaaa office warehouse surplus
# 64                     abbadon corporation
# 66                              abbi print
# 68                      abbonizio transfer
# 70                        abc construction
# 72             abc multi language services
# 77                                abstract
# 82                        acacia financial
# 85               accelerated land transfer
# 87               access personnel services
# 89    accessibility modification solutions
# 92   accord mechanical management services
# 94                     accountants for you
# 97                   accu fire fabrication
# 100                               accustar
# 105                        ack contracting
# 107                            acme supply
# 109                         acorn services
# 111              acp demolition remodeling
# 116                               acutedge
# 120                     adaptive resources
# 122                      adcon consultants
# 125              adept consulting services
# 128                      adkins management
# 131                    admiral integration
# 133            adolphues building services
# 137            advanced disposal solutions
# 139             advanced hydraulic systems
# 141         advanced infrastructure design
# 143                   advanced integration
#
#                                right_side  similairity
# 1                  119 degrees architects     1.000000
# 8                24 hour cleaning service     0.984480
# 10                         259 strategies     1.000000
# 15                            4u services     1.000000
# 19                         521 management     1.000000
# 21                   6 degrees consulting     1.000000
# 23                      84 lumber company     1.000000
# 25                    a a court reporting     1.000000
# 29             a c environmental services     1.000000
# 31                           a i security     1.000000
# 39                         a best vending     1.000000
# 41                       a m e mechanical     1.000000
# 45                     a lee cook hauling     1.000000
# 47                         d a m electric     0.911652
# 51                   am truck auto repair     0.920130
# 58      aaaa office and warehouse surplus     0.938333
# 64                    abbadon corporation     1.000000
# 66                             abbi print     1.000000
# 68                     abbonizio transfer     1.000000
# 70                       abc construction     1.000000
# 72            abc multi language services     1.000000
# 77                               abstract     1.000000
# 82                       acacia financial     1.000000
# 85              accelerated land transfer     1.000000
# 87              access personnel services     1.000000
# 89   accessibility modification solutions     1.000000
# 92     accord mechanical management servi     0.967023
# 94                    accountants for you     1.000000
# 97                  accu fire fabrication     1.000000
# 100                              accustar     1.000000
# 105                       ack contracting     1.000000
# 107                           acme supply     1.000000
# 109                        acorn services     1.000000
# 111             acp demolition remodeling     1.000000
# 116                              acutedge     1.000000
# 120                    adaptive resources     1.000000
# 122                     adcon consultants     1.000000
# 125                 adept consulting serv     0.934368
# 128                     adkins management     1.000000
# 131                   admiral integration     1.000000
# 133           adolphues building services     1.000000
# 137           advanced disposal solutions     1.000000
# 139            advanced hydraulic systems     1.000000
# 141        advanced infrastructure design     1.000000
# 143                  advanced integration     1.000000

# %%
# Explore different companies result between fuzzy match(matched) and TDIDF match(filter_matches)
fuzzy_matched = matched['company_name_x']
tfidf_matched = filter_matches['left_side']
pd.concat([fuzzy_matched, tfidf_matched]).drop_duplicates(keep=False)
# Out:
# 5                                 22
# 25                    a bob s towing
# 35                      a m painting
# 40               a v rental services
# 58                  ac s contractors
# 89                   adg enterprises
# 58     aaaa office warehouse surplus
# 125        adept consulting services
# dtype: object

# %% [markdown]
# <a id="tfidf80"></a>
# ### TF-IDF with different score-cutoff 80

# %%
# TF-IDF on company_name with 80 score-cutoff
combined = cleaned_mini_registry.append(cleaned_license, sort=False)

# transform to matrix
from sklearn.feature_extraction.text import TfidfVectorizer

company_names = combined['company_name'].values.astype('U')
vectorizer = TfidfVectorizer(min_df=1, analyzer=ngrams)
tf_idf_matrix = vectorizer.fit_transform(company_names)

# calculate cosine similarity
import time
t1 = time.time()
matches = awesome_cossim_top(tf_idf_matrix, tf_idf_matrix.transpose(), 2, 0.8)
t = time.time() - t1

# %%
print('Time for calculating cosine similarity: ', t/60, ' minute')
# Out:
# Time for calculating cosine similarity:  1.6015166680018107  minute

# %%
matches_df = get_matches_df(matches, company_names, top=1000)

# %%
# last company name of clean_mini_registry
last_index = len(cleaned_mini_registry) - 1
last_company_name = cleaned_mini_registry.loc[last_index, 'company_name']
last_company_index_to_consider = matches_df.loc[matches_df['left_side'] == last_company_name].index.tolist()[-1] # this should be the cutting line of matrix mult

# %%
matches_df = matches_df[:last_company_index_to_consider + 1]

filter_matches = matches_df.duplicated(subset='left_side', keep='first') # all duplicates except their first occurrence will be marked as True

filter_matches = matches_df[filter_matches]

print('TF-IDF match: ', len(filter_matches), ' out of ', len(cleaned_mini_registry))
# Out:
# TF-IDF match:  56  out of  100

# %%
filter_matches
# Out:
#                                  left_side  \
# 1                   119 degrees architects
# 8                24 hour cleaning services
# 10                          259 strategies
# 15                             4u services
# 19                          521 management
# 21                    6 degrees consulting
# 23                       84 lumber company
# 25                     a a court reporting
# 29              a c environmental services
# 31                            a i security
# 37                        a k architecture
# 40                          a best vending
# 42                        a m e mechanical
# 44              a g consulting engineering
# 47                      a lee cook hauling
# 49                            a m electric
# 51                            a m painting
# 53                            a c advisory
# 55                   a m truck auto repair
# 58                a t russell construction
# 60                     a v rental services
# 63             aa carpet cleaning services
# 65           aaaa office warehouse surplus
# 67     aarch realty d b a era aarch realty
# 72                     abbadon corporation
# 74                              abbi print
# 76                      abbonizio transfer
# 78                        abc construction
# 80             abc multi language services
# 85                                abstract
# 88                        ac s contractors
# 90                 aca computer integrator
# 92                        acacia financial
# 95               accelerated land transfer
# 97               access personnel services
# 99    accessibility modification solutions
# 102  accord mechanical management services
# 104                    accountants for you
# 107                  accu fire fabrication
# 110                               accustar
# 115                        ack contracting
# 117                            acme supply
# 119                         acorn services
# 121              acp demolition remodeling
# 126                               acutedge
# 129           adames professional services
# 131                     adaptive resources
# 133                      adcon consultants
# 136              adept consulting services
# 139                      adkins management
# 142                    admiral integration
# 144            adolphues building services
# 148            advanced disposal solutions
# 150             advanced hydraulic systems
# 152         advanced infrastructure design
# 154                   advanced integration
#
#                                right_side  similairity
# 1                  119 degrees architects     1.000000
# 8                24 hour cleaning service     0.984480
# 10                         259 strategies     1.000000
# 15                            4u services     1.000000
# 19                         521 management     1.000000
# 21                   6 degrees consulting     1.000000
# 23                      84 lumber company     1.000000
# 25                    a a court reporting     1.000000
# 29             a c environmental services     1.000000
# 31                           a i security     1.000000
# 37                           architecture     0.800316
# 40                         a best vending     1.000000
# 42                       a m e mechanical     1.000000
# 44                   consulting engineers     0.842319
# 47                     a lee cook hauling     1.000000
# 49                         d a m electric     0.911652
# 51                           t m painting     0.877573
# 53                           g c advisors     0.839451
# 55                   am truck auto repair     0.920130
# 58                   russell construction     0.848516
# 60                     av rental services     0.800547
# 63       all pro carpet cleaning services     0.801799
# 65      aaaa office and warehouse surplus     0.938333
# 67                           aarch realty     0.843033
# 72                    abbadon corporation     1.000000
# 74                             abbi print     1.000000
# 76                     abbonizio transfer     1.000000
# 78                       abc construction     1.000000
# 80            abc multi language services     1.000000
# 85                               abstract     1.000000
# 88                        l s contractors     0.827689
# 90                   computer integration     0.813501
# 92                       acacia financial     1.000000
# 95              accelerated land transfer     1.000000
# 97              access personnel services     1.000000
# 99   accessibility modification solutions     1.000000
# 102    accord mechanical management servi     0.967023
# 104                   accountants for you     1.000000
# 107                 accu fire fabrication     1.000000
# 110                              accustar     1.000000
# 115                       ack contracting     1.000000
# 117                           acme supply     1.000000
# 119                        acorn services     1.000000
# 121             acp demolition remodeling     1.000000
# 126                              acutedge     1.000000
# 129                 professional services     0.834793
# 131                    adaptive resources     1.000000
# 133                     adcon consultants     1.000000
# 136                 adept consulting serv     0.934368
# 139                     adkins management     1.000000
# 142                   admiral integration     1.000000
# 144           adolphues building services     1.000000
# 148           advanced disposal solutions     1.000000
# 150            advanced hydraulic systems     1.000000
# 152        advanced infrastructure design     1.000000
# 154                  advanced integration     1.000000

# %% [markdown]
# <a id="tfidf85"></a>
# ### TF-IDF with different score-cutoff 85

# %%
# TF-IDF on company_name with 80 score-cutoff
combined = cleaned_mini_registry.append(cleaned_license, sort=False)

# transform to matrix
from sklearn.feature_extraction.text import TfidfVectorizer

company_names = combined['company_name'].values.astype('U')
vectorizer = TfidfVectorizer(min_df=1, analyzer=ngrams)
tf_idf_matrix = vectorizer.fit_transform(company_names)

# calculate cosine similarity
import time
t1 = time.time()
matches = awesome_cossim_top(tf_idf_matrix, tf_idf_matrix.transpose(), 2, 0.85)
t = time.time() - t1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-b5db9493b850> in <module>
#       1 # TF-IDF on company_name with 80 score-cutoff
# ----> 2 combined = cleaned_mini_registry.append(cleaned_license, sort=False)
#       3
#       4 # transform to matrix
#       5 from sklearn.feature_extraction.text import TfidfVectorizer
#
# NameError: name 'cleaned_mini_registry' is not defined

# %%
print('Execution time for cossim 85: ', t/60, ' minute')
# Out:
# Execution time for cossim 85:  1.6140947222709656  minute

# %%
matches_df = get_matches_df(matches, company_names, top=1000)

# %%
# last company name of clean_mini_registry
last_index = len(cleaned_mini_registry) - 1
last_company_name = cleaned_mini_registry.loc[last_index, 'company_name']
last_company_index_to_consider = matches_df.loc[matches_df['left_side'] == last_company_name].index.tolist()[-1] # this should be the cutting line of matrix mult

# %%
matches_df = matches_df[:last_company_index_to_consider + 1]

filter_matches = matches_df.duplicated(subset='left_side', keep='first') # all duplicates except their first occurrence will be marked as True

filter_matches = matches_df[filter_matches]

print('TF-IDF match: ', len(filter_matches), ' out of ', len(cleaned_mini_registry))
# Out:
# TF-IDF match:  46  out of  100

# %%
filter_matches
# Out:
#                                  left_side  \
# 1                   119 degrees architects
# 8                24 hour cleaning services
# 10                          259 strategies
# 15                             4u services
# 19                          521 management
# 21                    6 degrees consulting
# 23                       84 lumber company
# 25                     a a court reporting
# 29              a c environmental services
# 31                            a i security
# 39                          a best vending
# 41                        a m e mechanical
# 45                      a lee cook hauling
# 47                            a m electric
# 49                            a m painting
# 52                   a m truck auto repair
# 59           aaaa office warehouse surplus
# 65                     abbadon corporation
# 67                              abbi print
# 69                      abbonizio transfer
# 71                        abc construction
# 73             abc multi language services
# 78                                abstract
# 83                        acacia financial
# 86               accelerated land transfer
# 88               access personnel services
# 90    accessibility modification solutions
# 93   accord mechanical management services
# 95                     accountants for you
# 98                   accu fire fabrication
# 101                               accustar
# 106                        ack contracting
# 108                            acme supply
# 110                         acorn services
# 112              acp demolition remodeling
# 117                               acutedge
# 121                     adaptive resources
# 123                      adcon consultants
# 126              adept consulting services
# 129                      adkins management
# 132                    admiral integration
# 134            adolphues building services
# 138            advanced disposal solutions
# 140             advanced hydraulic systems
# 142         advanced infrastructure design
# 144                   advanced integration
#
#                                right_side  similairity
# 1                  119 degrees architects     1.000000
# 8                24 hour cleaning service     0.984480
# 10                         259 strategies     1.000000
# 15                            4u services     1.000000
# 19                         521 management     1.000000
# 21                   6 degrees consulting     1.000000
# 23                      84 lumber company     1.000000
# 25                    a a court reporting     1.000000
# 29             a c environmental services     1.000000
# 31                           a i security     1.000000
# 39                         a best vending     1.000000
# 41                       a m e mechanical     1.000000
# 45                     a lee cook hauling     1.000000
# 47                         d a m electric     0.911652
# 49                           t m painting     0.877573
# 52                   am truck auto repair     0.920130
# 59      aaaa office and warehouse surplus     0.938333
# 65                    abbadon corporation     1.000000
# 67                             abbi print     1.000000
# 69                     abbonizio transfer     1.000000
# 71                       abc construction     1.000000
# 73            abc multi language services     1.000000
# 78                               abstract     1.000000
# 83                       acacia financial     1.000000
# 86              accelerated land transfer     1.000000
# 88              access personnel services     1.000000
# 90   accessibility modification solutions     1.000000
# 93     accord mechanical management servi     0.967023
# 95                    accountants for you     1.000000
# 98                  accu fire fabrication     1.000000
# 101                              accustar     1.000000
# 106                       ack contracting     1.000000
# 108                           acme supply     1.000000
# 110                        acorn services     1.000000
# 112             acp demolition remodeling     1.000000
# 117                              acutedge     1.000000
# 121                    adaptive resources     1.000000
# 123                     adcon consultants     1.000000
# 126                 adept consulting serv     0.934368
# 129                     adkins management     1.000000
# 132                   admiral integration     1.000000
# 134           adolphues building services     1.000000
# 138           advanced disposal solutions     1.000000
# 140            advanced hydraulic systems     1.000000
# 142        advanced infrastructure design     1.000000
# 144                  advanced integration     1.000000

# %% [markdown]
# ## Full Dataset with TF-IDF

# %%
all_company_names = pd.concat([registry['company_name'].dropna(), license['company_name'].dropna()]).unique()

# %%
len(all_company_names)
# Out:
# 201279

# %%
# transform to matrix
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(min_df=1, analyzer=ngrams)
tf_idf_matrix = vectorizer.fit_transform(all_company_names)

# calculate cosine similarity
import time
t1 = time.time()
matches = awesome_cossim_top(tf_idf_matrix, tf_idf_matrix.transpose(), 2, 0.85)
t = time.time() - t1

# %%
print('Execution time for cossim 85: ', t, ' sec')
# Out:
# Execution time for cossim 85:  140.76658654212952  sec

# %%
matches
# Out:
# <201279x201279 sparse matrix of type '<class 'numpy.float64'>'
# 	with 214803 stored elements in Compressed Sparse Row format>

# %%
matches_df = get_matches_df(matches, all_company_names, top=1000000)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-28-0856bdfa9781> in <module>
# ----> 1 matches_df = get_matches_df(matches, all_company_names, top=1000000)
#
# <ipython-input-24-4cedae86b276> in get_matches_df(sparse_matrix, name_vector, top)
#      15
#      16     for index in range(0, nr_matches):
# ---> 17         left_side[index] = name_vector[sparserows[index]]
#      18         right_side[index] = name_vector[sparsecols[index]]
#      19         similairity[index] = sparse_matrix.data[index]
#
# IndexError: index 214803 is out of bounds for axis 0 with size 214803

# %%
# last company name of clean_mini_registry
last_index = len(cleaned_mini_registry) - 1
last_company_name = cleaned_mini_registry.loc[last_index, 'company_name']
last_company_index_to_consider = matches_df.loc[matches_df['left_side'] == last_company_name].index.tolist()[-1] # this should be the cutting line of matrix mult

# %%
matches_df = matches_df[:last_company_index_to_consider + 1]

filter_matches = matches_df.duplicated(subset='left_side', keep='first') # all duplicates except their first occurrence will be marked as True

filter_matches = matches_df[filter_matches]

print('TF-IDF match: ', len(filter_matches), ' out of ', len(cleaned_mini_registry))
# Out:
# TF-IDF match:  46  out of  100

# %% [markdown]
# <a id="cossimsklarn"></a>
# ## Test Cosine Similary with sklearn

# %%
# from sklearn.metrics.pairwise import cosine_similarity
# t1 = time.time()
# cosine_similarity(tf_idf_matrix, tf_idf_matrix)
# t = time.time() - t1

# %%
############################################################

# %%
# TF-IDF on company_name with 80 score-cutoff
combined = cleaned_mini_registry.append(cleaned_license, sort=False)

# transform to matrix
from sklearn.feature_extraction.text import TfidfVectorizer

company_names = combined['company_name'].values.astype('U')
vectorizer = TfidfVectorizer(min_df=1, analyzer=ngrams)
tf_idf_matrix = vectorizer.fit_transform(company_names)

# calculate cosine similarity
import time
t1 = time.time()
matches = awesome_cossim_top(tf_idf_matrix, tf_idf_matrix.transpose(), 10, 0.85)
t = time.time() - t1

# %%
print('Execution time for cossim 90:', t, 'sec')
# Out:
# Execution time for cossim 90: 99.12980008125305 sec

# %%
# time for fuzzywuzzy for whole registry data

# clean company_name and dba name
ignore = ['inc', 'group', 'llc', 'corp', 'pc', 'incorporated', 'ltd', 'co']
cleaned_registry = skool.clean_strings(registry, ['company_name', 'dba_name'], True, ignore)
cleaned_license = skool.clean_strings(license, ['company_name'], True, ignore)

cleaned_registry = cleaned_registry.drop_duplicates(subset='company_name', keep='first', inplace=False)

# %%
import time
t1 = time.time()
merged = (
    skool.fuzzy_merge(cleaned_registry, cleaned_license, on="company_name", score_cutoff=95)
    .pipe(skool.fuzzy_merge, cleaned_mini_registry, cleaned_license, left_on="dba_name", right_on="company_name", score_cutoff=95)
)
t = time.time() - t1
matched = merged.dropna(subset=['company_name_y'])

print('Fuzzywuzzy match: ', len(matched), 'out of', len(cleaned_registry))

print('Execution fuzzywuzzy match: ', t/60, ' minute')
# Out:
# Fuzzywuzzy match:  1353 out of 3117
# Execution fuzzywuzzy match:  14.572765370210012  minute

# %%
###########################################################

# %%
# def filterMatches(df):
#     for i in range(1, len(df)):
#         print(matches_df[i]['left_side'])

# %%
# filterMatches(matches_df)

# %%
# matches_df = matches_df[matches_df['similairity'] < 0.99999] # Remove all exact matches
# len(matches_df)

# %%
# matches_df.to_excel (r'C:\Users\dabinlee\Desktop\mwdsbe\data\TFIDF.xlsx', index = None, header=True)

# %%
# mini_combined = clean_mini_registry.append(clean_license[:50], sort=False)

# %%
# company_names = mini_combined['company_name']
# vectorizer = TfidfVectorizer(min_df=1, analyzer=ngrams)
# tf_idf_matrix = vectorizer.fit_transform(company_names.values.astype('U'))

# %%
# matches = cosine_similarity(tf_idf_matrix, tf_idf_matrix)

# %%
# matches_df = get_matches_df(matches, company_names) # subview error

# %%
# matches_df

# %%
# matches_df = matches_df[matches_df['similairity'] < 0.99999] # Remove all exact matches
# matches_df

# %% [markdown]
# ## Comparing two different datasets using K nearst N

# %%
# Transform messy data into tdidf matrix

# %%
# from sklearn.metrics.pairwise import cosine_similarity
# from sklearn.feature_extraction.text import TfidfVectorizer

# # clean data: clean_mini_registry
# clean_names = clean_mini_registry['company_name']
# # messy data: clean_license

# vectorizer = TfidfVectorizer(min_df=1, analyzer=ngrams, lowercase=False)
# tfidf = vectorizer.fit_transform(clean_names)

# from sklearn.neighbors import NearestNeighbors
# nbrs = NearestNeighbors(n_neighbors=1, n_jobs=-1).fit(tfidf)

# messy_names = clean_license['company_name'].values

# ### matching query:
# def getNearestN(query):
#   queryTFIDF_ = vectorizer.transform(query)
#   distances, indices = nbrs.kneighbors(queryTFIDF_)
#   return distances, indices

# distances, indices = getNearestN(messy_names.astype('U')) # getting nearest n

# # creating df
# index = [i for i in range(5)]
# columns = ['score', 'clean', 'messy']
# matches = pd.DataFrame(index=index, columns=columns)

# for i,j in enumerate(indices):
#     j = j[0]
#     matches[j]['score'] = round(distances[i][0],2)
#     matches[j]['clean'] = clean_names.values[j][0][0]
#     matches[j]['messy'] = messy_names[i]

# %%
# matches[0][0] = 0

# %%
#matches[matches['Match confidence (lower is better)'] < 0.1]

# %%
# len(clean_names)
