# %%
import mwdsbe
import mwdsbe.datasets.licenses as licenses
import schuylkill as skool
import numpy as np

# %%
registry = mwdsbe.load_registry()

# %%
len(registry)
# Out:
# 3119

# %%
license = licenses.CommercialActivityLicenses().download()

# %%
len(license)
# Out:
# 203121

# %%
def exact_match(data1, data2, on, how):
    if how not in ["exact", "contains", "startswith"]:
        raise ValueError("how should be one of: 'exact', 'contains', 'startswith'")
    
    merged = skool.exact_merge(data1, data2, on=on, how=how)
    matched = merged.dropna(subset=['company_name_y'])
    
    return len(matched) / len(data1) * 100

# %%
# find max target score cutoff using binary search
def find_max_fuzzy_match_score(data1, data2, target):
    
    total_n = len(data1)
    
    # binary search
    start = 0
    end = 100
    
    maxScore = -1
    
    while start <= end:
        mid = (start + end) / 2;
        
        fuzzy_merged = skool.fuzzy_merge(data1, data2, on="company_name", score_cutoff=mid)
        fuzzy_matched = fuzzy_merged.dropna(subset=['company_name_y'])
        match_n = len(fuzzy_matched)
        
        match_prop = match_n / total_n
        
        if match_prop == target:
            start = mid + 1
            maxScore = mid
            matched = True
        elif match_prop < target:
            end = mid - 1
        else:
            start = mid + 1
    
    return maxScore

# %%
exact_match(registry, license, on="company_name", how="exact")
# Out:
# 4.039756332157743

# %%
exact_match(registry, license, on="company_name", how="contains")
# Out:
# C:\Users\dabinlee\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\strings.py:1843: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
# 5.706957358127605

# %%
exact_match(registry, license, on="company_name", how="startswith")
# Out:
# 5.45046489259378

# %%
# test for the first 100 registry data
mini_registry = registry[:100]

# %%
# clean punctuation & ignore "inc", "group" "llc"
# cleaned_mini_registry = skool.clean_strings(mini_registry, ['company_name'],True, ['inc', 'group', 'llc', ' '])
# cleaned_license = skool.clean_strings(license, ['company_name'], True, ['inc', 'group', 'llc', ' '])

# clean company_name and dba name
ignore = ['inc', 'group', 'llc', 'corp', 'pc', 'incorporated', 'ltd']
cleaned_mini_registry = skool.clean_strings(mini_registry, ['company_name', 'dba_name'], True, ignore)
cleaned_license = skool.clean_strings(license, ['company_name'], True, ignore)

# %%
find_max_fuzzy_match_score(cleaned_mini_registry, cleaned_license, 1)
# Out:
# 56.375

# %%
merged = skool.fuzzy_merge(cleaned_mini_registry, cleaned_license, on="company_name", score_cutoff=56.375)
matched = merged.dropna(subset=["company_name_y"])
matched
# Out:
#                                  company_name_x    dba_name owner_first  \
# 0                        119 degrees architects         NaN      Rafael
# 1                                       12bravo         NaN     JEFFREY
# 2                          1st choice financial    provisio    Kathrina
# 3                                  212 harakawa  two twelve         Ann
# 4                           215 media solutions         NaN      Dewain
# ..                                          ...         ...         ...
# 95  advance detective bureau t a d o richardson         NaN       David
# 96                  advanced disposal solutions         NaN     Suzanne
# 97                   advanced hydraulic systems         NaN      Judith
# 98               advanced infrastructure design         NaN      Mojgan
# 99                         advanced integration         NaN       Donna
#
#     owner_last                      location  location_city location_state  \
# 0       Utrera  1503 Green Street, Suite # 4   Philadelphia             PA
# 1    YEKENCHIK           236 McKendimen Road  Medford Lakes             NJ
# 2        Nease            133 N. 21st Street      Camp Hill             PA
# 3     Harakawa  236 W 27th Street, Suite 802       New York             NY
# 4      Johnson             810 Felton Avenue    Sharon Hill             PA
# ..         ...                           ...            ...            ...
# 95  Richardson  10 East Chestnut Hill Avenue   Philadelphia             PA
# 96     Dolaway             2200 Adams Avenue   Philadelphia             PA
# 97        Ward           727 East 9th Street        Chester             PA
# 98  Mohtashami            1 Crossroads Drive       Hamilton             NJ
# 99     Chappel     1 McCormick Road, Suite A   Mckees Rocks             PA
#
#     zip_code               mailing_address   mailing_city  ...  \
# 0    19130.0  1503 Green Street, Suite # 4   Philadelphia  ...
# 1     8055.0           236 McKendimen Road  Medford Lakes  ...
# 2    17011.0            133 N. 21st Street      Camp Hill  ...
# 3    10001.0  236 W 27th Street, Suite 802       New York  ...
# 4    19079.0             810 Felton Avenue    Sharon Hill  ...
# ..       ...                           ...            ...  ...
# 95   19118.0  10 East Chestnut Hill Avenue   Philadelphia  ...
# 96   19124.0             2200 Adams Avenue   Philadelphia  ...
# 97   19013.0           727 East 9th Street        Chester  ...
# 98    8691.0            1 Crossroads Drive       Hamilton  ...
# 99   15136.0     1 McCormick Road, Suite A   Mckees Rocks  ...
#
#          location_standard        lat        lng                    geometry  \
# 0            1503 GREEN ST  39.964275 -75.163042  POINT (-75.16304 39.96427)
# 1                      NaN        NaN        NaN                        None
# 2                      NaN        NaN        NaN                        None
# 3                      NaN        NaN        NaN                        None
# 4                      NaN        NaN        NaN                        None
# ..                     ...        ...        ...                         ...
# 95  10 E CHESTNUT HILL AVE  40.078136 -75.209818  POINT (-75.20982 40.07814)
# 96          2200 ADAMS AVE  40.005190 -75.087504  POINT (-75.08750 40.00519)
# 97                     NaN        NaN        NaN                        None
# 98                     NaN        NaN        NaN                        None
# 99                     NaN        NaN        NaN                        None
#
#     match_probability  right_index license_num            issue_date  \
# 0                1.00     131113.0      480115  2009-07-31T00:00:00Z
# 1                0.93     200625.0      815623  2019-06-17T00:00:00Z
# 2                0.83      37281.0      174332  2004-10-12T00:00:00Z
# 3                0.60      99973.0      334667  2005-08-30T00:00:00Z
# 4                0.83     123871.0      444271  2008-05-06T00:00:00Z
# ..                ...          ...         ...                   ...
# 95               0.72     180050.0      725552  2017-01-12T00:00:00Z
# 96               1.00     126252.0      135111  2008-08-22T00:00:00Z
# 97               1.00      10624.0      104763  1997-07-07T00:00:00Z
# 98               1.00     173126.0      689813  2016-01-28T00:00:00Z
# 99               1.00      29527.0      152902  2003-03-03T00:00:00Z
#
#     license_status                  company_name_y
# 0           Active          119 degrees architects
# 1           Active                        12 bravo
# 2           Active           omni choice financial
# 3           Active                        1225 raw
# 4           Active               medical solutions
# ..             ...                             ...
# 95          Active        advance detective bureau
# 96          Active     advanced disposal solutions
# 97          Active      advanced hydraulic systems
# 98          Active  advanced infrastructure design
# 99          Active            advanced integration
#
# [100 rows x 26 columns]

# %%
export_excel = matched.to_excel (r'C:\Users\dabinlee\Desktop\mwdsbe\data\clean_fuzzy_merge_56.xlsx', index = None, header=True)

# %%
exact_match(cleaned_mini_registry, cleaned_license, on="company_name", how="exact")
# Out:
# 40.0

# %%
exact_match(cleaned_mini_registry, cleaned_license, on="company_name", how="contains")
# Out:
# 631.0

# %%
exact_match(cleaned_mini_registry, cleaned_license, on="company_name", how="startswith")
# Out:
# 248.0

# %%
merged = skool.fuzzy_merge(cleaned_mini_registry, cleaned_license, on="company_name", score_cutoff=95)
matched = merged.dropna(subset=["company_name_y"])
matched
# Out:
#                            company_name_x                         dba_name  \
# 0                  119 degrees architects                              NaN
# 5                                      22                              NaN
# 7               24 hour cleaning services                              NaN
# 8                          259 strategies                              NaN
# 12                            4u services                 stellar services
# 15                         521 management                              NaN
# 16                   6 degrees consulting                              NaN
# 17                      84 lumber company                84 lumber company
# 18                    a a court reporting                   andrea st john
# 21             a c environmental services                              NaN
# 22                           a i security                              NaN
# 25                         a bob s towing                              NaN
# 29                         a best vending    a best vending coffee service
# 30                       a m e mechanical                              NaN
# 33                     a lee cook hauling                              NaN
# 34                           a m electric                              NaN
# 35                           a m painting                              NaN
# 37                  a m truck auto repair                              NaN
# 40                    a v rental services                              NaN
# 48                    abbadon corporation        superior facility service
# 49                             abbi print                              NaN
# 50                     abbonizio transfer                              NaN
# 51                    abc construction co                              NaN
# 52            abc multi language services                              NaN
# 56                               abstract                              NaN
# 58                       ac s contractors                              NaN
# 60                       acacia financial                              NaN
# 62              accelerated land transfer                              NaN
# 63              access personnel services                              NaN
# 64   accessibility modification solutions                              NaN
# 66  accord mechanical management services                              NaN
# 67                    accountants for you                              NaN
# 69                  accu fire fabrication                              NaN
# 71                               accustar                        touch pro
# 75                        ack contracting                  ack contracting
# 77                         acorn services                              NaN
# 78              acp demolition remodeling                              NaN
# 82                               acutedge                              NaN
# 85                     adaptive resources                              NaN
# 86                      adcon consultants                              NaN
# 89                        adg enterprises                              NaN
# 90                      adkins management                              NaN
# 92                    admiral integration                              NaN
# 93            adolphues building services  servicemaster janitorial by abs
# 96            advanced disposal solutions                              NaN
# 97             advanced hydraulic systems                              NaN
# 98         advanced infrastructure design                              NaN
# 99                   advanced integration                              NaN
#
#      owner_first          owner_last  \
# 0         Rafael              Utrera
# 5       Caroline              Harper
# 7   Mary Colleen           Zoltowski
# 8          Chaka         Fattah, Jr.
# 12         Liang                Chen
# 15          Kris              Bowman
# 16        Robert              Lawson
# 17      Margaret          Hardy-Knox
# 18        Andrea            St. John
# 21    ANTOINETTE             PATRICK
# 22       RAYMOND             ALVAREZ
# 25        Mikina            Harrison
# 29           Sue             Epstein
# 30        Alfred          Edmunds Jr
# 33           Amy            Lee-Cook
# 34       Anthony            Muhammad
# 35      Abdullah            Muhammad
# 37         CATHY  MATARAZZO-NICHOLAS
# 40         Bruce             Johnson
# 48         Donna               Cohen
# 49     Abdoulaye           Coumbassa
# 50         Karen           Abbonizio
# 51      KIMBERLY              NUGENT
# 52       Chankia       Hourn-Quigley
# 56     Daniel S.              Kebede
# 58         Megan          Caldarelli
# 60        Noreen               White
# 62        Marsha                Wolf
# 63        Tyrone              Miller
# 64      Stamatia        Papanikolaou
# 66        Ulrick              Joseph
# 67        Marcia               Libes
# 69       Deardra              Murphy
# 71      Lisa Ann            Mariotti
# 75        Brenda             Kellogg
# 77       Deborah      Proctor LePera
# 78    Dee-Thomas               Jones
# 82       Sandeep               Banga
# 85        Eliseo           Rodriguez
# 86      Lawrence               Dibor
# 89         Diana           Patterson
# 90        Sheila              Adkins
# 92      Katiusca             McEntee
# 93       ANTONIE           ADOLPHUES
# 96       Suzanne             Dolaway
# 97        Judith                Ward
# 98        Mojgan          Mohtashami
# 99         Donna             Chappel
#
#                                              location    location_city  \
# 0                        1503 Green Street, Suite # 4     Philadelphia
# 5                                     757 Public Road        Bethlehem
# 7                               14005 Barcalow Street     Philadelphia
# 8                        Two Logan Square, Suite 1900     Philadelphia
# 12                     70 West 36th Street, Ste. #702         New York
# 15                         1000 1st Avenue, Suite 104  King Of Prussia
# 16                      6545 Hamiton Avenue, Suite 1A       Ptttsburgh
# 17                                     1019 Route 519      Eighty Four
# 18                  303 Chestnut Street, Second Floor     Philadelphia
# 21                         2045 NORTH LAWRENCE STREET     Philadelphia
# 22                               10234 Dedater Street     Philadelphia
# 25                               2220 Orthodox Street     Philadelphia
# 29                                      7336 State Rd     Philadelphia
# 30                                6123 Washington Ave     Philadelphia
# 33                                643 Pennfield Drive         Hatfield
# 34                            2222 N. Marshall Street     Philadelphia
# 35                           2745 North Garnet Street     Philadelphia
# 37                                14065 Townsend Road     Philadelphia
# 40                                  4039 Comly Street     Philadelphia
# 48                                  712 Bigler Street     Philadelphia
# 49                                 321 S. 60th Street     Philadelphia
# 50      416E S. Governor Printz Boulevard, PO Box 166           Lester
# 51                                 714 Dunksferry Rd.         Bensalem
# 52                  901 North Penn Street, Suite 1504     Philadelphia
# 56                                   1734 Chiswick CT    Silver Spring
# 58                                7173 Charles Street     Philadelphia
# 60              6000 Midlantic Drive, Suite 410 North       Mt. Laurel
# 62                     1845 Walnut Street, 25th Floor     Philadelphia
# 63                           38 - 42 W. Orange Street        Lancaster
# 64                     2818 E. Allegheny Ave, 2nd  Fl     Philadelphia
# 66                            218 E Washington Street       Norristown
# 67                                        PO Box 1040      Cherry Hill
# 69                                   8 Progress Drive      Morrisville
# 71                        3060 Plaza Drive, Suite 101    Garnet Valley
# 75                             18 Campus Blvd Ste 100   Newtown Square
# 77                      3553 West Chester Pike, # 401   Newtown Square
# 78                               720 Pines Wood Drive       Middletown
# 82                  5 Great Valley Parkway, Suite 210          Malvern
# 85                                104 Broadway Street         Carnegie
# 86  2465 North 50th Street Bala Building, Suite #1...     Philadelphia
# 89         3479 Lawrenceville - Suwanee Road, Suite B          Suwanee
# 90                                4113 Colonial Court     Valley Forge
# 92                                 1001 Route 70 West      Cherry Hill
# 93                             5530 Litchfield Street     Philadelphia
# 96                                  2200 Adams Avenue     Philadelphia
# 97                                727 East 9th Street          Chester
# 98                                 1 Crossroads Drive         Hamilton
# 99                          1 McCormick Road, Suite A     Mckees Rocks
#
#    location_state  zip_code  \
# 0              PA   19130.0
# 5              PA   18015.0
# 7              PA   19116.0
# 8              PA   19103.0
# 12             NY   10018.0
# 15             PA   19406.0
# 16             PA   15206.0
# 17             PA   15330.0
# 18             PA   19106.0
# 21             PA   19122.0
# 22             PA   19116.0
# 25             PA   19137.0
# 29             PA   19136.0
# 30             PA   19143.0
# 33             PA   19440.0
# 34             PA   19133.0
# 35             PA   19132.0
# 37             PA   19154.0
# 40             PA   19135.0
# 48             PA   19148.0
# 49             PA   19143.0
# 50             PA   19029.0
# 51             PA   19020.0
# 52             PA   19123.0
# 56             MD   20904.0
# 58             PA   19135.0
# 60             NJ    8054.0
# 62             PA   19103.0
# 63             PA   17603.0
# 64             PA   19134.0
# 66             PA   19401.0
# 67             NJ    8034.0
# 69             PA   19067.0
# 71             PA   19060.0
# 75             PA   19073.0
# 77             PA   19073.0
# 78             DE   19709.0
# 82             PA   19355.0
# 85             PA   15104.0
# 86             PA   19131.0
# 89             GA   30024.0
# 90             PA   19403.0
# 92             NJ    8002.0
# 93             PA   19143.0
# 96             PA   19124.0
# 97             PA   19013.0
# 98             NJ    8691.0
# 99             PA   15136.0
#
#                                       mailing_address     mailing_city  ...  \
# 0                        1503 Green Street, Suite # 4     Philadelphia  ...
# 5                                     757 Public Road        Bethlehem  ...
# 7                               14005 Barcalow Street     Philadelphia  ...
# 8                        Two Logan Square, Suite 1900     Philadelphia  ...
# 12                     70 West 36th Street, Ste. #702         New York  ...
# 15                         1000 1st Avenue, Suite 104  King Of Prussia  ...
# 16                      6545 Hamiton Avenue, Suite 1A       Ptttsburgh  ...
# 17                                     1019 Route 519      Eighty Four  ...
# 18                               P.O. Box 74, Suite 4       Moorestown  ...
# 21                         2045 NORTH LAWRENCE STREET     Philadelphia  ...
# 22                               10234 Dedater Street     Philadelphia  ...
# 25                               2220 Orthodox Street     Philadelphia  ...
# 29                                      7336 State Rd     Philadelphia  ...
# 30                                6123 Washington Ave     Philadelphia  ...
# 33                                643 Pennfield Drive         Hatfield  ...
# 34                            2222 N. Marshall Street     Philadelphia  ...
# 35                           2745 North Garnet Street     Philadelphia  ...
# 37                                14065 Townsend Road     Philadelphia  ...
# 40                                  4039 Comly Street     Philadelphia  ...
# 48                                      712 Bigler St     Philadelphia  ...
# 49                                 321 S. 60th Street     Philadelphia  ...
# 50                  416E S. Governor Printz Boulevard           Lester  ...
# 51                                 714 Dunksferry Rd.         Bensalem  ...
# 52                  901 North Penn Street, Suite 1504     Philadelphia  ...
# 56                                   1734 Chiswick CT    Silver Spring  ...
# 58                                7173 Charles Street     Philadelphia  ...
# 60              6000 Midlantic Drive, Suite 410 North       Mt. Laurel  ...
# 62                     1845 Walnut Street, 25th Floor     Philadelphia  ...
# 63                           38 - 42 W. Orange Street        Lancaster  ...
# 64                      2818 E. Allegheny Ave, 2nd Fl     Philadelphia  ...
# 66                            218 E Washington Street       Norristown  ...
# 67                                        PO Box 1040      Cherry Hill  ...
# 69                                   8 Progress Drive      Morrisville  ...
# 71                        3060 Plaza Drive, Suite 101    Garnet Valley  ...
# 75                             18 Campus Blvd Ste 100   Newtown Square  ...
# 77                      3553 West Chester Pike, # 401   Newtown Square  ...
# 78                               720 Pines Wood Drive       Middletown  ...
# 82                  5 Great Valley Parkway, Suite 210          Malvern  ...
# 85                                104 Broadway Street         Carnegie  ...
# 86  2465 North 50th Street Bala Building, Suite #1...     Philadelphia  ...
# 89         3479 Lawrenceville - Suwanee Road, Suite B          Suwanee  ...
# 90                                4113 Colonial Court     Valley Forge  ...
# 92                                 1001 Route 70 West      Cherry Hill  ...
# 93                             5530 Litchfield Street     Philadelphia  ...
# 96                                  2200 Adams Avenue     Philadelphia  ...
# 97                                727 East 9th Street          Chester  ...
# 98                                 1 Crossroads Drive         Hamilton  ...
# 99                          1 McCormick Road, Suite A     Mckees Rocks  ...
#
#        location_standard        lat        lng                    geometry  \
# 0          1503 GREEN ST  39.964275 -75.163042  POINT (-75.16304 39.96427)
# 5                    NaN        NaN        NaN                        None
# 7      14005 BARCALOW ST  40.131349 -75.014284  POINT (-75.01428 40.13135)
# 8       100-20 N 18TH ST  39.955726 -75.169784  POINT (-75.16978 39.95573)
# 12                   NaN        NaN        NaN                        None
# 15                   NaN        NaN        NaN                        None
# 16                   NaN        NaN        NaN                        None
# 17                   NaN        NaN        NaN                        None
# 18       303 CHESTNUT ST  39.948849 -75.146173  POINT (-75.14617 39.94885)
# 21    2045 N LAWRENCE ST  39.982290 -75.141137  POINT (-75.14114 39.98229)
# 22      10234 DEDATER ST  40.106057 -75.018803  POINT (-75.01880 40.10606)
# 25      2220 ORTHODOX ST  40.008166 -75.078701  POINT (-75.07870 40.00817)
# 29         7336 STATE RD  40.026532 -75.030907  POINT (-75.03091 40.02653)
# 30   6123 WASHINGTON AVE  39.948499 -75.246577  POINT (-75.24658 39.94850)
# 33                   NaN        NaN        NaN                        None
# 34    2222 N MARSHALL ST  39.985489 -75.144539  POINT (-75.14454 39.98549)
# 35      2745 N GARNET ST  39.996079 -75.162692  POINT (-75.16269 39.99608)
# 37     14065 TOWNSEND RD  40.108419 -74.975170  POINT (-74.97517 40.10842)
# 40         4039 COMLY ST  40.025665 -75.065982  POINT (-75.06598 40.02566)
# 48         712 BIGLER ST  39.912636 -75.161093  POINT (-75.16109 39.91264)
# 49         321 S 60TH ST  39.955801 -75.241786  POINT (-75.24179 39.95580)
# 50                   NaN        NaN        NaN                        None
# 51                   NaN        NaN        NaN                        None
# 52         901 N PENN ST  39.961707 -75.134510  POINT (-75.13451 39.96171)
# 56                   NaN        NaN        NaN                        None
# 58       7173 CHARLES ST  40.034781 -75.042004  POINT (-75.04200 40.03478)
# 60                   NaN        NaN        NaN                        None
# 62        1845 WALNUT ST  39.950665 -75.171552  POINT (-75.17155 39.95067)
# 63                   NaN        NaN        NaN                        None
# 64  2818 E ALLEGHENY AVE  39.982439 -75.101489  POINT (-75.10149 39.98244)
# 66                   NaN        NaN        NaN                        None
# 67                   NaN        NaN        NaN                        None
# 69                   NaN        NaN        NaN                        None
# 71                   NaN        NaN        NaN                        None
# 75                   NaN        NaN        NaN                        None
# 77                   NaN        NaN        NaN                        None
# 78                   NaN        NaN        NaN                        None
# 82                   NaN        NaN        NaN                        None
# 85                   NaN        NaN        NaN                        None
# 86        2465 N 50TH ST  39.999592 -75.227267  POINT (-75.22727 39.99959)
# 89                   NaN        NaN        NaN                        None
# 90                   NaN        NaN        NaN                        None
# 92                   NaN        NaN        NaN                        None
# 93    5530 LITCHFIELD ST  39.940602 -75.228043  POINT (-75.22804 39.94060)
# 96        2200 ADAMS AVE  40.005190 -75.087504  POINT (-75.08750 40.00519)
# 97                   NaN        NaN        NaN                        None
# 98                   NaN        NaN        NaN                        None
# 99                   NaN        NaN        NaN                        None
#
#     match_probability  right_index license_num            issue_date  \
# 0                1.00     131113.0      480115  2009-07-31T00:00:00Z
# 5                1.00     168704.0      667661  2015-06-10T00:00:00Z
# 7                0.98      17313.0      120711  1999-08-30T00:00:00Z
# 8                1.00     102418.0      346817  2005-11-28T00:00:00Z
# 12               1.00     141065.0      531189  2011-04-22T00:00:00Z
# 15               1.00      25999.0      136428  2002-03-08T00:00:00Z
# 16               1.00     171406.0      681851  2015-10-26T00:00:00Z
# 17               1.00     111889.0      393009  2006-11-30T00:00:00Z
# 18               1.00     154368.0      107405  2013-07-29T00:00:00Z
# 21               1.00     118976.0      122477  2007-09-07T00:00:00Z
# 22               1.00     174631.0      698635  2016-04-07T00:00:00Z
# 25               0.96     134134.0      134939  2010-02-04T00:00:00Z
# 29               1.00     110623.0      122115  2006-10-06T00:00:00Z
# 30               1.00     148551.0      569144  2012-07-18T00:00:00Z
# 33               1.00     176271.0      706507  2016-06-29T00:00:00Z
# 34               0.96      28702.0      154795  2002-11-27T00:00:00Z
# 35               0.96     118227.0      419397  2007-08-06T00:00:00Z
# 37               0.98      19860.0      131320  2000-05-25T00:00:00Z
# 40               0.97     118917.0      422259  2007-09-06T00:00:00Z
# 48               1.00     103079.0      019267  2005-12-23T00:00:00Z
# 49               1.00     152457.0      591018  2013-04-23T00:00:00Z
# 50               1.00     132216.0      132302  2009-10-15T00:00:00Z
# 51               1.00       1504.0      010250  1994-08-25T00:00:00Z
# 52               1.00     140709.0      529347  2011-04-01T00:00:00Z
# 56               1.00     182271.0      734777  2017-04-10T00:00:00Z
# 58               0.97      37485.0      190889  2004-10-25T00:00:00Z
# 60               1.00     129494.0      471078  2009-04-15T00:00:00Z
# 62               1.00     110107.0      383081  2006-09-19T00:00:00Z
# 63               1.00     135545.0      500487  2010-05-04T00:00:00Z
# 64               1.00     178833.0      719871  2016-11-15T00:00:00Z
# 66               0.96       8948.0      088671  1996-12-12T00:00:00Z
# 67               1.00     110637.0      387213  2006-10-10T00:00:00Z
# 69               1.00     135288.0      498981  2010-04-20T00:00:00Z
# 71               1.00     157073.0      613448  2013-12-27T00:00:00Z
# 75               1.00     197901.0      804592  2019-03-05T00:00:00Z
# 77               1.00     123258.0      001818  2008-04-08T00:00:00Z
# 78               1.00     180088.0      725597  2017-01-13T00:00:00Z
# 82               1.00     167451.0      661326  2015-04-16T00:00:00Z
# 85               1.00     169183.0      670235  2015-07-06T00:00:00Z
# 86               1.00      10622.0      104755  1997-07-07T00:00:00Z
# 89               0.97      32003.0      168981  2003-10-06T00:00:00Z
# 90               1.00      10717.0      100507  1997-07-16T00:00:00Z
# 92               1.00     151290.0      584611  2013-02-15T00:00:00Z
# 93               1.00     193949.0      788165  2018-09-05T00:00:00Z
# 96               1.00     126252.0      135111  2008-08-22T00:00:00Z
# 97               1.00      10624.0      104763  1997-07-07T00:00:00Z
# 98               1.00     173126.0      689813  2016-01-28T00:00:00Z
# 99               1.00      29527.0      152902  2003-03-03T00:00:00Z
#
#     license_status                        company_name_y
# 0           Active                119 degrees architects
# 5           Active                                    22
# 7           Active              24 hour cleaning service
# 8           Active                        259 strategies
# 12          Active                           4u services
# 15          Active                        521 management
# 16          Active                  6 degrees consulting
# 17          Active                     84 lumber company
# 18          Active                   a a court reporting
# 21          Active            a c environmental services
# 22          Active                          a i security
# 25          Active                         a bobs towing
# 29          Active                        a best vending
# 30          Active                      a m e mechanical
# 33          Active                    a lee cook hauling
# 34          Active                           am electric
# 35          Active                           am painting
# 37          Active                  am truck auto repair
# 40          Active                    av rental services
# 48          Active                   abbadon corporation
# 49          Active                            abbi print
# 50          Active                    abbonizio transfer
# 51          Active                   abc construction co
# 52          Active           abc multi language services
# 56          Active                              abstract
# 58          Active                       a s contractors
# 60          Active                      acacia financial
# 62          Active             accelerated land transfer
# 63          Active             access personnel services
# 64          Active  accessibility modification solutions
# 66          Active    accord mechanical management servi
# 67          Active                   accountants for you
# 69          Active                 accu fire fabrication
# 71          Active                              accustar
# 75          Active                       ack contracting
# 77          Active                        acorn services
# 78          Active             acp demolition remodeling
# 82          Active                              acutedge
# 85          Active                    adaptive resources
# 86          Active                     adcon consultants
# 89          Active                        ag enterprises
# 90          Active                     adkins management
# 92          Active                   admiral integration
# 93          Active           adolphues building services
# 96          Active           advanced disposal solutions
# 97          Active            advanced hydraulic systems
# 98          Active        advanced infrastructure design
# 99          Active                  advanced integration
#
# [48 rows x 26 columns]

# %%
export_excel = matched.to_excel (r'C:\Users\dabinlee\Desktop\mwdsbe\data\clean_fuzzy_merge_95.xlsx', index = None, header=True)

# %%
merged = skool.fuzzy_merge(cleaned_mini_registry, cleaned_license, on="company_name", score_cutoff=90)
matched = merged.dropna(subset=["company_name_y"])
matched

export_excel = matched.to_excel (r'C:\Users\dabinlee\Desktop\mwdsbe\data\clean_fuzzy_merge_90.xlsx', index = None, header=True)

# %%
merged = skool.fuzzy_merge(cleaned_mini_registry, cleaned_license, on="company_name", score_cutoff=85)
matched = merged.dropna(subset=["company_name_y"])
matched

export_excel = matched.to_excel (r'C:\Users\dabinlee\Desktop\mwdsbe\data\clean_fuzzy_merge_85.xlsx', index = None, header=True)

# %%
export_excel = matched.to_excel (r'C:\Users\dabinlee\Desktop\mwdsbe\data\clean_fuzzy_merge_95.xlsx', index = None, header=True)

# %%
merged = skool.fuzzy_merge(cleaned_mini_registry, cleaned_license, on="company_name", score_cutoff=90)
matched = merged.dropna(subset=["company_name_y"])
matched

export_excel = matched.to_excel (r'C:\Users\dabinlee\Desktop\mwdsbe\data\clean_fuzzy_merge_90.xlsx', index = None, header=True)

# %%
# fuzzy match of cleaned data
find_max_fuzzy_match_score(cleaned_mini_registry, cleaned_license, 1)
# Out:
# 56.375

# %%
# df to excel
export_excel = registry.to_excel (r'C:\Users\dabinlee\Desktop\export_dataframe.xlsx', index = None, header=True)

# %%
# compare both company_name & dba name

merged = (
    skool.fuzzy_merge(cleaned_mini_registry, cleaned_license, on="company_name", score_cutoff=70)
    .pipe(skool.fuzzy_merge, cleaned_mini_registry, cleaned_license, left_on="dba_name", right_on="company_name", score_cutoff=90)
)
matched = merged.dropna(subset=['company_name_y'])
matched
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-79-902fda47f014> in <module>
#       7 merged = (
#       8     skool.fuzzy_merge(cleaned_mini_registry, cleaned_license, on="company_name", score_cutoff=70)
# ----> 9     .pipe(skool.fuzzy_merge, cleaned_mini_registry, cleaned_license, left_on="dba_name", right_on="company_name", score_cutoff=90)
#      10 )
#      11 matched = merged.dropna(subset=['company_name_y'])
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in pipe(self, func, *args, **kwargs)
#    5026     @Appender(_shared_docs["pipe"] % _shared_doc_kwargs)
#    5027     def pipe(self, func, *args, **kwargs):
# -> 5028         return com._pipe(self, func, *args, **kwargs)
#    5029
#    5030     _shared_docs["aggregate"] = dedent(
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\common.py in _pipe(obj, func, *args, **kwargs)
#     481         return func(*args, **kwargs)
#     482     else:
# --> 483         return func(obj, *args, **kwargs)
#     484
#     485
#
# c:\users\dabinlee\documents\github\schuylkill\schuylkill\utils.py in wrapper(*args, **kwargs)
#      77
#      78         if not process_merged:
# ---> 79             return f(*args, **kwargs)
#      80         else:
#      81
#
# c:\users\dabinlee\documents\github\schuylkill\schuylkill\fuzzy.py in fuzzy_merge(left, right, on, left_on, right_on, workers, score_cutoff, scorer, max_matches, suffixes)
#      95     if left_on is None or right_on is None:
#      96         raise ValueError("Please specify `on` or `left_on/right_on`")
# ---> 97     if left_on not in left.columns:
#      98         raise ValueError(f"'{left_on}' is not a column in `left`")
#      99     if right_on not in right.columns:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in __contains__(self, key)
#    4228     @Appender(_index_shared_docs["contains"] % _index_doc_kwargs)
#    4229     def __contains__(self, key):
# -> 4230         hash(key)
#    4231         try:
#    4232             return key in self._engine
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in __hash__(self)
#    1884         raise TypeError(
#    1885             "{0!r} objects are mutable, thus they cannot be"
# -> 1886             " hashed".format(self.__class__.__name__)
#    1887         )
#    1888
#
# TypeError: 'DataFrame' objects are mutable, thus they cannot be hashed

# %%
registry[20:40]
# Out:
#                                               company_name  \
# registry_id
# 20           A & B Unique Construction / Home Repair, Inc.
# 21                      A & C ENVIRONMENTAL SERVICES, INC.
# 22                                     A & I Security, LLC
# 23                                 A & O Recovery Services
# 24                         A AND R FENCE AND GUIDERAIL LLC
# 25                                    A Bob's Towing, Inc.
# 26                                   A Esteban & Co., Inc.
# 27                                   A K Architecture, LLC
# 28                                A N S Steel Company, LLC
# 29                                     A-Best Vending Corp
# 30                                   A-M-E Mechanical, LLC
# 31                       A. G.  Consulting Engineering, PC
# 32                            A. L. Jackson & Company P.A.
# 33                               A. Lee Cook Hauling, Inc.
# 34                                    A. M. Electric, Inc.
# 35                                     A. M. Painting, LLC
# 36                                     A.C. Advisory, Inc.
# 37                          A.M. Truck & Auto Repair, Inc.
# 38                               A.R.B. Construction, Inc.
# 39                               A.T. Russell Construction
#
#                                     dba_name       owner_first  \
# registry_id
# 20                                       NaN           Barbara
# 21                                       NaN        ANTOINETTE
# 22                                       NaN           RAYMOND
# 23                                       NaN             Kathy
# 24                                       NaN              Anna
# 25                                       NaN            Mikina
# 26                                       NaN        Alfonso C.
# 27                                       NaN              Lisa
# 28                                       NaN             Linda
# 29           A-Best Vending & Coffee Service               Sue
# 30                                       NaN            Alfred
# 31                                       NaN  Ariganjan (Gary)
# 32                                       NaN           Anthony
# 33                                       NaN               Amy
# 34                                       NaN           Anthony
# 35                                       NaN          Abdullah
# 36                                       NaN             Adela
# 37                                       NaN             CATHY
# 38                                       NaN            Joanna
# 39                                       NaN         TinaMarie
#
#                      owner_last                          location  \
# registry_id
# 20                        Davis                 5008 Wayne Avenue
# 21                      PATRICK        2045 NORTH LAWRENCE STREET
# 22                      ALVAREZ              10234 Dedater Street
# 23                    Gallagher            3319 Kensington Avenue
# 24                         ESAU                   564 13th street
# 25                     Harrison              2220 Orthodox Street
# 26                      Esteban              132 West 36th Street
# 27                    Armstrong                  2425 Pine Street
# 28                      Manning               4340 Sepviva Street
# 29                      Epstein                     7336 State Rd
# 30                   Edmunds Jr               6123 Washington Ave
# 31                      Guleria  131 West 33rd Street, Suite 12 B
# 32                      Jackson      1221 Brickell Ave, 9th Floor
# 33                     Lee-Cook               643 Pennfield Drive
# 34                     Muhammad           2222 N. Marshall Street
# 35                     Muhammad          2745 North Garnet Street
# 36                       Cepeda         99 Park Avenue Suite 1560
# 37           MATARAZZO-NICHOLAS               14065 Townsend Road
# 38               Johnson-Harris           135 East Hortter Street
# 39                      Russell             4619 Lancaster Avenue
#
#             location_city location_state  zip_code  \
# registry_id
# 20           Philadelphia             PA   19144.0
# 21           Philadelphia             PA   19122.0
# 22           Philadelphia             PA   19116.0
# 23           Philadelphia             PA   19134.0
# 24              Hammonton             NJ    8037.0
# 25           Philadelphia             PA   19137.0
# 26               New York             NY   10018.0
# 27           Philadelphia             PA   19103.0
# 28           Philadelphia             PA   19124.0
# 29           Philadelphia             PA   19136.0
# 30           Philadelphia             PA   19143.0
# 31               New York             NY   10001.0
# 32                  Miami             FL   33131.0
# 33               Hatfield             PA   19440.0
# 34           Philadelphia             PA   19133.0
# 35           Philadelphia             PA   19132.0
# 36               New York             NY   10016.0
# 37           Philadelphia             PA   19154.0
# 38           Philadelphia             PA   19119.0
# 39           Philadelphia             PA   19104.0
#
#                               mailing_address  mailing_city mailing_state  \
# registry_id
# 20                          5008 Wayne Avenue  Philadelphia            PA
# 21                 2045 NORTH LAWRENCE STREET  Philadelphia            PA
# 22                       10234 Dedater Street  Philadelphia            PA
# 23                     3319 Kensington Avenue  Philadelphia            PA
# 24                            564 13th street     Hammonton            NJ
# 25                       2220 Orthodox Street  Philadelphia            PA
# 26                       132 West 36th Street      New York            NY
# 27                           2425 Pine Street  Philadelphia            PA
# 28                        4340 Sepviva Street  Philadelphia            PA
# 29                              7336 State Rd  Philadelphia            PA
# 30                        6123 Washington Ave  Philadelphia            PA
# 31           131 West 33rd Street, Suite 12 B      New York            NY
# 32               1221 Brickell Ave, 9th Floor         Miami            FL
# 33                        643 Pennfield Drive      Hatfield            PA
# 34                    2222 N. Marshall Street  Philadelphia            PA
# 35                   2745 North Garnet Street  Philadelphia            PA
# 36                  99 Park Avenue Suite 1560      New York            NY
# 37                        14065 Townsend Road  Philadelphia            PA
# 38                    135 East Hortter Street  Philadelphia            PA
# 39                      4619 Lancaster Avenue  Philadelphia            PA
#
#              mailing_zip certification_type  \
# registry_id
# 20               19144.0               MWBE
# 21               19122.0               MWBE
# 22               19116.0                MBE
# 23               19134.0                WBE
# 24                8037.0                WBE
# 25               19137.0               MWBE
# 26               10018.0                MBE
# 27               19103.0                WBE
# 28               19124.0                WBE
# 29               19136.0                WBE
# 30               19143.0                MBE
# 31               10001.0                MBE
# 32               33131.0                MBE
# 33               19440.0                WBE
# 34               19133.0                MBE
# 35               19132.0                MBE
# 36               10016.0               MWBE
# 37               19154.0                WBE
# 38               19119.0               MWBE
# 39               19104.0               MWBE
#
#                                                     capability  local  \
# registry_id
# 20                          NAICS 238130 Carpentry Contractors   True
# 21           Asphalt roof shingle installation ; Aerial or ...   True
# 22           Insurance investigation services (except claim...   True
# 23           ; 5416\tManagement, Scientific, and Technical ...   True
# 24                    Highway, Street, and Bridge Construction  False
# 25           NAICS\t48841\tMotor Vehicle Towing ; NAICS\t81...   True
# 26           NAICS\t323111\tAddress lists commercial printi...  False
# 27           NAICS\t5413   Architectural, Engineering, and ...   True
# 28           NAICS\t2362\tNonresidential Building Construct...   True
# 29                                Vending machine installation   True
# 30           NAICS\t238220   Heating, ventilation and air-c...   True
# 31           NAICS\t5413\tArchitectural, Engineering, and R...  False
# 32           Accountants' (i.e., CPAs) offices, certified p...  False
# 33           Transportation and Warehousing ; Agricultural ...  False
# 34                         NAICS 238210 Electrical contractors   True
# 35           NAICS 238320 Painting & Wall Covering Contractors   True
# 36                               90108\tFinancial Consultant;   False
# 37           NAICS\t44122\tMotorcycle, Boat, and Other Moto...   True
# 38           Addition, alteration and renovation for-sale b...   True
# 39           NAICS\t2383\tBuilding Finishing Contractors ; ...   True
#
#              out_of_state    location_standard        lat        lng  \
# registry_id
# 20                  False       5008 WAYNE AVE  40.025369 -75.168070
# 21                  False   2045 N LAWRENCE ST  39.982290 -75.141137
# 22                  False     10234 DEDATER ST  40.106057 -75.018803
# 23                  False  3319 KENSINGTON AVE  39.998001 -75.110180
# 24                   True                  NaN        NaN        NaN
# 25                  False     2220 ORTHODOX ST  40.008166 -75.078701
# 26                   True                  NaN        NaN        NaN
# 27                  False         2425 PINE ST  39.947695 -75.181090
# 28                  False      4340 SEPVIVA ST  40.003004 -75.079992
# 29                  False        7336 STATE RD  40.026532 -75.030907
# 30                  False  6123 WASHINGTON AVE  39.948499 -75.246577
# 31                   True                  NaN        NaN        NaN
# 32                   True                  NaN        NaN        NaN
# 33                  False                  NaN        NaN        NaN
# 34                  False   2222 N MARSHALL ST  39.985489 -75.144539
# 35                  False     2745 N GARNET ST  39.996079 -75.162692
# 36                   True                  NaN        NaN        NaN
# 37                  False    14065 TOWNSEND RD  40.108419 -74.975170
# 38                  False     135 E HORTTER ST  40.053217 -75.182349
# 39                  False   4619 LANCASTER AVE  39.971044 -75.214417
#
#                                geometry
# registry_id
# 20           POINT (-75.16807 40.02537)
# 21           POINT (-75.14114 39.98229)
# 22           POINT (-75.01880 40.10606)
# 23           POINT (-75.11018 39.99800)
# 24                                 None
# 25           POINT (-75.07870 40.00817)
# 26                                 None
# 27           POINT (-75.18109 39.94770)
# 28           POINT (-75.07999 40.00300)
# 29           POINT (-75.03091 40.02653)
# 30           POINT (-75.24658 39.94850)
# 31                                 None
# 32                                 None
# 33                                 None
# 34           POINT (-75.14454 39.98549)
# 35           POINT (-75.16269 39.99608)
# 36                                 None
# 37           POINT (-74.97517 40.10842)
# 38           POINT (-75.18235 40.05322)
# 39           POINT (-75.21442 39.97104)
