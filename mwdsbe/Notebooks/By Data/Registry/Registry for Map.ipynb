# %%
import mwdsbe
import geopandas as gpd
import pandas as pd

# %%
registry = mwdsbe.load_registry() # geopandas df

# %%
registry.head()
# Out:
#                            company_name    dba_name owner_first owner_last  \
# registry_id
# 0                119 Degrees Architects         NaN      Rafael     Utrera
# 1                         12Bravo Group         NaN     JEFFREY  YEKENCHIK
# 2            1st Choice Financial Group    ProVisio    Kathrina      Nease
# 3                     212 Harakawa Inc.  Two Twelve         Ann   Harakawa
# 4                   215 Media Solutions         NaN      Dewain    Johnson
#
#                                  location  location_city location_state  \
# registry_id
# 0            1503 Green Street, Suite # 4   Philadelphia             PA
# 1                     236 McKendimen Road  Medford Lakes             NJ
# 2                      133 N. 21st Street      Camp Hill             PA
# 3            236 W 27th Street, Suite 802       New York             NY
# 4                       810 Felton Avenue    Sharon Hill             PA
#
#              zip_code               mailing_address   mailing_city  \
# registry_id
# 0             19130.0  1503 Green Street, Suite # 4   Philadelphia
# 1              8055.0           236 McKendimen Road  Medford Lakes
# 2             17011.0            133 N. 21st Street      Camp Hill
# 3             10001.0  236 W 27th Street, Suite 802       New York
# 4             19079.0             810 Felton Avenue    Sharon Hill
#
#             mailing_state  mailing_zip certification_type  \
# registry_id
# 0                      PA      19130.0                MBE
# 1                      NJ       8055.0               DSBE
# 2                      PA      17011.0                WBE
# 3                      NY      10001.0               MWBE
# 4                      PA      19079.0                MBE
#
#                                                     capability  local  \
# registry_id
# 0            NAICS 5413 Architectural, Engineering, and Rel...   True
# 1            Addition, alteration and renovation for-sale b...  False
# 2                           NAICS 928120 International Affairs  False
# 3            Graphic Design Services; Graphic design servic...  False
# 4            NAICS 5414 Specialized Design Services ; NAICS...  False
#
#              out_of_state location_standard        lat        lng  \
# registry_id
# 0                   False     1503 GREEN ST  39.964275 -75.163042
# 1                    True               NaN        NaN        NaN
# 2                   False               NaN        NaN        NaN
# 3                    True               NaN        NaN        NaN
# 4                   False               NaN        NaN        NaN
#
#                                geometry
# registry_id
# 0            POINT (-75.16304 39.96427)
# 1                                  None
# 2                                  None
# 3                                  None
# 4                                  None

# %%
registry_geo = registry.dropna(subset=["geometry"])

# %%
registry_geo
# Out:
#                                company_name         dba_name   owner_first  \
# registry_id
# 0                    119 Degrees Architects              NaN        Rafael
# 7            24 Hour Cleaning Services Ltd.              NaN  Mary Colleen
# 8                       259 Strategies, LLC              NaN         Chaka
# 10                          3rd Floor Media              NaN          Gary
# 18                    A & A Court Reporting  Andrea St. John        Andrea
# ...                                     ...              ...           ...
# 3106         Zanaras Reporting & Video, LLC              NaN         JULIE
# 3109                Zekeria Consulting, LLC              NaN        Zainen
# 3112                   Zimmerman Studio LLC              NaN        Pamela
# 3114                            Zoeza Group              NaN         Jason
# 3118             Zweig, Ramick & Associates              NaN        Jeanne
#
#               owner_last                              location location_city  \
# registry_id
# 0                 Utrera          1503 Green Street, Suite # 4  Philadelphia
# 7              Zoltowski                 14005 Barcalow Street  Philadelphia
# 8            Fattah, Jr.          Two Logan Square, Suite 1900  Philadelphia
# 10              Shepherd         7544 Fayette Street, Suite 1F  Philadelphia
# 18              St. John     303 Chestnut Street, Second Floor  Philadelphia
# ...                  ...                                   ...           ...
# 3106             ZANARAS         1845 WALNUT STREET, Suite 938  Philadelphia
# 3109             Zekeria            220 Locust Street, Unit 9C  Philadelphia
# 3112           Zimmerman  1927 South Broad Street, First Floor  Philadelphia
# 3114             Wingard      536 W. Moreland Avenue, Suite C.  Philadelphia
# 3118               Zweig                    2320 Faunce Street  Philadelphia
#
#             location_state  zip_code                       mailing_address  \
# registry_id
# 0                       PA   19130.0          1503 Green Street, Suite # 4
# 7                       PA   19116.0                 14005 Barcalow Street
# 8                       PA   19103.0          Two Logan Square, Suite 1900
# 10                      PA   19150.0                           PO Box 2274
# 18                      PA   19106.0                  P.O. Box 74, Suite 4
# ...                    ...       ...                                   ...
# 3106                    PA   19103.0         1845 WALNUT STREET, Suite 938
# 3109                    PA   19106.0            220 Locust Street, Unit 9C
# 3112                    PA   19148.0  1927 South Broad Street, First Floor
# 3114                    PA   19118.0      536 W. Moreland Avenue, Suite C.
# 3118                    PA   19152.0                    2320 Faunce Street
#
#              mailing_city mailing_state  mailing_zip certification_type  \
# registry_id
# 0            Philadelphia            PA      19130.0                MBE
# 7            Philadelphia            PA      19116.0                WBE
# 8            Philadelphia            PA      19103.0                MBE
# 10            Bala Cynwyd            PA      19004.0                MBE
# 18             Moorestown            NJ       8057.0                WBE
# ...                   ...           ...          ...                ...
# 3106         Philadelphia            PA      19103.0                WBE
# 3109         Philadelphia            PA      19106.0               MWBE
# 3112         Philadelphia            PA      19148.0                WBE
# 3114         Philadelphia            PA      19118.0                MBE
# 3118         Philadelphia            PA      19152.0                WBE
#
#                                                     capability  local  \
# registry_id
# 0            NAICS 5413 Architectural, Engineering, and Rel...   True
# 7            Janitorial equipment and supplies merchant who...   True
# 8            NAICS\t5416\tManagement, Scientific, and Techn...   True
# 10           512240: Audio recording post-production servic...   True
# 18                      Court reporting and stenotype services   True
# ...                                                        ...    ...
# 3106         Court reporting and stenotype services ; Court...   True
# 3109         90101\tBusiness Consultant; 90108\tFinancial C...   True
# 3112         5413 Architectural, Engineering, and Related S...   True
# 3114         90124\tResearch Consulting; 90113\tTraining Co...   True
# 3118         Accounting, Tax Preparation, Bookkeeping, and ...   True
#
#              out_of_state   location_standard        lat        lng  \
# registry_id
# 0                   False       1503 GREEN ST  39.964275 -75.163042
# 7                   False   14005 BARCALOW ST  40.131349 -75.014284
# 8                   False    100-20 N 18TH ST  39.955726 -75.169784
# 10                  False     7544 FAYETTE ST  40.069307 -75.160155
# 18                   True     303 CHESTNUT ST  39.948849 -75.146173
# ...                   ...                 ...        ...        ...
# 3106                False      1845 WALNUT ST  39.950665 -75.171552
# 3109                False       220 LOCUST ST  39.944816 -75.145274
# 3112                False     1927 S BROAD ST  39.926058 -75.168948
# 3114                False  536 W MORELAND AVE  40.059613 -75.207085
# 3118                False      2320 FAUNCE ST  40.051443 -75.055115
#
#                                geometry
# registry_id
# 0            POINT (-75.16304 39.96427)
# 7            POINT (-75.01428 40.13135)
# 8            POINT (-75.16978 39.95573)
# 10           POINT (-75.16016 40.06931)
# 18           POINT (-75.14617 39.94885)
# ...                                 ...
# 3106         POINT (-75.17155 39.95067)
# 3109         POINT (-75.14527 39.94482)
# 3112         POINT (-75.16895 39.92606)
# 3114         POINT (-75.20708 40.05961)
# 3118         POINT (-75.05512 40.05144)
#
# [893 rows x 20 columns]

# %%
# add neighborhoods
zillow = gpd.read_file('data/neighborhood/zillow_neighborhoods.geojson')

# %%
with open("neighborhoods.json", "w") as ff:
        ff.write(zillow.to_json())

# %%
registry_gdf = gpd.GeoDataFrame(registry_geo, geometry='geometry', crs={"init": "epsg:4326"})
joined = gpd.sjoin(registry_gdf, zillow, op='within', how='left')

# %%
joined.head()
# Out:
#                       company_name         dba_name   owner_first  \
# 0           119 Degrees Architects              NaN        Rafael
# 7   24 Hour Cleaning Services Ltd.              NaN  Mary Colleen
# 8              259 Strategies, LLC              NaN         Chaka
# 10                 3rd Floor Media              NaN          Gary
# 18           A & A Court Reporting  Andrea St. John        Andrea
#
#      owner_last                           location location_city  \
# 0        Utrera       1503 Green Street, Suite # 4  Philadelphia
# 7     Zoltowski              14005 Barcalow Street  Philadelphia
# 8   Fattah, Jr.       Two Logan Square, Suite 1900  Philadelphia
# 10     Shepherd      7544 Fayette Street, Suite 1F  Philadelphia
# 18     St. John  303 Chestnut Street, Second Floor  Philadelphia
#
#    location_state  zip_code               mailing_address  mailing_city  ...  \
# 0              PA   19130.0  1503 Green Street, Suite # 4  Philadelphia  ...
# 7              PA   19116.0         14005 Barcalow Street  Philadelphia  ...
# 8              PA   19103.0  Two Logan Square, Suite 1900  Philadelphia  ...
# 10             PA   19150.0                   PO Box 2274   Bala Cynwyd  ...
# 18             PA   19106.0          P.O. Box 74, Suite 4    Moorestown  ...
#
#    certification_type                                         capability  \
# 0                 MBE  NAICS 5413 Architectural, Engineering, and Rel...
# 7                 WBE  Janitorial equipment and supplies merchant who...
# 8                 MBE  NAICS\t5416\tManagement, Scientific, and Techn...
# 10                MBE  512240: Audio recording post-production servic...
# 18                WBE             Court reporting and stenotype services
#
#    local out_of_state  location_standard        lat        lng  \
# 0   True        False      1503 GREEN ST  39.964275 -75.163042
# 7   True        False  14005 BARCALOW ST  40.131349 -75.014284
# 8   True        False   100-20 N 18TH ST  39.955726 -75.169784
# 10  True        False    7544 FAYETTE ST  40.069307 -75.160155
# 18  True         True    303 CHESTNUT ST  39.948849 -75.146173
#
#                       geometry  index_right     ZillowName
# 0   POINT (-75.16304 39.96427)        125.0  Spring Garden
# 7   POINT (-75.01428 40.13135)        123.0       Somerton
# 8   POINT (-75.16978 39.95573)         73.0   Logan Square
# 10  POINT (-75.16016 40.06931)        140.0  West Oak Lane
# 18  POINT (-75.14617 39.94885)         97.0       Old City
#
# [5 rows x 22 columns]

# %%
totals = joined.groupby('ZillowName').size()
totals = totals.to_frame('N').reset_index()
totals.head()
# Out:
#          ZillowName  N
# 0           Airport  2
# 1    Allegheny West  6
# 2           Andorra  2
# 3  Aston Woodbridge  2
# 4   Bartram Village  1

# %%
totals = zillow.merge(totals, on='ZillowName', how='left')

# %%
totals['N'] = totals['N'].fillna(0)

# %%
totals
# Out:
#              ZillowName                                           geometry  \
# 0       Academy Gardens  POLYGON ((-74.99851 40.06435, -74.99456 40.061...
# 1               Airport  POLYGON ((-75.19728 39.89252, -75.19617 39.892...
# 2        Allegheny West  POLYGON ((-75.16592 40.00327, -75.16596 40.003...
# 3               Andorra  POLYGON ((-75.22463 40.06686, -75.22588 40.065...
# 4      Aston Woodbridge  POLYGON ((-75.00860 40.05369, -75.00861 40.053...
# ..                  ...                                                ...
# 153              Wister  POLYGON ((-75.17210 40.03840, -75.17197 40.037...
# 154    Woodland Terrace  POLYGON ((-75.20399 39.94968, -75.20396 39.949...
# 155          Wynnefield  POLYGON ((-75.22070 40.00392, -75.21792 39.994...
# 156  Wynnefield Heights  POLYGON ((-75.20103 40.00419, -75.20410 40.000...
# 157            Yorktown  POLYGON ((-75.14917 39.97907, -75.15096 39.970...
#
#        N
# 0    0.0
# 1    2.0
# 2    6.0
# 3    2.0
# 4    2.0
# ..   ...
# 153  4.0
# 154  1.0
# 155  6.0
# 156  7.0
# 157  0.0
#
# [158 rows x 3 columns]

# %%
with open("n_neighborhoods.json", "w") as ff:
        ff.write(totals.to_json())

# %%
import geopandas as gpd
MSA = gpd.read_file('./data/MSA')

# %%
MSA
# Out:
#     CSAFP CBSAFP        AFFGEOID  GEOID            NAME LSAD        ALAND  \
# 0    None  31340  310M400US31340  31340   Lynchburg, VA   M1   5491925729
# 1     488  42220  310M400US42220  42220  Santa Rosa, CA   M1   4081491107
# 2    None  24900  310M400US24900  24900   Greenwood, MS   M2   3165909249
# 3     538  46140  310M400US46140  46140       Tulsa, OK   M1  16238554204
# 4    None  18260  310M400US18260  18260  Cookeville, TN   M2   2960951070
# ..    ...    ...             ...    ...             ...  ...          ...
# 940   288  13060  310M400US13060  13060    Bay City, TX   M2   2830586734
# 941  None  48300  310M400US48300  48300   Wenatchee, WA   M1  12277658519
# 942   314  35460  310M400US35460  35460     Newport, TN   M2   1128782873
# 943   408  45860  310M400US45860  45860  Torrington, CT   M2   2384116952
# 944   390  21900  310M400US21900  21900    Fairmont, WV   M2    799642788
#
#          AWATER                                           geometry
# 0      68559452  POLYGON ((-79.85840 37.26715, -79.85660 37.268...
# 1     497455304  POLYGON ((-123.53354 38.76841, -123.52851 38.7...
# 2      48172332  POLYGON ((-90.45376 33.27625, -90.45310 33.328...
# 3     492994165  POLYGON ((-97.06448 36.68106, -97.06411 36.684...
# 4      35466926  POLYGON ((-85.84648 36.28817, -85.83735 36.341...
# ..          ...                                                ...
# 940  1345801267  POLYGON ((-96.37833 28.39078, -96.36755 28.440...
# 941   266186967  POLYGON ((-121.18080 47.89849, -121.17723 47.9...
# 942    18734377  POLYGON ((-83.31519 35.89332, -83.31078 35.895...
# 943    62334525  POLYGON ((-73.51795 41.67086, -73.51678 41.687...
# 944     7185842  POLYGON ((-80.49816 39.56333, -80.49537 39.564...
#
# [945 rows x 9 columns]

# %%
Philly_MSA = MSA.loc[MSA['NAME'].str.contains('Philadelphia-Camden-Wilmington')]

# %%
Philly_MSA
# Out:
#     CSAFP CBSAFP        AFFGEOID  GEOID  \
# 379   428  37980  310M400US37980  37980
#
#                                             NAME LSAD        ALAND     AWATER  \
# 379  Philadelphia-Camden-Wilmington, PA-NJ-DE-MD   M1  11921840711  692432936
#
#                                               geometry
# 379  MULTIPOLYGON (((-75.41272 39.38437, -75.41130 ...

# %%
from matplotlib import pyplot as plt

# %%
fig, ax = plt.subplots(figsize=(5, 5))
Philly_MSA.to_crs(epsg=4326).plot(ax=ax, facecolor="none", edgecolor="black")

ax.set_title("Equirectangular")
ax.set_axis_off()
ax.set_aspect("equal")

# %%
with open("Philly_MSA.json", "w") as ff:
        ff.write(Philly_MSA.to_json())

# %%
registry
# Out:
#                            company_name    dba_name owner_first owner_last  \
# registry_id
# 0                119 Degrees Architects         NaN      Rafael     Utrera
# 1                         12Bravo Group         NaN     JEFFREY  YEKENCHIK
# 2            1st Choice Financial Group    ProVisio    Kathrina      Nease
# 3                     212 Harakawa Inc.  Two Twelve         Ann   Harakawa
# 4                   215 Media Solutions         NaN      Dewain    Johnson
# ...                                 ...         ...         ...        ...
# 3114                        Zoeza Group         NaN       Jason    Wingard
# 3115                         ZONES, LLC         NaN         Mr.      Lalji
# 3116                   Zook Motors Inc.         NaN       Susan     Wilson
# 3117                          Zora, LLC         NaN     Charles   O'Reilly
# 3118         Zweig, Ramick & Associates         NaN      Jeanne      Zweig
#
#                                      location  location_city location_state  \
# registry_id
# 0                1503 Green Street, Suite # 4   Philadelphia             PA
# 1                         236 McKendimen Road  Medford Lakes             NJ
# 2                          133 N. 21st Street      Camp Hill             PA
# 3                236 W 27th Street, Suite 802       New York             NY
# 4                           810 Felton Avenue    Sharon Hill             PA
# ...                                       ...            ...            ...
# 3114         536 W. Moreland Avenue, Suite C.   Philadelphia             PA
# 3115                          1102 15TH ST SW         Auburn             WA
# 3116                      25 Willow Run Drive           Kane             PA
# 3117                         1901 Dorcas Lane     Wilmington             DE
# 3118                       2320 Faunce Street   Philadelphia             PA
#
#              zip_code                   mailing_address   mailing_city  ...  \
# registry_id                                                             ...
# 0             19130.0      1503 Green Street, Suite # 4   Philadelphia  ...
# 1              8055.0               236 McKendimen Road  Medford Lakes  ...
# 2             17011.0                133 N. 21st Street      Camp Hill  ...
# 3             10001.0      236 W 27th Street, Suite 802       New York  ...
# 4             19079.0                 810 Felton Avenue    Sharon Hill  ...
# ...               ...                               ...            ...  ...
# 3114          19118.0  536 W. Moreland Avenue, Suite C.   Philadelphia  ...
# 3115          98001.0                   1102 15TH ST SW         Auburn  ...
# 3116          16735.0               25 Willow Run Drive           Kane  ...
# 3117          19806.0                  1901 Dorcas Lane     Wilmington  ...
# 3118          19152.0                2320 Faunce Street   Philadelphia  ...
#
#             mailing_zip  certification_type  \
# registry_id
# 0               19130.0                 MBE
# 1                8055.0                DSBE
# 2               17011.0                 WBE
# 3               10001.0                MWBE
# 4               19079.0                 MBE
# ...                 ...                 ...
# 3114            19118.0                 MBE
# 3115            98001.0                 MBE
# 3116            16735.0                 WBE
# 3117            19806.0                MWBE
# 3118            19152.0                 WBE
#
#                                                     capability  local  \
# registry_id
# 0            NAICS 5413 Architectural, Engineering, and Rel...   True
# 1            Addition, alteration and renovation for-sale b...  False
# 2                           NAICS 928120 International Affairs  False
# 3            Graphic Design Services; Graphic design servic...  False
# 4            NAICS 5414 Specialized Design Services ; NAICS...  False
# ...                                                        ...    ...
# 3114         90124\tResearch Consulting; 90113\tTraining Co...   True
# 3115            42710\tCOMPUTER EQUIPMENT & PERIPHERALS- NEW;   False
# 3116         26005\tTIRE CHANGING & REPAIRS; 25074\tTOWING ...  False
# 3117         Alarm apparatus, electric, merchant wholesaler...  False
# 3118         Accounting, Tax Preparation, Bookkeeping, and ...   True
#
#              out_of_state   location_standard        lat        lng  \
# registry_id
# 0                   False       1503 GREEN ST  39.964275 -75.163042
# 1                    True                 NaN        NaN        NaN
# 2                   False                 NaN        NaN        NaN
# 3                    True                 NaN        NaN        NaN
# 4                   False                 NaN        NaN        NaN
# ...                   ...                 ...        ...        ...
# 3114                False  536 W MORELAND AVE  40.059613 -75.207085
# 3115                 True                 NaN        NaN        NaN
# 3116                False                 NaN        NaN        NaN
# 3117                 True                 NaN        NaN        NaN
# 3118                False      2320 FAUNCE ST  40.051443 -75.055115
#
#                                geometry    id
# registry_id
# 0            POINT (-75.16304 39.96427)     0
# 1                                  None     1
# 2                                  None     2
# 3                                  None     3
# 4                                  None     4
# ...                                 ...   ...
# 3114         POINT (-75.20708 40.05961)  3114
# 3115                               None  3115
# 3116                               None  3116
# 3117                               None  3117
# 3118         POINT (-75.05512 40.05144)  3118
#
# [3119 rows x 21 columns]
