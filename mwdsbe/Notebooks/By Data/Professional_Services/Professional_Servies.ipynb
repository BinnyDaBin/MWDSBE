# %% [markdown]
# # Professional Services Contracts
# The entire dataset for Professional Services Contracts by fiscal quarter - from 2013 Q4 to 2019 Q3

# %%
import mwdsbe
import schuylkill as skool
import pandas as pd
import glob
import time

# %% [markdown]
# ## Functions

# %%
def drop_duplicates_by_date(df, date_column):
    df.sort_values(by=date_column, ascending=False, inplace=True)
    df = df.loc[~df.index.duplicated(keep="first")]
    df.sort_index(inplace=True)
    return df

# %% [markdown]
# ## 1. Only read vendor column from Professional Services
# In order to have a sense of how many matches we get from Professional Services data

# %% [markdown]
# ## Data

# %%
registry = mwdsbe.load_registry() # geopandas df

# %%
path = r'C:\Users\dabinlee\Documents\GitHub\mwdsbe\mwdsbe\data\professional_services'
ps_vendor = pd.concat([pd.read_csv(file, usecols=['vendor']) for file in glob.glob(path + "/*.csv")], ignore_index = True)

# %%
ps_vendor
# Out:
#                                                   vendor
# 0                                      Albert Scaperotto
# 1                    Ceisler Media & Issue Advocacy, LLC
# 2                                        Charles Swanson
# 3                                Cliftonlarsonallen LLP
# 4                                Cliftonlarsonallen LLP
# ...                                                  ...
# 37681              Whitman, Requardt and Associates, LLP
# 37682              Whitman, Requardt and Associates, LLP
# 37683  Wood Environment & Infrastructure Solutions, Inc.
# 37684                            Zelenkofske Axelrod LLC
# 37685                                    inContact, Inc.
#
# [37686 rows x 1 columns]

# %%
ps_vendor = ps_vendor.drop_duplicates()

# %%
len(ps_vendor)
# Out:
# 2692

# %% [markdown]
# #### Clean Data

# %%
ignore_words = ['inc', 'group', 'llc', 'corp', 'pc', 'incorporated', 'ltd', 'co', 'associates', 'services', 'company', 'enterprises', 'enterprise', 'service', 'corporation']
cleaned_registry = skool.clean_strings(registry, ['company_name', 'dba_name'], True, ignore_words)
cleaned_ps_vendor = skool.clean_strings(ps_vendor, ['vendor'], True, ignore_words)

cleaned_registry = cleaned_registry.dropna(subset=['company_name'])
cleaned_ps_vendor = cleaned_ps_vendor.dropna(subset=['vendor'])

# %%
cleaned_ps_vendor = cleaned_ps_vendor.drop_duplicates()

# %%
len(cleaned_ps_vendor)
# Out:
# 2269

# %% [markdown]
# ## TF-IDF Merge Registry and Professional Services
# on company_name and vendor before full merge

# %%
t1 = time.time()
merged = (
    skool.tf_idf_merge(cleaned_registry, cleaned_ps_vendor, left_on="company_name", right_on="vendor", score_cutoff=85)
    .pipe(skool.tf_idf_merge, cleaned_registry, cleaned_ps_vendor, left_on="dba_name", right_on="vendor", score_cutoff=85)
)
t = time.time() - t1

# %%
print('Execution time:', t, 'sec')
# Out:
# Execution time: 0.38282060623168945 sec

# %%
len(merged)
# Out:
# 3119

# %%
matched_PS = merged.dropna(subset=['vendor'])

# %%
matched_PS
# Out:
#                           company_name dba_name owner_first  owner_last  \
# registry_id
# 12                                  4u  stellar       Liang        Chen
# 27                    a k architecture      NaN        Lisa   Armstrong
# 60                    acacia financial      NaN      Noreen       White
# 65                     acclaim systems      NaN     Kailash    Kalantri
# 86                   adcon consultants      NaN    Lawrence       Dibor
# ...                                ...      ...         ...         ...
# 3007         viridian landscape studio      NaN       Tavis  Dockwiller
# 3017                               vkg      NaN    Kimberly   Hawthorne
# 3056                       wfgd studio      NaN    Marcella      Coffey
# 3097                             yikes      NaN       Tracy    Levesque
# 3118                      zweig ramick      NaN      Jeanne       Zweig
#
#                                                       location location_city  \
# registry_id
# 12                              70 West 36th Street, Ste. #702      New York
# 27                                            2425 Pine Street  Philadelphia
# 60                       6000 Midlantic Drive, Suite 410 North    Mt. Laurel
# 65                             110 EAST PENNSYLVANIA BOULEVARD  Feasterville
# 86           2465 North 50th Street Bala Building, Suite #1...  Philadelphia
# ...                                                        ...           ...
# 3007                                       3868 Terrace Street  Philadelphia
# 3017                                      734 E. Dorset Street  Philadelphia
# 3056                               718 Arch Street, Suite 302s  Philadelphia
# 3097                                    204 East Girard Avenue  Philadelphia
# 3118                                        2320 Faunce Street  Philadelphia
#
#             location_state  zip_code  \
# registry_id
# 12                      NY   10018.0
# 27                      PA   19103.0
# 60                      NJ    8054.0
# 65                      PA   19053.0
# 86                      PA   19131.0
# ...                    ...       ...
# 3007                    PA   19128.0
# 3017                    PA   19119.0
# 3056                    PA   19106.0
# 3097                    PA   19125.0
# 3118                    PA   19152.0
#
#                                                mailing_address  mailing_city  \
# registry_id
# 12                              70 West 36th Street, Ste. #702      New York
# 27                                            2425 Pine Street  Philadelphia
# 60                       6000 Midlantic Drive, Suite 410 North    Mt. Laurel
# 65                             110 EAST PENNSYLVANIA BOULEVARD  Feasterville
# 86           2465 North 50th Street Bala Building, Suite #1...  Philadelphia
# ...                                                        ...           ...
# 3007                                       3868 Terrace Street  Philadelphia
# 3017                                      734 E. Dorset Street  Philadelphia
# 3056                               718 Arch Street, Suite 302S  Philadelphia
# 3097                                    204 East Girard Avenue  Philadelphia
# 3118                                        2320 Faunce Street  Philadelphia
#
#              ...                                         capability  local  \
# registry_id  ...
# 12           ...  Internet service providers, using own operated...  False
# 27           ...  NAICS\t5413   Architectural, Engineering, and ...   True
# 60           ...  Financial management consulting (except invest...  False
# 65           ...  NAICS\t5415\tComputer Systems Design and Relat...  False
# 86           ...  Construction management, multifamily building ...   True
# ...          ...                                                ...    ...
# 3007         ...                   Landscape architectural services   True
# 3017         ...  Computer Training  ; Computer Training  ; Prof...   True
# 3056         ...  Art services, graphic ; Communication design s...   True
# 3097         ...  Advertising periodical publishers, exclusively...   True
# 3118         ...  Accounting, Tax Preparation, Bookkeeping, and ...   True
#
#             out_of_state location_standard        lat        lng  \
# registry_id
# 12                  True               NaN        NaN        NaN
# 27                 False      2425 PINE ST  39.947695 -75.181090
# 60                  True               NaN        NaN        NaN
# 65                 False               NaN        NaN        NaN
# 86                 False    2465 N 50TH ST  39.999592 -75.227267
# ...                  ...               ...        ...        ...
# 3007               False   3868 TERRACE ST  40.020794 -75.213208
# 3017               False     734 DORSET ST  40.062765 -75.175337
# 3056               False       718 ARCH ST  39.952586 -75.152491
# 3097               False  204 E GIRARD AVE  39.968918 -75.133325
# 3118               False    2320 FAUNCE ST  40.051443 -75.055115
#
#                                geometry  right_index  match_probability  \
# registry_id
# 12                                 None      31193.0                1.0
# 27           POINT (-75.18109 39.94770)      25835.0                1.0
# 60                                 None         40.0                1.0
# 65                                 None       3110.0                1.0
# 86           POINT (-75.22727 39.99959)      16398.0                1.0
# ...                                 ...          ...                ...
# 3007         POINT (-75.21321 40.02079)       7645.0                1.0
# 3017         POINT (-75.17534 40.06276)        902.0                1.0
# 3056         POINT (-75.15249 39.95259)       7080.0                1.0
# 3097         POINT (-75.13332 39.96892)       8495.0                1.0
# 3118         POINT (-75.05512 40.05144)        204.0                1.0
#
#                                 vendor
# registry_id
# 12                             stellar
# 27                    a k architecture
# 60                    acacia financial
# 65                     acclaim systems
# 86                   adcon consultants
# ...                                ...
# 3007         viridian landscape studio
# 3017                               vkg
# 3056                       wfgd studio
# 3097                             yikes
# 3118                      zweig ramick
#
# [205 rows x 23 columns]

# %%
len(matched_PS)
# Out:
# 205

# %% [markdown]
# #### New matches

# %%
matched_OL = pd.read_excel(r'C:\Users\dabinlee\Desktop\mwdsbe\data\license-opendataphilly\tf-idf\tf-idf-85.xlsx')
matched_OL = matched_OL.set_index('left_index')

# %%
matched_OL = drop_duplicates_by_date(matched_OL, "issue_date") # without duplicates
# Out:
# C:\Users\dabinlee\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
len(matched_OL)
# Out:
# 1502

# %%
new_matches = matched_PS.index.difference(matched_OL.index).tolist()

# %%
len(new_matches)
# Out:
# 71

# %% [markdown]
# ## 2. Load useful columns
# * vendor
# * tot_payments
# * department_name
# * year
# * fiscal quarter

# %%
all_files = glob.glob(path + "/*.csv")

li = []

for file in all_files:
    # get vendor, tot_payments, and department_name from original data
    df = pd.read_csv(file, usecols=['vendor', 'tot_payments', 'department_name'])
    
    file_name = file.split('\\')[-1]
    year = file_name.split('-')[1]
    quarter = file_name.split('-')[2].split('.')[0]
    
    df['fy_year'] = year
    df['fy_quarter'] = quarter
    
    li.append(df)

ps = pd.concat(li, ignore_index=False)

# %%
# save cleaned professional services
ps.to_excel (r'C:\Users\dabinlee\Desktop\mwdsbe\data\professional_services\cleaned_ps.xlsx', header=True, index=False)

# %%
ps = pd.read_excel(r'C:\Users\dabinlee\Desktop\mwdsbe\data\professional_services\cleaned_ps.xlsx')

# %%
ps
# Out:
#                department_name  \
# 0      City Controllers Office
# 1      City Controllers Office
# 2      City Controllers Office
# 3      City Controllers Office
# 4      City Controllers Office
# ...                        ...
# 37681                    WATER
# 37682                    WATER
# 37683                    WATER
# 37684                    WATER
# 37685                    WATER
#
#                                                   vendor tot_payments  \
# 0                                      Albert Scaperotto        11908
# 1                    Ceisler Media & Issue Advocacy, LLC            0
# 2                                        Charles Swanson            0
# 3                                Cliftonlarsonallen LLP             0
# 4                                Cliftonlarsonallen LLP             0
# ...                                                  ...          ...
# 37681              Whitman, Requardt and Associates, LLP            0
# 37682              Whitman, Requardt and Associates, LLP       4594.5
# 37683  Wood Environment & Infrastructure Solutions, Inc.            0
# 37684                            Zelenkofske Axelrod LLC       410182
# 37685                                    inContact, Inc.       180728
#
#        fy_year fy_quarter
# 0         2013         Q4
# 1         2013         Q4
# 2         2013         Q4
# 3         2013         Q4
# 4         2013         Q4
# ...        ...        ...
# 37681     2019         Q3
# 37682     2019         Q3
# 37683     2019         Q3
# 37684     2019         Q3
# 37685     2019         Q3
#
# [37686 rows x 5 columns]

# %% [markdown]
# ## Full Merge with Registry
# * TF-IDF 85
# * on company_name and vendor

# %%
# clean ps vendor column
ignore_words = ['inc', 'group', 'llc', 'corp', 'pc', 'incorporated', 'ltd', 'co', 'associates', 'services', 'company', 'enterprises', 'enterprise', 'service', 'corporation']
cleaned_ps = skool.clean_strings(ps, ['vendor'], True, ignore_words)
cleaned_ps = cleaned_ps.dropna(subset=['vendor'])

# %% [markdown]
# keep duplicates: one vendor can have multiple payments

# %%
t1 = time.time()
merged = (
    skool.tf_idf_merge(cleaned_registry, cleaned_ps, left_on="company_name", right_on="vendor", score_cutoff=85, max_matches = 100)
    .pipe(skool.tf_idf_merge, cleaned_registry, cleaned_ps, left_on="dba_name", right_on="vendor", score_cutoff=85, max_matches = 100)
)
t = time.time() - t1

# %%
print('Execution time:', t, 'sec')
# Out:
# Execution time: 67.21271276473999 sec

# %%
len(merged)
# Out:
# 6295

# %%
matched = merged.dropna(subset=['vendor'])

# %%
len(matched)
# Out:
# 3382

# %%
matched.head()
# Out:
#         company_name dba_name owner_first owner_last  \
# 12                4u  stellar       Liang       Chen
# 12                4u  stellar       Liang       Chen
# 12                4u  stellar       Liang       Chen
# 12                4u  stellar       Liang       Chen
# 27  a k architecture      NaN        Lisa  Armstrong
#
#                           location location_city location_state  zip_code  \
# 12  70 West 36th Street, Ste. #702      New York             NY   10018.0
# 12  70 West 36th Street, Ste. #702      New York             NY   10018.0
# 12  70 West 36th Street, Ste. #702      New York             NY   10018.0
# 12  70 West 36th Street, Ste. #702      New York             NY   10018.0
# 27                2425 Pine Street  Philadelphia             PA   19103.0
#
#                    mailing_address  mailing_city  ...        lat       lng  \
# 12  70 West 36th Street, Ste. #702      New York  ...        NaN       NaN
# 12  70 West 36th Street, Ste. #702      New York  ...        NaN       NaN
# 12  70 West 36th Street, Ste. #702      New York  ...        NaN       NaN
# 12  70 West 36th Street, Ste. #702      New York  ...        NaN       NaN
# 27                2425 Pine Street  Philadelphia  ...  39.947695 -75.18109
#
#                       geometry right_index  match_probability  \
# 12                        None     33050.0                1.0
# 12                        None     31193.0                1.0
# 12                        None     36125.0                1.0
# 12                        None     34416.0                1.0
# 27  POINT (-75.18109 39.94770)     37354.0                1.0
#
#       department_name            vendor  tot_payments  fy_year fy_quarter
# 12  DISTRICT ATTORNEY           stellar        129210   2019.0         Q1
# 12  DISTRICT ATTORNEY           stellar         60000   2018.0         Q4
# 12  DISTRICT ATTORNEY           stellar        138150   2019.0         Q3
# 12  DISTRICT ATTORNEY           stellar        129210   2019.0         Q2
# 27    PUBLIC PROPERTY  a k architecture         45719   2019.0         Q3
#
# [5 rows x 27 columns]

# %%
# save cleaned professional services
matched.to_excel (r'C:\Users\dabinlee\Desktop\mwdsbe\data\professional_services\matched.xlsx', header=True)

# %%
matched = pd.read_excel(r'C:\Users\dabinlee\Desktop\mwdsbe\data\professional_services\matched.xlsx')

# %%
matched.rename(columns={'Unnamed: 0': 'left_index'}, inplace=True)

# %%
matched.set_index('left_index', inplace=True)

# %%
matched
# Out:
#                 company_name dba_name owner_first owner_last  \
# left_index
# 12                        4u  stellar       Liang       Chen
# 12                        4u  stellar       Liang       Chen
# 12                        4u  stellar       Liang       Chen
# 12                        4u  stellar       Liang       Chen
# 27          a k architecture      NaN        Lisa  Armstrong
# ...                      ...      ...         ...        ...
# 3118            zweig ramick      NaN      Jeanne      Zweig
# 3118            zweig ramick      NaN      Jeanne      Zweig
# 3118            zweig ramick      NaN      Jeanne      Zweig
# 3118            zweig ramick      NaN      Jeanne      Zweig
# 3118            zweig ramick      NaN      Jeanne      Zweig
#
#                                   location location_city location_state  \
# left_index
# 12          70 West 36th Street, Ste. #702      New York             NY
# 12          70 West 36th Street, Ste. #702      New York             NY
# 12          70 West 36th Street, Ste. #702      New York             NY
# 12          70 West 36th Street, Ste. #702      New York             NY
# 27                        2425 Pine Street  Philadelphia             PA
# ...                                    ...           ...            ...
# 3118                    2320 Faunce Street  Philadelphia             PA
# 3118                    2320 Faunce Street  Philadelphia             PA
# 3118                    2320 Faunce Street  Philadelphia             PA
# 3118                    2320 Faunce Street  Philadelphia             PA
# 3118                    2320 Faunce Street  Philadelphia             PA
#
#             zip_code                 mailing_address  mailing_city  ...  \
# left_index                                                          ...
# 12             10018  70 West 36th Street, Ste. #702      New York  ...
# 12             10018  70 West 36th Street, Ste. #702      New York  ...
# 12             10018  70 West 36th Street, Ste. #702      New York  ...
# 12             10018  70 West 36th Street, Ste. #702      New York  ...
# 27             19103                2425 Pine Street  Philadelphia  ...
# ...              ...                             ...           ...  ...
# 3118           19152              2320 Faunce Street  Philadelphia  ...
# 3118           19152              2320 Faunce Street  Philadelphia  ...
# 3118           19152              2320 Faunce Street  Philadelphia  ...
# 3118           19152              2320 Faunce Street  Philadelphia  ...
# 3118           19152              2320 Faunce Street  Philadelphia  ...
#
#                   lat        lng  \
# left_index
# 12                NaN        NaN
# 12                NaN        NaN
# 12                NaN        NaN
# 12                NaN        NaN
# 27          39.947695 -75.181090
# ...               ...        ...
# 3118        40.051443 -75.055115
# 3118        40.051443 -75.055115
# 3118        40.051443 -75.055115
# 3118        40.051443 -75.055115
# 3118        40.051443 -75.055115
#
#                                                 geometry right_index  \
# left_index
# 12                                                   NaN       33050
# 12                                                   NaN       31193
# 12                                                   NaN       36125
# 12                                                   NaN       34416
# 27          POINT (-75.18109018817358 39.94769504710167)       37354
# ...                                                  ...         ...
# 3118        POINT (-75.05511537466825 40.05144316591304)        6340
# 3118        POINT (-75.05511537466825 40.05144316591304)        4663
# 3118        POINT (-75.05511537466825 40.05144316591304)        3109
# 3118        POINT (-75.05511537466825 40.05144316591304)         204
# 3118        POINT (-75.05511537466825 40.05144316591304)        1894
#
#             match_probability    department_name            vendor  \
# left_index
# 12                        1.0  DISTRICT ATTORNEY           stellar
# 12                        1.0  DISTRICT ATTORNEY           stellar
# 12                        1.0  DISTRICT ATTORNEY           stellar
# 12                        1.0  DISTRICT ATTORNEY           stellar
# 27                        1.0    PUBLIC PROPERTY  a k architecture
# ...                       ...                ...               ...
# 3118                      1.0           COMMERCE      zweig ramick
# 3118                      1.0           Commerce      zweig ramick
# 3118                      1.0           Commerce      zweig ramick
# 3118                      1.0           Commerce      zweig ramick
# 3118                      1.0           Commerce      zweig ramick
#
#             tot_payments  fy_year fy_quarter
# left_index
# 12                129210     2019         Q1
# 12                 60000     2018         Q4
# 12                138150     2019         Q3
# 12                129210     2019         Q2
# 27                 45719     2019         Q3
# ...                  ...      ...        ...
# 3118             32062.2     2014         Q4
# 3118             32062.2     2014         Q3
# 3118             26552.2     2014         Q2
# 3118                 NaN     2013         Q4
# 3118                   0     2014         Q1
#
# [3382 rows x 27 columns]
