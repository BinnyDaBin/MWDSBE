# %% [markdown]
# # Matching Registry and PA State Business License Data

# %%
import pandas as pd
import mwdsbe
import mwdsbe.datasets.licenses as licenses
import schuylkill as skool
import time

# %%
def drop_duplicates_by_date(df, date_column):
    df.sort_values(by=date_column, ascending=False, inplace=True)
    df = df.loc[~df.index.duplicated(keep="first")]
    df.sort_index(inplace=True)
    return df

# %% [markdown]
# ## Data

# %%
registry = mwdsbe.load_registry() # geopandas df
license = licenses.CommercialActivityLicenses().get()

# %%
registry.head()
# Out:
#                            company_name    dba_name owner_first owner_last  \
# registry_id
# 0                119 Degrees Architects         NaN      Rafael     Utrera
# 1                         12Bravo Group         NaN     JEFFREY  YEKENCHIK
# 2            1st Choice Financial Group    ProVisio    Kathrina      Nease
# 3                     212 Harakawa Inc.  Two Twelve         Ann   Harakawa
# 4                   215 Media Solutions         NaN      Dewain    Johnson
#
#                                  location  location_city location_state  \
# registry_id
# 0            1503 Green Street, Suite # 4   Philadelphia             PA
# 1                     236 McKendimen Road  Medford Lakes             NJ
# 2                      133 N. 21st Street      Camp Hill             PA
# 3            236 W 27th Street, Suite 802       New York             NY
# 4                       810 Felton Avenue    Sharon Hill             PA
#
#              zip_code               mailing_address   mailing_city  \
# registry_id
# 0             19130.0  1503 Green Street, Suite # 4   Philadelphia
# 1              8055.0           236 McKendimen Road  Medford Lakes
# 2             17011.0            133 N. 21st Street      Camp Hill
# 3             10001.0  236 W 27th Street, Suite 802       New York
# 4             19079.0             810 Felton Avenue    Sharon Hill
#
#             mailing_state  mailing_zip certification_type  \
# registry_id
# 0                      PA      19130.0                MBE
# 1                      NJ       8055.0               DSBE
# 2                      PA      17011.0                WBE
# 3                      NY      10001.0               MWBE
# 4                      PA      19079.0                MBE
#
#                                                     capability  local  \
# registry_id
# 0            NAICS 5413 Architectural, Engineering, and Rel...   True
# 1            Addition, alteration and renovation for-sale b...  False
# 2                           NAICS 928120 International Affairs  False
# 3            Graphic Design Services; Graphic design servic...  False
# 4            NAICS 5414 Specialized Design Services ; NAICS...  False
#
#              out_of_state location_standard        lat        lng  \
# registry_id
# 0                   False     1503 GREEN ST  39.964275 -75.163042
# 1                    True               NaN        NaN        NaN
# 2                   False               NaN        NaN        NaN
# 3                    True               NaN        NaN        NaN
# 4                   False               NaN        NaN        NaN
#
#                                geometry
# registry_id
# 0            POINT (-75.16304 39.96427)
# 1                                  None
# 2                                  None
# 3                                  None
# 4                                  None

# %%
state_license = pd.read_csv('./data/PAStateBusinessLicense/Sales_Tax_Licenses_and_Certificates_Current_Monthly_County_Revenue.csv')

# %%
print('Size of state_license data:', len(state_license))
# Out:
# Size of state_license data: 347532

# %%
# convert state_license column names from titlecase to snakecase
def to_snake_case(aList):
    res = []
    for item in aList:
        words = item.strip().lower().split(' ')
        item = '_'.join(words)
        res.append(item)
    return res

# %%
state_license.columns = to_snake_case(state_license.columns.tolist())

# %%
# clean data
ignore_words = ['inc', 'group', 'llc', 'corp', 'pc', 'incorporated', 'ltd', 'co', 'associates', 'services', 'company', 'enterprises', 'enterprise', 'service', 'corporation']
cleaned_registry = skool.clean_strings(registry, ['company_name', 'dba_name'], True, ignore_words)
cleaned_license = skool.clean_strings(license, ['company_name'], True, ignore_words)
cleaned_state_license = skool.clean_strings(state_license, ['legal_name', 'trade_name'], True, ignore_words)

cleaned_registry = cleaned_registry.dropna(subset=['company_name'])
cleaned_license = cleaned_license.dropna(subset=['company_name'])
cleaned_state_license = cleaned_state_license.dropna(subset=['legal_name'])

# %%
len(cleaned_license)
# Out:
# 203541

# %%
cleaned_state_license.head()
# Out:
#       county             legal_name                 trade_name postal_code  \
# 0      ADAMS           nugen energy               nugen energy       17331
# 1  ALLEGHENY                 cellux  mobilexpress west mifflin       15123
# 2  ALLEGHENY  dina persichetti hill              nails at last       15101
# 3      ADAMS         elwood mummert           mummert elwood k  17331-7700
# 4  ALLEGHENY             cosmograce                  brillobox       15224
#
#   country account_number license_type expiration_date  \
# 0      US       67**9551       Retail      09/30/2021
# 1      US       85**6245       Retail      01/31/2021
# 2      US       81**6740       Retail      02/29/2024
# 3      US       81**7441       Retail      01/31/2021
# 4      US       67**9185       Retail      09/30/2021
#
#                                address_with_lat/long
# 0  1601 CARLISLE PIKE\nHANOVER, PA 17331\n(39.834...
# 1  3075 CLAIRON RD CENTURY III MA\nWEST MIFFLIN, ...
# 2  4085 WM FLYNN HWY STE 10A\nALLISON PARK, PA 15101
# 3  700 PINE GROVE RD\nHANOVER, PA 17331-7700\n(39...
# 4  4104 PENN AVE\nPITTSBURGH, PA 15224\n(40.46574...

# %%
# just getting PA state in registry
pa_registry = cleaned_registry[cleaned_registry.location_state == 'PA']

# %%
len(pa_registry)
# Out:
# 1769

# %% [markdown]
# ## Merge registry and state_license by company_name and legal_name / trade name

# %%
t1 = time.time()
merged = (
    skool.tf_idf_merge(pa_registry, cleaned_state_license, left_on="company_name", right_on="legal_name", score_cutoff=85)
    .pipe(skool.tf_idf_merge, pa_registry, cleaned_state_license, left_on="company_name", right_on="trade_name", score_cutoff=85)
    .pipe(skool.tf_idf_merge, pa_registry, cleaned_state_license, left_on="dba_name", right_on="legal_name", score_cutoff=85)
    .pipe(skool.tf_idf_merge, pa_registry, cleaned_state_license, left_on="dba_name", right_on="trade_name", score_cutoff=85)
)
t = time.time() - t1

# %%
print('Execution time:', t/60, 'min')
# Out:
# Execution time: 21.944276861349742 min

# %%
matched = merged.dropna(subset=['legal_name', 'dba_name'], how='all')

# %%
len(matched)
# Out:
# 585

# %%
matched_state = matched

# %%
# matched.to_excel (r'C:\Users\dabinlee\Desktop\mwdsbe\data\state_license\pa-registry-full-state-license\tf-idf-85.xlsx', header=True)

# %%
matched_state = pd.read_excel(r'C:\Users\dabinlee\Desktop\mwdsbe\data\state_license\pa-registry-full-state-license\tf-idf-85.xlsx')

# %%
len(matched_state)
# Out:
# 585

# %%
exact_matches = matched_state[matched_state.match_probability == 1]

# %%
len(exact_matches)
# Out:
# 139

# %% [markdown]
# ##### Eliminate companies with different zip code

# %%
matched_state['postal_code_clean'] = matched_state.postal_code.astype(str).apply(lambda x : x.split("-")[0]).astype(float)
# Out:
# C:\Users\dabinlee\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
matched_state = matched_state.set_index('left_index')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-107-4aeda51781a3> in <module>
# ----> 1 matched_state = matched_state.set_index('left_index')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4409
#    4410         if missing:
# -> 4411             raise KeyError("None of {} are in the columns".format(missing))
#    4412
#    4413         if inplace:
#
# KeyError: "None of ['left_index'] are in the columns"

# %%
len(matched_state)
# Out:
# 585

# %%
# matched_state_zip = matched_state[matched_state.zip_code == matched_state.postal_code_clean]

# %%
# len(matched_state_zip)
# Out:
# 247

# %%
matched_state['expiration_date'] = pd.to_datetime(matched_state['expiration_date'], errors='coerce')
# Out:
# C:\Users\dabinlee\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
matched_state = drop_duplicates_by_date(matched_state, 'expiration_date')
# Out:
# C:\Users\dabinlee\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dabinlee\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
len(matched_state) # state_license, same zip code, without duplicates
# Out:
# 564

# %% [markdown]
# ## Comparing between match between "registry-opendata license" and "registry-state license"
# How many more new companies do we get from registry-opendata license matching?

# %%
# t1 = time.time()
# merged = (
#     skool.tf_idf_merge(cleaned_registry, cleaned_license, on="company_name", score_cutoff=85)
#     .pipe(skool.tf_idf_merge, cleaned_registry, cleaned_license, left_on="dba_name", right_on="company_name", score_cutoff=85)
# )
# t = time.time() - t1

# %%
# print('Execution time:', t/60, 'min')

# %%
# matched_openphilly_license = merged.dropna(subset=['company_name_y'])

# %%
# len(matched_openphilly_license)

# %%
# matched_openphilly_license.issue_date = matched_openphilly_license.issue_date.astype(str)

# %%
# matched_openphilly_license.to_excel (r'C:\Users\dabinlee\Desktop\mwdsbe\data\license-opendataphilly\tf-idf\tf-idf-85.xlsx', header=True)

# %% [markdown]
# ##### Loading matched of registry and opendataphilly_license data

# %%
matched_opendataphilly_license = pd.read_excel(r'C:\Users\dabinlee\Desktop\mwdsbe\data\license-opendataphilly\tf-idf\tf-idf-85.xlsx')

# %%
matched_opendataphilly_license = matched_opendataphilly_license.set_index('left_index')

# %%
len(matched_opendataphilly_license)
# Out:
# 1642

# %%
matched_opendataphilly_license = drop_duplicates_by_date(matched_opendataphilly_license, "issue_date") # without duplicates
# Out:
# C:\Users\dabinlee\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
len(matched_opendataphilly_license)
# Out:
# 1502

# %%
matched_opendataphilly_license.tail()
# Out:
#                           company_name_x dba_name owner_first owner_last  \
# left_index
# 3107        zavorski masonry restoration      NaN        Lisa   Zavorski
# 3110                   zenga engineering      NaN   Gwendolyn     Lodise
# 3113                       zizza highway      NaN      Arlene      Zizza
# 3115                               zones      NaN         Mr.      Lalji
# 3117                                zora      NaN     Charles   O'Reilly
#
#                           location location_city location_state  zip_code  \
# left_index
# 3107               717 Ford Avenue     Langhorne             PA   19047.0
# 3110         313 East Broad Street       Palmyra             NJ    8065.0
# 3113        382 CONCHESTER HIGHWAY    Glen Mills             PA   19342.0
# 3115               1102 15TH ST SW        Auburn             WA   98001.0
# 3117              1901 Dorcas Lane    Wilmington             DE   19806.0
#
#                    mailing_address mailing_city  ... location_standard  lat  \
# left_index                                       ...
# 3107               717 Ford Avenue    Langhorne  ...               NaN  NaN
# 3110         313 East Broad Street      Palmyra  ...               NaN  NaN
# 3113        382 CONCHESTER HIGHWAY   Glen Mills  ...               NaN  NaN
# 3115               1102 15TH ST SW       Auburn  ...               NaN  NaN
# 3117              1901 Dorcas Lane   Wilmington  ...               NaN  NaN
#
#            lng geometry  right_index  match_probability license_num  \
# left_index
# 3107       NaN      NaN       101652           1.000000      343160
# 3110       NaN      NaN       136814           1.000000      509641
# 3113       NaN      NaN       189864           1.000000      770177
# 3115       NaN      NaN        26525           0.860842      145187
# 3117       NaN      NaN        88625           1.000000       33338
#
#                            issue_date  license_status  \
# left_index
# 3107        2005-10-31 00:00:00+00:00          Active
# 3110        2010-07-26 00:00:00+00:00          Active
# 3113        2018-03-23 00:00:00+00:00          Active
# 3115        2002-05-06 00:00:00+00:00          Active
# 3117        2005-01-28 00:00:00+00:00          Active
#
#                           company_name_y
# left_index
# 3107        zavorski masonry restoration
# 3110                   zenga engineering
# 3113                       zizza highway
# 3115                                zone
# 3117                                zora
#
# [5 rows x 26 columns]

# %%
# unique company?
len(matched_opendataphilly_license.index.unique()) # yes
# Out:
# 1502

# %%
diff = matched_state.index.difference(matched_opendataphilly_license.index).tolist()

# %%
len(diff)
# Out:
# 201

# %%
matched_state.loc[diff][['company_name', 'dba_name', 'legal_name', 'trade_name']]
# Out:
#                             company_name                           dba_name  \
# 2                   1st choice financial                           provisio
# 14                                   4x3                                NaN
# 28                           a n s steel                                NaN
# 65                       acclaim systems                                NaN
# 72     ace construction maintenance more  ace construction maintenance more
# ...                                  ...                                ...
# 3054             westside framing studio                    westside studio
# 3059  whaumbush dba detention physicians               detention physicians
# 3068                           wilson500                                NaN
# 3099              your quality solutions                                NaN
# 3116                         zook motors                                NaN
#
#                   legal_name              trade_name
# 2                 provisions              provisions
# 14                       4x3                     4x3
# 28               a n s steel               ans steel
# 65           acclaim systems         acclaim systems
# 72                       NaN                     NaN
# ...                      ...                     ...
# 3054                     NaN                     NaN
# 3059                     NaN                     NaN
# 3068               wilson500               wilson500
# 3099  your quality solutions  your quality solutions
# 3116             zook motors             zook motors
#
# [201 rows x 4 columns]

# %%
# newly matched: matching with state_license data
difference = matched_state.loc[diff]

# %%
difference_SL = difference

# %%
# difference.to_excel (r'C:\Users\dabinlee\Desktop\mwdsbe\data\difference.xlsx', header=True)

# %% [markdown]
# ## Investigate missing companies in opendataphilly license data
# We found 94 newly matched companies from matching between registry and state_license, why these are not appeared in matching between registry and opendataphilly license data?

# %%
t1 = time.time()
merged = (
    skool.tf_idf_merge(cleaned_registry, cleaned_license, on="company_name", score_cutoff=0)
    .pipe(skool.tf_idf_merge, cleaned_registry, cleaned_license, left_on="dba_name", right_on="company_name", score_cutoff=0)
)
t = time.time() - t1

# %%
print('Execution time:', t/60, 'min')
# Out:
# Execution time: 3.9544533332188925 min

# %%
matched = merged.dropna(subset=['company_name_y'])

# %%
len(matched)
# Out:
# 3165

# %%
matched = drop_duplicates_by_date(matched, 'issue_date')
# Out:
# C:\Users\dabinlee\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dabinlee\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
# matched.issue_date = matched.issue_date.astype(str)
# matched.to_excel(r'C:\Users\dabinlee\Desktop\mwdsbe\data\tf-idf0.xlsx', header=True)

# %%
matched
# Out:
#               company_name_x    dba_name owner_first owner_last  \
# 0     119 degrees architects         NaN      Rafael     Utrera
# 1                    12bravo         NaN     JEFFREY  YEKENCHIK
# 2       1st choice financial    provisio    Kathrina      Nease
# 3               212 harakawa  two twelve         Ann   Harakawa
# 4        215 media solutions         NaN      Dewain    Johnson
# ...                      ...         ...         ...        ...
# 3114                   zoeza         NaN       Jason    Wingard
# 3115                   zones         NaN         Mr.      Lalji
# 3116             zook motors         NaN       Susan     Wilson
# 3117                    zora         NaN     Charles   O'Reilly
# 3118            zweig ramick         NaN      Jeanne      Zweig
#
#                               location  location_city location_state  \
# 0         1503 Green Street, Suite # 4   Philadelphia             PA
# 1                  236 McKendimen Road  Medford Lakes             NJ
# 2                   133 N. 21st Street      Camp Hill             PA
# 3         236 W 27th Street, Suite 802       New York             NY
# 4                    810 Felton Avenue    Sharon Hill             PA
# ...                                ...            ...            ...
# 3114  536 W. Moreland Avenue, Suite C.   Philadelphia             PA
# 3115                   1102 15TH ST SW         Auburn             WA
# 3116               25 Willow Run Drive           Kane             PA
# 3117                  1901 Dorcas Lane     Wilmington             DE
# 3118                2320 Faunce Street   Philadelphia             PA
#
#       zip_code                   mailing_address   mailing_city  ...  \
# 0      19130.0      1503 Green Street, Suite # 4   Philadelphia  ...
# 1       8055.0               236 McKendimen Road  Medford Lakes  ...
# 2      17011.0                133 N. 21st Street      Camp Hill  ...
# 3      10001.0      236 W 27th Street, Suite 802       New York  ...
# 4      19079.0                 810 Felton Avenue    Sharon Hill  ...
# ...        ...                               ...            ...  ...
# 3114   19118.0  536 W. Moreland Avenue, Suite C.   Philadelphia  ...
# 3115   98001.0                   1102 15TH ST SW         Auburn  ...
# 3116   16735.0               25 Willow Run Drive           Kane  ...
# 3117   19806.0                  1901 Dorcas Lane     Wilmington  ...
# 3118   19152.0                2320 Faunce Street   Philadelphia  ...
#
#        location_standard        lat        lng                    geometry  \
# 0          1503 GREEN ST  39.964275 -75.163042  POINT (-75.16304 39.96427)
# 1                    NaN        NaN        NaN                        None
# 2                    NaN        NaN        NaN                        None
# 3                    NaN        NaN        NaN                        None
# 4                    NaN        NaN        NaN                        None
# ...                  ...        ...        ...                         ...
# 3114  536 W MORELAND AVE  40.059613 -75.207085  POINT (-75.20708 40.05961)
# 3115                 NaN        NaN        NaN                        None
# 3116                 NaN        NaN        NaN                        None
# 3117                 NaN        NaN        NaN                        None
# 3118      2320 FAUNCE ST  40.051443 -75.055115  POINT (-75.05512 40.05144)
#
#       right_index  match_probability license_num                issue_date  \
# 0        131105.0           1.000000    480115.0 2009-07-31 00:00:00+00:00
# 1        108854.0           0.566374    379054.0 2006-07-26 00:00:00+00:00
# 2         37296.0           0.742458    174332.0 2004-10-12 00:00:00+00:00
# 3          4417.0           0.489846     82446.0 1995-10-06 00:00:00+00:00
# 4        147975.0           0.668217    565674.0 2012-05-30 00:00:00+00:00
# ...           ...                ...         ...                       ...
# 3114     122356.0           0.789721    436094.0 2008-02-20 00:00:00+00:00
# 3115      26525.0           0.860842    145187.0 2002-05-06 00:00:00+00:00
# 3116     136273.0           0.553686    505624.0 2010-06-15 00:00:00+00:00
# 3117      88625.0           1.000000     33338.0 2005-01-28 00:00:00+00:00
# 3118      82695.0           0.448378     33731.0 2005-01-28 00:00:00+00:00
#
#       license_status          company_name_y
# 0             Active  119 degrees architects
# 1             Active                   bravo
# 2             Active   omni choice financial
# 3             Active                  baraka
# 4             Active   forte media solutions
# ...              ...                     ...
# 3114          Active               the zoeza
# 3115          Active                    zone
# 3116          Active       beaverbrook motor
# 3117          Active                    zora
# 3118          Active         rosenzweig gary
#
# [3025 rows x 26 columns]

# %%
cleaned_registry.loc[cleaned_registry.index.difference(matched.index)]
# Out:
#                                company_name dba_name owner_first owner_last  \
# 5                                        22      NaN    Caroline     Harper
# 14                                      4x3      NaN         Amy      Siano
# 181                            ama resource      NaN  Anne Marie       Auld
# 197               american renewable energy      NaN         Wei       Wang
# 203                      ampm north america      NaN       James      Moody
# ...                                     ...      ...         ...        ...
# 3015                          vj of suffolk      NaN       Vijay      Desai
# 3017                                    vkg      NaN    Kimberly  Hawthorne
# 3079  woods peacock engineering consultants      NaN      Carrie    Seifert
# 3087                                     wu      NaN     Raymond         Wu
# 3101                                     yu      NaN    K. Peter         Yu
#
#                                     location location_city location_state  \
# 5                            757 Public Road     Bethlehem             PA
# 14                 63 W Lancaster Ave, Ste 4       Ardmore             PA
# 181                            P.O. Box 9796    Wilmington             DE
# 197   255 Old New Brunswick Road, Suite N280    Piscataway             NJ
# 203                          612 Vernon Road  Philadelphia             PA
# ...                                      ...           ...            ...
# 3015  1090 King Georges Post Road, Suite 301        Edison             NJ
# 3017                    734 E. Dorset Street  Philadelphia             PA
# 3079         5250 CHEROKEE AVENUE, SUITE 420    Alexandria             VA
# 3087              100 Gaither Drive, Suite C  Mount Laurel             NJ
# 3101                     200 Riverfront Blvd  Elmwood Park             NJ
#
#       zip_code                         mailing_address  mailing_city  \
# 5      18015.0                         757 Public Road     Bethlehem
# 14     19003.0               63 W Lancaster Ave, Ste 4       Ardmore
# 181    19809.0                           P.O. Box 9796    Wilmington
# 197     8854.0  255 Old New Brunswick Road, Suite N280    Piscataway
# 203    19119.0                         612 Vernon Road  Philadelphia
# ...        ...                                     ...           ...
# 3015    8837.0  1090 King Georges Post Road, Suite 301        Edison
# 3017   19119.0                    734 E. Dorset Street  Philadelphia
# 3079   22312.0         5250 CHEROKEE AVENUE, SUITE 420    Alexandria
# 3087    8054.0     100 Gaither Drive, Suite C, Suite C  Mount Laurel
# 3101    7407.0                     200 Riverfront Blvd  Elmwood Park
#
#      mailing_state  mailing_zip certification_type  \
# 5               PA      18015.0                WBE
# 14              PA      19003.0                WBE
# 181             DE      19809.0                WBE
# 197             NJ       8854.0                MBE
# 203             PA      19119.0                MBE
# ...            ...          ...                ...
# 3015            NJ       8837.0                MBE
# 3017            PA      19119.0               MWBE
# 3079            VA      22312.0                WBE
# 3087            NJ       8054.0                MBE
# 3101            NJ       7407.0                MBE
#
#                                              capability  local  out_of_state  \
# 5     All Other Specialty Trade Contractors ; Enviro...  False         False
# 14    Graphic Design Services; Graphic design servic...  False         False
# 181   Waste materials merchant wholesalers  ; Materi...  False          True
# 197                                 26060\tINSULATION;   False          True
# 203   26046\tGENERAL CONSTRUCTION-REPAIR; 90611\tHea...   True         False
# ...                                                 ...    ...           ...
# 3015  Administrative Management and General Manageme...  False          True
# 3017  Computer Training  ; Computer Training  ; Prof...   True         False
# 3079  Engineering consulting services; Engineering s...  False          True
# 3087  Addition, alteration and renovation operative ...  False          True
# 3101  Engineering services; Building inspection bure...  False          True
#
#      location_standard        lat        lng                    geometry
# 5                  NaN        NaN        NaN                        None
# 14                 NaN        NaN        NaN                        None
# 181                NaN        NaN        NaN                        None
# 197                NaN        NaN        NaN                        None
# 203      612 VERNON RD  40.061407 -75.177179  POINT (-75.17718 40.06141)
# ...                ...        ...        ...                         ...
# 3015               NaN        NaN        NaN                        None
# 3017     734 DORSET ST  40.062765 -75.175337  POINT (-75.17534 40.06276)
# 3079               NaN        NaN        NaN                        None
# 3087               NaN        NaN        NaN                        None
# 3101               NaN        NaN        NaN                        None
#
# [94 rows x 20 columns]

# %%
cleaned_license.loc[cleaned_license.company_name == '22']
# Out:
#         license_num                issue_date license_status company_name
# 168732     667661.0 2015-06-10 00:00:00+00:00         Active           22

# %%
missed_by_OL = matched.loc[difference.index]
# Out:
# C:\Users\dabinlee\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   """Entry point for launching an IPython kernel.

# %%
missed_by_OL
# Out:
#                                          company_name_x  \
# left_index
# 28                                          a n s steel
# 65                                      acclaim systems
# 100         advanced technology and systems integrators
# 115                            affairs to be remembered
# 195         american personnel managers and consultants
# ...                                                 ...
# 3013                                       visual sound
# 3039                   watts window cleaning janitorial
# 3068                                          wilson500
# 3099                             your quality solutions
# 3116                                        zook motors
#
#                                            dba_name owner_first  \
# left_index
# 28                                              NaN       Linda
# 65                                              NaN     Kailash
# 100                                             NaN     Venkata
# 115                                             NaN      Eileen
# 195         american personnel managers consultants    Patricia
# ...                                             ...         ...
# 3013                                            NaN    MARJORIE
# 3039                       watts facility solutions      Yvette
# 3068                                            NaN     Corinna
# 3099                                            NaN      Angela
# 3116                                            NaN       Susan
#
#                   owner_last                         location  location_city  \
# left_index
# 28                   Manning              4340 Sepviva Street   Philadelphia
# 65                  Kalantri  110 EAST PENNSYLVANIA BOULEVARD   Feasterville
# 100                  Gundala                 209 Heather Road    Upper Darby
# 115         Williamson-Getty                    555 Abbott Dr       Broomall
# 195                 Gingrich  3607 ROSEMONT AVENUE, SUITE 101      Camp Hill
# ...                      ...                              ...            ...
# 3013                BOGOSIAN                     485 PARK WAY       Broomall
# 3039                   Watts           4548 Market Street, M4   Philadelphia
# 3068                  Wilson               500 Arlington Road      Camp Hill
# 3099                Lundberg             24 Cobblestone Drive  Willow Street
# 3116                  Wilson              25 Willow Run Drive           Kane
#
#            location_state  zip_code                  mailing_address  \
# left_index
# 28                     PA   19124.0              4340 Sepviva Street
# 65                     PA   19053.0  110 EAST PENNSYLVANIA BOULEVARD
# 100                    PA   19082.0                 209 Heather Road
# 115                    PA   19008.0                    555 Abbott Dr
# 195                    PA   17011.0  3607 ROSEMONT AVENUE, SUITE 101
# ...                   ...       ...                              ...
# 3013                   PA   19008.0                     485 PARK WAY
# 3039                   PA   19139.0           4548 Market Street, M4
# 3068                   PA   17011.0               500 Arlington Road
# 3099                   PA   17584.0             24 Cobblestone Drive
# 3116                   PA   16735.0              25 Willow Run Drive
#
#              mailing_city  ... location_standard        lat        lng  \
# left_index                 ...
# 28           Philadelphia  ...   4340 SEPVIVA ST  40.003004 -75.079992
# 65           Feasterville  ...               NaN        NaN        NaN
# 100           Upper Darby  ...               NaN        NaN        NaN
# 115              Broomall  ...               NaN        NaN        NaN
# 195             Camp Hill  ...               NaN        NaN        NaN
# ...                   ...  ...               ...        ...        ...
# 3013             Broomall  ...               NaN        NaN        NaN
# 3039         Philadelphia  ...    4548 MARKET ST  39.958043 -75.212655
# 3068            Camp Hill  ...               NaN        NaN        NaN
# 3099        Willow Street  ...               NaN        NaN        NaN
# 3116                 Kane  ...               NaN        NaN        NaN
#
#                               geometry right_index match_probability  \
# left_index
# 28          POINT (-75.07999 40.00300)     56931.0          0.629722
# 65                                None     31063.0          0.568845
# 100                               None    130738.0          0.795560
# 115                               None     50976.0          0.469441
# 195                               None    109303.0          0.836791
# ...                                ...         ...               ...
# 3013                              None     16797.0          0.697870
# 3039        POINT (-75.21266 39.95804)    135282.0          0.816941
# 3068                              None    113155.0          0.503507
# 3099                              None    129579.0          0.621094
# 3116                              None    136273.0          0.553686
#
#            license_num                 issue_date  license_status  \
# left_index
# 28            182098.0  2005-01-28 00:00:00+00:00        Inactive
# 65            164123.0  2003-07-16 00:00:00+00:00          Active
# 100           478125.0  2009-07-01 00:00:00+00:00          Active
# 115            32121.0  2005-01-28 00:00:00+00:00          Active
# 195           381151.0  2006-08-14 00:00:00+00:00          Active
# ...                ...                        ...             ...
# 3013          118778.0  1999-07-15 00:00:00+00:00          Active
# 3039          102365.0  2010-04-20 00:00:00+00:00          Active
# 3068           11690.0  2007-01-25 00:00:00+00:00          Active
# 3099           37939.0  2009-04-22 00:00:00+00:00          Active
# 3116          505624.0  2010-06-15 00:00:00+00:00          Active
#
#                               company_name_y
# left_index
# 28                                     steel
# 65                               l m systems
# 100         advanced technology and syst int
# 115                          catered affairs
# 195           american personnel managers an
# ...                                      ...
# 3013                        visual solutions
# 3039                   watts window cleaning
# 3068                                 wilsons
# 3099                             air quality
# 3116                       beaverbrook motor
#
# [94 rows x 26 columns]

# %%
# missed_by_OL.issue_date = missed_by_OL.issue_date.astype(str)
# missed_by_OL.to_excel (r'C:\Users\dabinlee\Desktop\mwdsbe\data\missing94.xlsx', header=True)

# %% [markdown]
# ##### median

# %%
missed_by_OL.match_probability.median()
# Out:
# 0.6752304834235887

# %%
difference.match_probability.median()
# Out:
# 1.0

# %% [markdown]
# ##### mean

# %%
missed_by_OL.match_probability.mean()
# Out:
# 0.6641255379006749

# %%
difference.match_probability.mean()
# Out:
# 0.991423969309069

# %% [markdown]
# ##### max & min

# %%
missed_by_OL.match_probability.max()
# Out:
# 0.8497287372705913

# %%
missed_by_OL.match_probability.min()
# Out:
# 0.39815105014993596

# %%
difference.match_probability.max()
# Out:
# 1.0

# %%
difference.match_probability.min()
# Out:
# 0.858655159823412

# %%
difference_OL_SL = difference.merge(missed_by_OL, left_index=True, right_index=True)

# %%
difference_SL_OL = difference_OL_SL[['company_name','dba_name_x', 'match_probability_x', 'legal_name', 'trade_name', 'match_probability_y', 'company_name_y']]

# %%
difference_SL_OL.to_excel(r'C:\Users\dabinlee\Desktop\mwdsbe\data\94-difference-SL-OL.xlsx', header=True)

# %%
difference_SL_OL
# Out:
#                                            company_name  \
# left_index
# 28                                          a n s steel
# 65                                      acclaim systems
# 100         advanced technology and systems integrators
# 115                            affairs to be remembered
# 195         american personnel managers and consultants
# ...                                                 ...
# 3013                                       visual sound
# 3039                   watts window cleaning janitorial
# 3068                                          wilson500
# 3099                             your quality solutions
# 3116                                        zook motors
#
#                                          dba_name_x  match_probability_x  \
# left_index
# 28                                              NaN             1.000000
# 65                                              NaN             1.000000
# 100                                             NaN             0.859795
# 115                                             NaN             1.000000
# 195         american personnel managers consultants             0.888080
# ...                                             ...                  ...
# 3013                                            NaN             1.000000
# 3039                       watts facility solutions             1.000000
# 3068                                            NaN             1.000000
# 3099                                            NaN             1.000000
# 3116                                            NaN             1.000000
#
#                                   legal_name  \
# left_index
# 28                               a n s steel
# 65                           acclaim systems
# 100              advanced technology systems
# 115                 affairs to be remembered
# 195              american personnel managers
# ...                                      ...
# 3013                            visual sound
# 3039        watts window cleaning janitorial
# 3068                               wilson500
# 3099                  your quality solutions
# 3116                             zook motors
#
#                                    trade_name  match_probability_y  \
# left_index
# 28                                  ans steel             0.629722
# 65                            acclaim systems             0.568845
# 100         advanced technology systems integ             0.795560
# 115                   affairs to be rememberd             0.469441
# 195         american personnel managers consu             0.836791
# ...                                       ...                  ...
# 3013                             visual sound             0.697870
# 3039         watts window cleaning janitorial             0.816941
# 3068                                wilson500             0.503507
# 3099                   your quality solutions             0.621094
# 3116                              zook motors             0.553686
#
#                               company_name_y
# left_index
# 28                                     steel
# 65                               l m systems
# 100         advanced technology and syst int
# 115                          catered affairs
# 195           american personnel managers an
# ...                                      ...
# 3013                        visual solutions
# 3039                   watts window cleaning
# 3068                                 wilsons
# 3099                             air quality
# 3116                       beaverbrook motor
#
# [94 rows x 7 columns]

# %% [markdown]
# ### Compare intersection between matched_opendataphilly_license and matched_state_zip
# * matched_opendataphilly_license: matched data between pa_registry and license data from opendataphilly
# * matched_state_zip: matched data between pa_registry and license data from state_registry and filter matches which do not match zipcodes

# %%
intersection = matched_state_zip.index.intersection(matched_opendataphilly_license.index).tolist()

# %%
len(intersection) # 246 - 94
# Out:
# 152

# %%
intersection1 = matched_opendataphilly_license.loc[intersection]

# %%
len(intersection1)
# Out:
# 152

# %%
intersection2 = matched_state_zip.loc[intersection]

# %%
len(intersection2)
# Out:
# 152

# %%
intersection1 = intersection1[['company_name_x', 'dba_name', 'match_probability', 'company_name_y']]

# %%
intersection2 = intersection2[['match_probability', 'legal_name', 'trade_name']]

# %%
intersection = intersection1.merge(intersection2, left_index=True, right_index=True)

# %%
intersection
# Out:
#                                   company_name_x  \
# left_index
# 16                          6 degrees consulting
# 43                 aaaa office warehouse surplus
# 48                                       abbadon
# 64          accessibility modification solutions
# 69                         accu fire fabrication
# ...                                          ...
# 3022              voith mactavish architects llp
# 3037                          wash cycle laundry
# 3044                          webco construction
# 3061                    wilco electronic systems
# 3113                               zizza highway
#
#                                  dba_name  match_probability_x  \
# left_index
# 16                                    NaN             1.000000
# 43          corporate furniture solutions             0.938296
# 48                      superior facility             1.000000
# 64                                    NaN             1.000000
# 69                                    NaN             1.000000
# ...                                   ...                  ...
# 3022                                  NaN             0.933612
# 3037                   wash cycle laundry             1.000000
# 3044                                  NaN             1.000000
# 3061                                  NaN             1.000000
# 3113                                  NaN             1.000000
#
#                                   company_name_y  match_probability_y  \
# left_index
# 16                          6 degrees consulting                  1.0
# 43             aaaa office and warehouse surplus                  1.0
# 48                                       abbadon                  1.0
# 64          accessibility modification solutions                  1.0
# 69                         accu fire fabrication                  1.0
# ...                                          ...                  ...
# 3022                  voith mactavish architects                  1.0
# 3037                          wash cycle laundry                  1.0
# 3044                          webco construction                  1.0
# 3061                    wilco electronic systems                  1.0
# 3113                               zizza highway                  1.0
#
#                                       legal_name  \
# left_index
# 16                          6 degrees consulting
# 43                 aaaa office warehouse surplus
# 48                                       abbadon
# 64          accessibility modification solutions
# 69                         accu fire fabrication
# ...                                          ...
# 3022              voith mactavish architects llp
# 3037                          wash cycle laundry
# 3044                          webco construction
# 3061                    wilco electronic systems
# 3113                               zizza highway
#
#                                      trade_name
# left_index
# 16                         6 degrees consulting
# 43                aaaa office warehouse surplus
# 48                                      abbadon
# 64          accessibility modification solution
# 69                        accu fire fabrication
# ...                                         ...
# 3022             voith mactavish architects llp
# 3037                         wash cycle laundry
# 3044                         webco construction
# 3061                    wilco electronic system
# 3113                              zizza highway
#
# [152 rows x 7 columns]

# %%
# intersection.to_excel (r'C:\Users\dabinlee\Desktop\mwdsbe\data\intersection.xlsx', header=True)

# %% [markdown]
# ## Merge by address - Not matching well

# %%
cleaned_state_license.head()
# Out:
#       county             legal_name                 trade_name postal_code  \
# 0      ADAMS           nugen energy               nugen energy       17331
# 1  ALLEGHENY                 cellux  mobilexpress west mifflin       15123
# 2  ALLEGHENY  dina persichetti hill              nails at last       15101
# 3      ADAMS         elwood mummert           mummert elwood k  17331-7700
# 4  ALLEGHENY             cosmograce                  brillobox       15224
#
#   country account_number license_type expiration_date  \
# 0      US       67**9551       Retail      09/30/2021
# 1      US       85**6245       Retail      01/31/2021
# 2      US       81**6740       Retail      02/29/2024
# 3      US       81**7441       Retail      01/31/2021
# 4      US       67**9185       Retail      09/30/2021
#
#                                address_with_lat/long
# 0  1601 CARLISLE PIKE\nHANOVER, PA 17331\n(39.834...
# 1  3075 CLAIRON RD CENTURY III MA\nWEST MIFFLIN, ...
# 2  4085 WM FLYNN HWY STE 10A\nALLISON PARK, PA 15101
# 3  700 PINE GROVE RD\nHANOVER, PA 17331-7700\n(39...
# 4  4104 PENN AVE\nPITTSBURGH, PA 15224\n(40.46574...

# %%
# split street address from address_with_lat/long
cleaned_state_license['street_address'] = cleaned_state_license['address_with_lat/long'].astype(str).apply(lambda x : x.split("\n")[0])

# %%
cleaned_state_license.head()
# Out:
#       county             legal_name                 trade_name postal_code  \
# 0      ADAMS           nugen energy               nugen energy       17331
# 1  ALLEGHENY                 cellux  mobilexpress west mifflin       15123
# 2  ALLEGHENY  dina persichetti hill              nails at last       15101
# 3      ADAMS         elwood mummert           mummert elwood k  17331-7700
# 4  ALLEGHENY             cosmograce                  brillobox       15224
#
#   country account_number license_type expiration_date  \
# 0      US       67**9551       Retail      09/30/2021
# 1      US       85**6245       Retail      01/31/2021
# 2      US       81**6740       Retail      02/29/2024
# 3      US       81**7441       Retail      01/31/2021
# 4      US       67**9185       Retail      09/30/2021
#
#                                address_with_lat/long  \
# 0  1601 CARLISLE PIKE\nHANOVER, PA 17331\n(39.834...
# 1  3075 CLAIRON RD CENTURY III MA\nWEST MIFFLIN, ...
# 2  4085 WM FLYNN HWY STE 10A\nALLISON PARK, PA 15101
# 3  700 PINE GROVE RD\nHANOVER, PA 17331-7700\n(39...
# 4  4104 PENN AVE\nPITTSBURGH, PA 15224\n(40.46574...
#
#                    street_address
# 0              1601 CARLISLE PIKE
# 1  3075 CLAIRON RD CENTURY III MA
# 2       4085 WM FLYNN HWY STE 10A
# 3               700 PINE GROVE RD
# 4                   4104 PENN AVE

# %%
pa_registry.head()
# Out:
#                        company_name  dba_name   owner_first owner_last  \
# registry_id
# 0            119 degrees architects       NaN        Rafael     Utrera
# 2              1st choice financial  provisio      Kathrina      Nease
# 4               215 media solutions       NaN        Dewain    Johnson
# 5                                22       NaN      Caroline     Harper
# 7                  24 hour cleaning       NaN  Mary Colleen  Zoltowski
#
#                                  location location_city location_state  \
# registry_id
# 0            1503 Green Street, Suite # 4  Philadelphia             PA
# 2                      133 N. 21st Street     Camp Hill             PA
# 4                       810 Felton Avenue   Sharon Hill             PA
# 5                         757 Public Road     Bethlehem             PA
# 7                   14005 Barcalow Street  Philadelphia             PA
#
#              zip_code               mailing_address  mailing_city  \
# registry_id
# 0             19130.0  1503 Green Street, Suite # 4  Philadelphia
# 2             17011.0            133 N. 21st Street     Camp Hill
# 4             19079.0             810 Felton Avenue   Sharon Hill
# 5             18015.0               757 Public Road     Bethlehem
# 7             19116.0         14005 Barcalow Street  Philadelphia
#
#             mailing_state  mailing_zip certification_type  \
# registry_id
# 0                      PA      19130.0                MBE
# 2                      PA      17011.0                WBE
# 4                      PA      19079.0                MBE
# 5                      PA      18015.0                WBE
# 7                      PA      19116.0                WBE
#
#                                                     capability  local  \
# registry_id
# 0            NAICS 5413 Architectural, Engineering, and Rel...   True
# 2                           NAICS 928120 International Affairs  False
# 4            NAICS 5414 Specialized Design Services ; NAICS...  False
# 5            All Other Specialty Trade Contractors ; Enviro...  False
# 7            Janitorial equipment and supplies merchant who...   True
#
#              out_of_state  location_standard        lat        lng  \
# registry_id
# 0                   False      1503 GREEN ST  39.964275 -75.163042
# 2                   False                NaN        NaN        NaN
# 4                   False                NaN        NaN        NaN
# 5                   False                NaN        NaN        NaN
# 7                   False  14005 BARCALOW ST  40.131349 -75.014284
#
#                                geometry
# registry_id
# 0            POINT (-75.16304 39.96427)
# 2                                  None
# 4                                  None
# 5                                  None
# 7            POINT (-75.01428 40.13135)

# %%
# clean street information
cleaned_pa_registry = skool.clean_strings(pa_registry, ['location'], True)
cleaned_state_license = skool.clean_strings(cleaned_state_license, ['street_address'], True)

cleaned_pa_registry = cleaned_pa_registry.dropna(subset=['location'])
cleaned_state_license = cleaned_state_license.dropna(subset=['street_address'])

# %%
t1 = time.time()
merged_by_street = skool.tf_idf_merge(cleaned_pa_registry, cleaned_state_license, left_on='location', right_on='street_address', score_cutoff=95)
t = time.time() - t1

# %%
print('Execution time:', t/60, 'min')
# Out:
# Execution time: 7.25786319176356 min

# %%
matched_by_street = merged_by_street.dropna(subset=['street_address'])

# %%
len(matched_by_street)
# Out:
# 179

# %%
len(matched_by_street.index.unique()) # bug in tf-idf merge: not doing best match
# Out:
# 155

# %%
matched_by_street[['company_name', 'location', 'match_probability', 'legal_name', 'trade_name', 'street_address']]
# Out:
#             company_name              location  match_probability  \
# 17             84 lumber        1019 route 519           1.000000
# 17             84 lumber        1019 route 519           1.000000
# 25        a bob s towing  2220 orthodox street           0.959385
# 28           a n s steel   4340 sepviva street           0.968335
# 33    a lee cook hauling   643 pennfield drive           0.951261
# ...                  ...                   ...                ...
# 3044  webco construction    2512 s 76th street           1.000000
# 3055           wf design      4590 main street           1.000000
# 3062    wilco mechanical            po box 477           1.000000
# 3062    wilco mechanical            po box 477           1.000000
# 3068           wilson500    500 arlington road           1.000000
#
#                                  legal_name  \
# 17                            2100 penn ave
# 17                                84 lumber
# 25                            a bobs towing
# 28                              a n s steel
# 33                            j j specialty
# ...                                     ...
# 3044                     webco construction
# 3055                        james morrissey
# 3062                              dew drops
# 3062  fredericktown united methodist church
# 3068                              wilson500
#
#                                trade_name      street_address
# 17                          2100 penn ave      1019 route 519
# 17            84 lumber 84 fitness center      1019 route 519
# 25                          a bobs towing    2220 orthodox st
# 28                              ans steel     4340 sepviva st
# 33                          j j specialty    643 pennfield dr
# ...                                   ...                 ...
# 3044                   webco construction  2512 s 76th street
# 3055                           somo sophi    4590 main street
# 3062                            dew drops          po box 477
# 3062  fredericktown united methodist chur          po box 477
# 3068                            wilson500  500 arlington road
#
# [179 rows x 6 columns]

# %%
# matched_by_street.to_excel (r'C:\Users\dabinlee\Desktop\mwdsbe\data\state_license\by_street\tf-idf-95.xlsx', header=True)

# %%
diff = matched_by_street.index.difference(matched_opendataphilly_license.index) # newly catched matches

# %%
len(diff)
# Out:
# 75

# %%
newly_matched_by_street = matched_by_street.loc[diff][['company_name', 'dba_name', 'location', 'legal_name', 'trade_name', 'street_address']]

# %%
# newly_matched_by_street.to_excel (r'C:\Users\dabinlee\Desktop\mwdsbe\data\state_license\by_street\tf-idf-95-diff.xlsx', header=True)
